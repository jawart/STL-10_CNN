# %% [markdown]
# # model_3 - configuration & training

# %%
# Choosing of single GPU - has to be done before tensorflow import:
# All the notebooks used earlier with that option have to be closed or to have to have restarted the kernel
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="2"        # Will use only single GPU device

# %%
import numpy as np
import pandas as pd
import my_functions
import keras
from keras import layers
from keras import models
from keras import Model
from keras import optimizers
from keras import regularizers
import warnings
import tensorflow as tf
warnings.filterwarnings('ignore')
tf.logging.set_verbosity(tf.logging.ERROR)
# Out:
# Using TensorFlow backend.
# /home/artur/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/artur/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/artur/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/artur/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/artur/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/artur/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ## 1. New model configuration

# %% [markdown]
# ### 1.1 New colnvolutional base
# - Available models:

# %%
# %%bash
# ls ./Models
# Out:
# classifier_0.h5
# classifier_1.h5
# conv_base_0.h5
# conv_base_1.h5
# model_0_0-100-100-RMSp-trd.h5
# model_0_0-100-100-sgd-trd.h5
# model_0_0-100-120-rmsp-trd.h5
# model_0_0-100-150-adlt-trd.h5
# model_0_0-100-150-sgd-trd.h5
# model_0_0-15-15-rmsp-trd.h5
# model_0_0-15-25-RMSp-trd.h5
# model_0_0-15-40-sgd-trd.h5
# model_0_0-30-100-sgd-trd.h5
# model_0_8-100-100-sgd-trd.h5
# model_0_8-100-150-sgd-trd.h5
# model_0_8-100-21-RMSp-trd.h5
# model_0_8-100-30-adlt-trd.h5
# model_0_8-100-30-RMSp-trd.h5
# model_0_8-30-100-sgd-trd.h5
# model_0_8-30-30-adlt-trd.h5
# model_0_8-30-32-sgd-trd.h5
# model_0_8-30-8-adlt-trd.h5
# model_0_8-30-8-RMSp-trd.h5
# model_0.h5
# model_1_8-100-100-sgd-trd.h5
# model_1_8-100-30-RMSp-trd.h5
# model_1_8-30-32-sgd-trd.h5
# model_1_8-30-40-sgd-trd.h5
# model_1_8-30-9-adlt-trd.h5
# model_1.h5
# model_2_8-100-100-sgd-trd.h5
# model_2_8-100-25-RMSp-trd.h5
# model_2_8-30-20-adlt-trd.h5
# model_2_8-30-40-sgd-trd.h5
# model_2_8-30-9-adlt-trd.h5
# model_2.h5

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(96, 96, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(256, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.name = 'conv_base_2'
model.summary()
model.save('./Models/conv_base_2.h5')
# Out:
# Model: "conv_base_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 32)        896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 2, 2, 256)         295168
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 1, 1, 256)         0
# =================================================================
# Total params: 536,000
# Trainable params: 536,000
# Non-trainable params: 0
# _________________________________________________________________

# %%
classifier_0 = keras.models.load_model('./Models/classifier_0.h5')
classifier_0.summary()
# Out:
# Model: "classifier_0"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 263,682
# Trainable params: 263,682
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 1.2 Classifier modification

# %%
classifier_2 = models.Sequential()
classifier_2.add(layers.Dense(512, activation='relu', input_dim=1*1*256))
classifier_2.add(layers.Dense(2, activation='sigmoid'))
classifier_2.name = 'classifier_2'
classifier_2.summary()
classifier_2.save('./Models/classifier_2.h5')
# Out:
# Model: "classifier_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 132,610
# Trainable params: 132,610
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 1.3 model_3 aggregation

# %%
conv_base_2 = keras.models.load_model('./Models/conv_base_2.h5')
classifier_2 = keras.models.load_model('./Models/classifier_2.h5')

model_3 = models.Sequential()
model_3.add(conv_base_2)
model_3.add(layers.Flatten())
model_3.add(classifier_2)
model_3.name = 'model_3'
model_3.summary()
model_3.save('./Models/model_3.h5') # not trained
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_base_2 (Sequential)     (None, 1, 1, 256)         536000
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# classifier_2 (Sequential)    (None, 2)                 132610
# =================================================================
# Total params: 668,610
# Trainable params: 668,610
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 2. Data loading and transformation
# - Available data:

# %%
# %%bash
# ls ./Used_data
# Out:
# TEST_IMAGES.npy
# TEST_LABELS.npy
# TRAIN_IMAGES.npy
# TRAIN_LABELS.npy
# TRAIN_X_EXTD.npy
# TRAIN_Y_EXTD.npy
# VALID_IMAGES.npy
# VALID_LABELS.npy

# %%
526# Loads and transforms 'Used data' to CNN training

train_x_name = 'TRAIN_X_EXTD.npy'
train_y_name = 'TRAIN_Y_EXTD.npy'

TRAIN_X, VALID_X, TEST_X, TRAIN_Y, VALID_Y, TEST_Y = my_functions.data_conversion(train_x_name, train_y_name)
# Out:
# LOADED DATA (before conversion):
#   set name              shape  dtype       data sight
# 0  TRAIN_X  (8000, 96, 96, 3)  uint8     [87, 73, 37]
# 1  TRAIN_Y            (8000,)  uint8                2
# 2  VALID_X   (500, 96, 96, 3)  uint8  [204, 205, 210]
# 3  VALID_Y             (500,)  uint8                1
# 4   TEST_X   (500, 96, 96, 3)  uint8  [132, 167, 203]
# 5   TEST_Y             (500,)  uint8                1
#
# DATA FOR TRAINING (after conversion):
#   set name              shape    dtype                            data sight
# 0  TRAIN_X  (8000, 96, 96, 3)  float32  [0.34117648, 0.28627452, 0.14509805]
# 1  TRAIN_Y          (8000, 2)  float32                            [0.0, 1.0]
# 2  VALID_X   (500, 96, 96, 3)  float32           [0.8, 0.8039216, 0.8235294]
# 3  VALID_Y           (500, 2)  float32                            [1.0, 0.0]
# 4   TEST_X   (500, 96, 96, 3)  float32     [0.5176471, 0.654902, 0.79607844]
# 5   TEST_Y           (500, 2)  float32                            [1.0, 0.0]

# %% [markdown]
# ## 3. Model training
#
# For the training the models without 'trd' have to be choosen,
# models with 'trd' are trained already
#
# - Available models to choice:

# %%
# %%bash
# ls ./Models
# Out:
# classifier_0.h5
# classifier_1.h5
# classifier_2.h5
# conv_base_0.h5
# conv_base_1.h5
# conv_base_2.h5
# model_0_0-100-100-RMSp-trd.h5
# model_0_0-100-100-sgd-trd.h5
# model_0_0-100-120-rmsp-trd.h5
# model_0_0-100-150-adlt-trd.h5
# model_0_0-100-150-sgd-trd.h5
# model_0_0-15-15-rmsp-trd.h5
# model_0_0-15-25-RMSp-trd.h5
# model_0_0-15-40-sgd-trd.h5
# model_0_0-30-100-sgd-trd.h5
# model_0_8-100-100-sgd-trd.h5
# model_0_8-100-150-sgd-trd.h5
# model_0_8-100-21-RMSp-trd.h5
# model_0_8-100-30-adlt-trd.h5
# model_0_8-100-30-RMSp-trd.h5
# model_0_8-30-100-sgd-trd.h5
# model_0_8-30-30-adlt-trd.h5
# model_0_8-30-32-sgd-trd.h5
# model_0_8-30-8-adlt-trd.h5
# model_0_8-30-8-RMSp-trd.h5
# model_0.h5
# model_1_8-100-100-sgd-trd.h5
# model_1_8-100-30-RMSp-trd.h5
# model_1_8-30-32-sgd-trd.h5
# model_1_8-30-40-sgd-trd.h5
# model_1_8-30-9-adlt-trd.h5
# model_1.h5
# model_2_8-100-100-sgd-trd.h5
# model_2_8-100-25-RMSp-trd.h5
# model_2_8-30-20-adlt-trd.h5
# model_2_8-30-40-sgd-trd.h5
# model_2_8-30-9-adlt-trd.h5
# model_2.h5
# model_3.h5

# %% [markdown]
# #### Existing results overview:

# %%
# Results overview (function no. 8)

summary = pd.DataFrame(my_functions.results_preview()) 
summary.index = summary.index + 1
summary
# Out:
#                     model_name  model_description  notebook  dataset_size  \
# 1    model_0_0-100-150-sgd-trd  32-64-128-256-512  Module_1          1600
# 2   model_0_0-100-150-adlt-trd  32-64-128-256-512  Module_1          1600
# 3   model_0_0-100-120-rmsp-trd  32-64-128-256-512  Module_1          1600
# 4   model_0_0-100-100-RMSp-trd  32-64-128-256-512  Module_1          1600
# 5    model_0_0-100-100-sgd-trd  32-64-128-256-512  Module_1          1600
# 6     model_0_0-30-100-sgd-trd  32-64-128-256-512  Module_1          1600
# 7      model_0_0-15-40-sgd-trd  32-64-128-256-512  Module_1          1600
# 8     model_0_0-15-25-RMSp-trd  32-64-128-256-512  Module_1          1600
# 9     model_0_0-15-15-rmsp-trd  32-64-128-256-512  Module_1          1600
# 10   model_0_8-100-150-sgd-trd  32-64-128-256-512  Module_3          8000
# 11   model_0_8-100-100-sgd-trd  32-64-128-256-512  Module_3          8000
# 12    model_0_8-30-100-sgd-trd  32-64-128-256-512  Module_3          8000
# 13     model_0_8-30-32-sgd-trd  32-64-128-256-512  Module_3          8000
# 14    model_0_8-30-30-adlt-trd  32-64-128-256-512  Module_3          8000
# 15     model_0_8-30-8-adlt-trd  32-64-128-256-512  Module_3          8000
# 16   model_0_8-100-30-adlt-trd  32-64-128-256-512  Module_3          8000
# 17     model_0_8-30-8-RMSp-trd  32-64-128-256-512  Module_3          8000
# 18   model_0_8-100-30-RMSp-trd  32-64-128-256-512  Module_3          8000
# 19   model_0_8-100-21-RMSp-trd  32-64-128-256-512  Module_3          8000
# 20   model_1_8-100-100-sgd-trd  model_0 + Dropout  Module_4          8000
# 21     model_1_8-30-32-sgd-trd  model_0 + Dropout  Module_4          8000
# 22     model_1_8-30-40-sgd-trd  model_0 + Dropout  Module_4          8000
# 23     model_1_8-30-9-adlt-trd  model_0 + Dropout  Module_4          8000
# 24   model_1_8-100-30-RMSp-trd  model_0 + Dropout  Module_4          8000
# 25   model_2_8-100-100-sgd-trd  model_0 + reg. L2  Module_5          8000
# 26     model_2_8-30-40-sgd-trd  model_0 + reg. L2  Module_5          8000
# 27     model_2_8-30-9-adlt-trd  model_0 + reg. L2  Module_5          8000
# 28    model_2_8-30-20-adlt-trd  model_0 + reg. L2  Module_5          8000
# 29   model_2_8-100-25-RMSp-trd  model_0 + reg. L2  Module_5          8000
#
#     batch_size  epochs         optimizer    acc      remarks
# 1          100     150               sgd  0.924  100-overfit
# 2          100     150          adadelta  0.918   20-overfit
# 3          100     120           rmsprop  0.924   15-overfit
# 4          100     100  RMSprop(lr=1e-4)  0.932   20-overfit
# 5          100     100               sgd  0.904   no overfit
# 6           30     100               sgd  0.918   40-overfit
# 7           15      40               sgd  0.920   15-overfit
# 8           15      25  RMSprop(lr=1e-4)  0.882    6-overfit
# 9           15      15           rmsprop  0.926    4-overfit
# 10         100     150               sgd  0.522   80-overfit
# 11         100     100               sgd  0.934          ok.
# 12          30     100               sgd  0.522   30-overfit
# 13          30      32               sgd  0.918           ok
# 14          30      30          adadelta  0.940    7-overfit
# 15          30       8          adadelta  0.938           ok
# 16         100      30          adadelta  0.928   13-overfit
# 17          30       8  RMSprop(lr=1e-4)  0.856       not ok
# 18         100      30  RMSprop(lr=1e-4)  0.940   20-overfit
# 19         100      21  RMSprop(lr=1e-4)  0.890   17-overfit
# 20         100     100               sgd  0.930   80-overfit
# 21          30      32               sgd  0.934          ok.
# 22          30      40               sgd  0.922   30-overfit
# 23          30       9          adadelta  0.922    7-overfit
# 24         100      30  RMSprop(lr=1e-4)  0.942   20-overfit
# 25         100     100               sgd  0.900   80-overfit
# 26          30      40               sgd  0.904   30-overfit
# 27          30       9          adadelta  0.898           ok
# 28          30      20          adadelta  0.930   12-overfit
# 29         100      25  RMSprop(lr=1e-4)  0.872           ok

# %% [markdown]
# ### 3.1 model_3 & optimizer sgd:

# %%
model = keras.models.load_model('./Models/model_3.h5') # not trained model!

epochs = 100
batch_size = 100
optimizer = 'sgd'
optimizer_name = optimizer
trd_model_name = 'model_3_8-100-100-sgd-trd' # model after training, name without file extension !
notebook = 'Module_6'
model_descr = '32+64+128+128+256'
dataset_size = len(TRAIN_X)

# Training (function no. 23)

acc = my_functions.train_and_chart(batch_size, epochs, model, optimizer, 
                                   TRAIN_X, TRAIN_Y, VALID_X, VALID_Y, trd_model_name)
del(model)
# Out:
# Train on 8000 samples, validate on 500 samples
# Epoch 1/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.6918 - acc: 0.5029 - val_loss: 0.6899 - val_acc: 0.5760
# Epoch 2/100
# 8000/8000 [==============================] - 7s 823us/step - loss: 0.6900 - acc: 0.6324 - val_loss: 0.6877 - val_acc: 0.6880
# Epoch 3/100
# 8000/8000 [==============================] - 7s 815us/step - loss: 0.6877 - acc: 0.6820 - val_loss: 0.6846 - val_acc: 0.7180
# Epoch 4/100
# 8000/8000 [==============================] - 7s 818us/step - loss: 0.6846 - acc: 0.7056 - val_loss: 0.6803 - val_acc: 0.7400
# Epoch 5/100
# 8000/8000 [==============================] - 7s 813us/step - loss: 0.6799 - acc: 0.7081 - val_loss: 0.6731 - val_acc: 0.7420
# Epoch 6/100
# 8000/8000 [==============================] - 7s 817us/step - loss: 0.6717 - acc: 0.7105 - val_loss: 0.6597 - val_acc: 0.7340
# Epoch 7/100
# 8000/8000 [==============================] - 7s 813us/step - loss: 0.6564 - acc: 0.7088 - val_loss: 0.6332 - val_acc: 0.7500
# Epoch 8/100
# 8000/8000 [==============================] - 6s 812us/step - loss: 0.6237 - acc: 0.7165 - val_loss: 0.5748 - val_acc: 0.7720
# Epoch 9/100
# 8000/8000 [==============================] - 7s 816us/step - loss: 0.5734 - acc: 0.7240 - val_loss: 0.5388 - val_acc: 0.7460
# Epoch 10/100
# 8000/8000 [==============================] - 7s 813us/step - loss: 0.5528 - acc: 0.7283 - val_loss: 0.5139 - val_acc: 0.7600
# Epoch 11/100
# 8000/8000 [==============================] - 6s 811us/step - loss: 0.5363 - acc: 0.7393 - val_loss: 0.4919 - val_acc: 0.7740
# Epoch 12/100
# 8000/8000 [==============================] - 7s 815us/step - loss: 0.5328 - acc: 0.7396 - val_loss: 0.4713 - val_acc: 0.7920
# Epoch 13/100
100
# 8000/8000 [==============================] - 7s 817us/step - loss: 0.1714 - acc: 0.9355 - val_loss: 0.2715 - val_acc: 0.9080
# Epoch 91/100
# 8000/8000 [==============================] - 7s 817us/step - loss: 0.1785 - acc: 0.9295 - val_loss: 0.2252 - val_acc: 0.9260
# Epoch 92/100
# 8000/8000 [==============================] - 7s 815us/step - loss: 0.1666 - acc: 0.9348 - val_loss: 0.1910 - val_acc: 0.9380
# Epoch 93/100
# 8000/8000 [==============================] - 7s 817us/step - loss: 0.1450 - acc: 0.9455 - val_loss: 0.1879 - val_acc: 0.9360
# Epoch 94/100
# 8000/8000 [==============================] - 7s 814us/step - loss: 0.1594 - acc: 0.9404 - val_loss: 0.1816 - val_acc: 0.9360
# Epoch 95/100
# 8000/8000 [==============================] - 7s 815us/step - loss: 0.1662 - acc: 0.9341 - val_loss: 0.1949 - val_acc: 0.9260
# Epoch 96/100
# 8000/8000 [==============================] - 7s 816us/step - loss: 0.1463 - acc: 0.9429 - val_loss: 0.2505 - val_acc: 0.8980
# Epoch 97/100
# 8000/8000 [==============================] - 7s 814us/step - loss: 0.1409 - acc: 0.9457 - val_loss: 0.1946 - val_acc: 0.9240
# Epoch 98/100
# 8000/8000 [==============================] - 7s 813us/step - loss: 0.1357 - acc: 0.9465 - val_loss: 0.1901 - val_acc: 0.9340
# Epoch 99/100
# 8000/8000 [==============================] - 7s 815us/step - loss: 0.1356 - acc: 0.9473 - val_loss: 0.2000 - val_acc: 0.9280
# Epoch 100/100
# 8000/8000 [==============================] - 7s 813us/step - loss: 0.1363 - acc: 0.9465 - val_loss: 0.1880 - val_acc: 0.9360
# 500/500 [==============================] - 0s 714us/step
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# Validation accuracy 0.9359999895095825
#
# Execution time:   0:10:58.885435

# %%
remark = 'ok'

# Results saving (function no. 6)

my_functions.results_update(trd_model_name, model_descr, notebook, dataset_size, 
                            batch_size, epochs, optimizer_name, acc, remark)

# Results overview (function no. 8)

summary = pd.DataFrame(my_functions.results_preview()) 
summary.index = summary.index + 1
summary
# Out:
#                     model_name  model_description  notebook  dataset_size  \
# 1    model_0_0-100-150-sgd-trd  32-64-128-256-512  Module_1          1600
# 2   model_0_0-100-150-adlt-trd  32-64-128-256-512  Module_1          1600
# 3   model_0_0-100-120-rmsp-trd  32-64-128-256-512  Module_1          1600
# 4   model_0_0-100-100-RMSp-trd  32-64-128-256-512  Module_1          1600
# 5    model_0_0-100-100-sgd-trd  32-64-128-256-512  Module_1          1600
# 6     model_0_0-30-100-sgd-trd  32-64-128-256-512  Module_1          1600
# 7      model_0_0-15-40-sgd-trd  32-64-128-256-512  Module_1          1600
# 8     model_0_0-15-25-RMSp-trd  32-64-128-256-512  Module_1          1600
# 9     model_0_0-15-15-rmsp-trd  32-64-128-256-512  Module_1          1600
# 10   model_0_8-100-150-sgd-trd  32-64-128-256-512  Module_3          8000
# 11   model_0_8-100-100-sgd-trd  32-64-128-256-512  Module_3          8000
# 12    model_0_8-30-100-sgd-trd  32-64-128-256-512  Module_3          8000
# 13     model_0_8-30-32-sgd-trd  32-64-128-256-512  Module_3          8000
# 14    model_0_8-30-30-adlt-trd  32-64-128-256-512  Module_3          8000
# 15     model_0_8-30-8-adlt-trd  32-64-128-256-512  Module_3          8000
# 16   model_0_8-100-30-adlt-trd  32-64-128-256-512  Module_3          8000
# 17     model_0_8-30-8-RMSp-trd  32-64-128-256-512  Module_3          8000
# 18   model_0_8-100-30-RMSp-trd  32-64-128-256-512  Module_3          8000
# 19   model_0_8-100-21-RMSp-trd  32-64-128-256-512  Module_3          8000
# 20   model_1_8-100-100-sgd-trd  model_0 + Dropout  Module_4          8000
# 21     model_1_8-30-32-sgd-trd  model_0 + Dropout  Module_4          8000
# 22     model_1_8-30-40-sgd-trd  model_0 + Dropout  Module_4          8000
# 23     model_1_8-30-9-adlt-trd  model_0 + Dropout  Module_4          8000
# 24   model_1_8-100-30-RMSp-trd  model_0 + Dropout  Module_4          8000
# 25   model_2_8-100-100-sgd-trd  model_0 + reg. L2  Module_5          8000
# 26     model_2_8-30-40-sgd-trd  model_0 + reg. L2  Module_5          8000
# 27     model_2_8-30-9-adlt-trd  model_0 + reg. L2  Module_5          8000
# 28    model_2_8-30-20-adlt-trd  model_0 + reg. L2  Module_5          8000
# 29   model_2_8-100-25-RMSp-trd  model_0 + reg. L2  Module_5          8000
# 30   model_3_8-100-100-sgd-trd  32+64+128+128+256  Module_6          8000
#
#     batch_size  epochs         optimizer    acc      remarks
# 1          100     150               sgd  0.924  100-overfit
# 2          100     150          adadelta  0.918   20-overfit
# 3          100     120           rmsprop  0.924   15-overfit
# 4          100     100  RMSprop(lr=1e-4)  0.932   20-overfit
# 5          100     100               sgd  0.904   no overfit
# 6           30     100               sgd  0.918   40-overfit
# 7           15      40               sgd  0.920   15-overfit
# 8           15      25  RMSprop(lr=1e-4)  0.882    6-overfit
# 9           15      15           rmsprop  0.926    4-overfit
# 10         100     150               sgd  0.522   80-overfit
# 11         100     100               sgd  0.934          ok.
# 12          30     100               sgd  0.522   30-overfit
# 13          30      32               sgd  0.918           ok
# 14          30      30          adadelta  0.940    7-overfit
# 15          30       8          adadelta  0.938           ok
# 16         100      30          adadelta  0.928   13-overfit
# 17          30       8  RMSprop(lr=1e-4)  0.856       not ok
# 18         100      30  RMSprop(lr=1e-4)  0.940   20-overfit
# 19         100      21  RMSprop(lr=1e-4)  0.890   17-overfit
# 20         100     100               sgd  0.930   80-overfit
# 21          30      32               sgd  0.934          ok.
# 22          30      40               sgd  0.922   30-overfit
# 23          30       9          adadelta  0.922    7-overfit
# 24         100      30  RMSprop(lr=1e-4)  0.942   20-overfit
# 25         100     100               sgd  0.900   80-overfit
# 26          30      40               sgd  0.904   30-overfit
# 27          30       9          adadelta  0.898           ok
# 28          30      20          adadelta  0.930   12-overfit
# 29         100      25  RMSprop(lr=1e-4)  0.872           ok
# 30         100     100               sgd  0.936           ok

# %% [markdown]
# ### 3.2 model_3 & optimizer adadelta:

# %%
model = keras.models.load_model('./Models/model_3.h5') # not trained model!

epochs = 100
batch_size = 100
optimizer = 'adadelta'
optimizer_name = optimizer
trd_model_name = 'model_3_8-100-100-adlt-trd' # model after training, name without file extension !
notebook = 'Module_6'
model_descr = '32+64+128+128+256'
dataset_size = len(TRAIN_X)

# Training (function no. 23)

acc = my_functions.train_and_chart(batch_size, epochs, model, optimizer, 
                                   TRAIN_X, TRAIN_Y, VALID_X, VALID_Y, trd_model_name)
del(model)
# Out:
# Train on 8000 samples, validate on 500 samples
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# Validation accuracy 0.9419999718666077
#
# Execution time:   0:11:39.002324

# %%
remark = '15-overfit'

# Results saving (function no. 6)

my_functions.results_update(trd_model_name, model_descr, notebook, dataset_size, 
                            batch_size, epochs, optimizer_name, acc, remark)

# Results overview (function no. 8)

summary = pd.DataFrame(my_functions.results_preview()) 
summary.index = summary.index + 1
summary
# Out:
#                     model_name  model_description  notebook  dataset_size  \
# 1    model_0_0-100-150-sgd-trd  32-64-128-256-512  Module_1          1600
# 2   model_0_0-100-150-adlt-trd  32-64-128-256-512  Module_1          1600
# 3   model_0_0-100-120-rmsp-trd  32-64-128-256-512  Module_1          1600
# 4   model_0_0-100-100-RMSp-trd  32-64-128-256-512  Module_1          1600
# 5    model_0_0-100-100-sgd-trd  32-64-128-256-512  Module_1          1600
# 6     model_0_0-30-100-sgd-trd  32-64-128-256-512  Module_1          1600
# 7      model_0_0-15-40-sgd-trd  32-64-128-256-512  Module_1          1600
# 8     model_0_0-15-25-RMSp-trd  32-64-128-256-512  Module_1          1600
# 9     model_0_0-15-15-rmsp-trd  32-64-128-256-512  Module_1          1600
# 10   model_0_8-100-150-sgd-trd  32-64-128-256-512  Module_3          8000
# 11   model_0_8-100-100-sgd-trd  32-64-128-256-512  Module_3          8000
# 12    model_0_8-30-100-sgd-trd  32-64-128-256-512  Module_3          8000
# 13     model_0_8-30-32-sgd-trd  32-64-128-256-512  Module_3          8000
# 14    model_0_8-30-30-adlt-trd  32-64-128-256-512  Module_3          8000
# 15     model_0_8-30-8-adlt-trd  32-64-128-256-512  Module_3          8000
# 16   model_0_8-100-30-adlt-trd  32-64-128-256-512  Module_3          8000
# 17     model_0_8-30-8-RMSp-trd  32-64-128-256-512  Module_3          8000
# 18   model_0_8-100-30-RMSp-trd  32-64-128-256-512  Module_3          8000
# 19   model_0_8-100-21-RMSp-trd  32-64-128-256-512  Module_3          8000
# 20   model_1_8-100-100-sgd-trd  model_0 + Dropout  Module_4          8000
# 21     model_1_8-30-32-sgd-trd  model_0 + Dropout  Module_4          8000
# 22     model_1_8-30-40-sgd-trd  model_0 + Dropout  Module_4          8000
# 23     model_1_8-30-9-adlt-trd  model_0 + Dropout  Module_4          8000
# 24   model_1_8-100-30-RMSp-trd  model_0 + Dropout  Module_4          8000
# 25   model_2_8-100-100-sgd-trd  model_0 + reg. L2  Module_5          8000
# 26     model_2_8-30-40-sgd-trd  model_0 + reg. L2  Module_5          8000
# 27     model_2_8-30-9-adlt-trd  model_0 + reg. L2  Module_5          8000
# 28    model_2_8-30-20-adlt-trd  model_0 + reg. L2  Module_5          8000
# 29   model_2_8-100-25-RMSp-trd  model_0 + reg. L2  Module_5          8000
# 30   model_3_8-100-100-sgd-trd  32+64+128+128+256  Module_6          8000
# 31  model_3_8-100-100-adlt-trd  32+64+128+128+256  Module_6          8000
#
#     batch_size  epochs         optimizer    acc      remarks
# 1          100     150               sgd  0.924  100-overfit
# 2          100     150          adadelta  0.918   20-overfit
# 3          100     120           rmsprop  0.924   15-overfit
# 4          100     100  RMSprop(lr=1e-4)  0.932   20-overfit
# 5          100     100               sgd  0.904   no overfit
# 6           30     100               sgd  0.918   40-overfit
# 7           15      40               sgd  0.920   15-overfit
# 8           15      25  RMSprop(lr=1e-4)  0.882    6-overfit
# 9           15      15           rmsprop  0.926    4-overfit
# 10         100     150               sgd  0.522   80-overfit
# 11         100     100               sgd  0.934          ok.
# 12          30     100               sgd  0.522   30-overfit
# 13          30      32               sgd  0.918           ok
# 14          30      30          adadelta  0.940    7-overfit
# 15          30       8          adadelta  0.938           ok
# 16         100      30          adadelta  0.928   13-overfit
# 17          30       8  RMSprop(lr=1e-4)  0.856       not ok
# 18         100      30  RMSprop(lr=1e-4)  0.940   20-overfit
# 19         100      21  RMSprop(lr=1e-4)  0.890   17-overfit
# 20         100     100               sgd  0.930   80-overfit
# 21          30      32               sgd  0.934          ok.
# 22          30      40               sgd  0.922   30-overfit
# 23          30       9          adadelta  0.922    7-overfit
# 24         100      30  RMSprop(lr=1e-4)  0.942   20-overfit
# 25         100     100               sgd  0.900   80-overfit
# 26          30      40               sgd  0.904   30-overfit
# 27          30       9          adadelta  0.898           ok
# 28          30      20          adadelta  0.930   12-overfit
# 29         100      25  RMSprop(lr=1e-4)  0.872           ok
# 30         100     100               sgd  0.936           ok
# 31         100     100          adadelta  0.942   15-overfit

# %% [markdown]
# ### 3.3 model_3 & optimizer adadelta:

# %%
model = keras.models.load_model('./Models/model_3.h5') # not trained model!

epochs = 20
batch_size = 100
optimizer = 'adadelta'
optimizer_name = optimizer
trd_model_name = 'model_3_8-100-20-adlt-trd' # model after training, name without file extension !
notebook = 'Module_6'
model_descr = '32+64+128+128+256'
dataset_size = len(TRAIN_X)

# Training (function no. 23)

acc = my_functions.train_and_chart(batch_size, epochs, model, optimizer, 
                                   TRAIN_X, TRAIN_Y, VALID_X, VALID_Y, trd_model_name)
del(model)
# Out:
# Train on 8000 samples, validate on 500 samples
# Epoch 1/20
# 8000/8000 [==============================] - 8s 986us/step - loss: 0.6612 - acc: 0.6284 - val_loss: 0.5301 - val_acc: 0.7400
# Epoch 2/20
# 8000/8000 [==============================] - 7s 875us/step - loss: 0.5599 - acc: 0.7333 - val_loss: 0.4507 - val_acc: 0.7980
# Epoch 3/20
# 8000/8000 [==============================] - 7s 873us/step - loss: 0.4540 - acc: 0.8034 - val_loss: 0.2775 - val_acc: 0.8980
# Epoch 4/20
# 8000/8000 [==============================] - 7s 877us/step - loss: 0.3818 - acc: 0.8396 - val_loss: 0.2743 - val_acc: 0.8940
# Epoch 5/20
# 8000/8000 [==============================] - 7s 876us/step - loss: 0.3433 - acc: 0.8579 - val_loss: 0.2277 - val_acc: 0.9120
# Epoch 6/20
# 8000/8000 [==============================] - 7s 871us/step - loss: 0.3199 - acc: 0.8662 - val_loss: 0.2491 - val_acc: 0.9020
# Epoch 7/20
# 8000/8000 [==============================] - 7s 873us/step - loss: 0.2906 - acc: 0.8817 - val_loss: 0.2155 - val_acc: 0.9100
# Epoch 8/20
# 8000/8000 [==============================] - 7s 874us/step - loss: 0.2701 - acc: 0.8871 - val_loss: 0.2017 - val_acc: 0.9220
# Epoch 9/20
# 8000/8000 [==============================] - 7s 875us/step - loss: 0.2500 - acc: 0.8965 - val_loss: 0.2087 - val_acc: 0.9200
# Epoch 10/20
# 8000/8000 [==============================] - 7s 874us/step - loss: 0.2440 - acc: 0.8961 - val_loss: 0.1957 - val_acc: 0.9240
# Epoch 11/20
# 8000/8000 [==============================] - 7s 876us/step - loss: 0.2136 - acc: 0.9089 - val_loss: 0.2055 - val_acc: 0.9260
# Epoch 12/20
# 8000/8000 [==============================] - 7s 869us/step - loss: 0.1875 - acc: 0.9240 - val_loss: 0.1870 - val_acc: 0.9360
# Epoch 13/20
# 8000/8000 [==============================] - 7s 867us/step - loss: 0.1826 - acc: 0.9237 - val_loss: 0.1993 - val_acc: 0.9180
# Epoch 14/20
# 8000/8000 [==============================] - 7s 874us/step - loss: 0.1529 - acc: 0.9396 - val_loss: 0.1583 - val_acc: 0.9460
# Epoch 15/20
# 8000/8000 [==============================] - 7s 869us/step - loss: 0.1257 - acc: 0.9516 - val_loss: 0.1888 - val_acc: 0.9340
# Epoch 16/20
# 8000/8000 [==============================] - 7s 875us/step - loss: 0.1163 - acc: 0.9539 - val_loss: 0.1966 - val_acc: 0.9360
# Epoch 17/20
# 8000/8000 [==============================] - 7s 868us/step - loss: 0.1022 - acc: 0.9580 - val_loss: 0.2249 - val_acc: 0.9320
# Epoch 18/20
# 8000/8000 [==============================] - 7s 877us/step - loss: 0.0758 - acc: 0.9716 - val_loss: 0.2924 - val_acc: 0.9020
# Epoch 19/20
# 8000/8000 [==============================] - 7s 873us/step - loss: 0.0474 - acc: 0.9819 - val_loss: 0.2522 - val_acc: 0.9300
# Epoch 20/20
# 8000/8000 [==============================] - 7s 873us/step - loss: 0.0483 - acc: 0.9856 - val_loss: 0.2321 - val_acc: 0.9460
# 500/500 [==============================] - 0s 494us/step
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# Validation accuracy 0.9459999799728394
#
# Execution time:   0:02:22.706580

# %%
remark = '12-overfit'

# Results saving (function no. 6)

my_functions.results_update(trd_model_name, model_descr, notebook, dataset_size, 
                            batch_size, epochs, optimizer_name, acc, remark)

# Results overview (function no. 8)

summary = pd.DataFrame(my_functions.results_preview()) 
summary.index = summary.index + 1
summary
# Out:
#                     model_name  model_description  notebook  dataset_size  \
# 1    model_0_0-100-150-sgd-trd  32-64-128-256-512  Module_1          1600
# 2   model_0_0-100-150-adlt-trd  32-64-128-256-512  Module_1          1600
# 3   model_0_0-100-120-rmsp-trd  32-64-128-256-512  Module_1          1600
# 4   model_0_0-100-100-RMSp-trd  32-64-128-256-512  Module_1          1600
# 5    model_0_0-100-100-sgd-trd  32-64-128-256-512  Module_1          1600
# 6     model_0_0-30-100-sgd-trd  32-64-128-256-512  Module_1          1600
# 7      model_0_0-15-40-sgd-trd  32-64-128-256-512  Module_1          1600
# 8     model_0_0-15-25-RMSp-trd  32-64-128-256-512  Module_1          1600
# 9     model_0_0-15-15-rmsp-trd  32-64-128-256-512  Module_1          1600
# 10   model_0_8-100-150-sgd-trd  32-64-128-256-512  Module_3          8000
# 11   model_0_8-100-100-sgd-trd  32-64-128-256-512  Module_3          8000
# 12    model_0_8-30-100-sgd-trd  32-64-128-256-512  Module_3          8000
# 13     model_0_8-30-32-sgd-trd  32-64-128-256-512  Module_3          8000
# 14    model_0_8-30-30-adlt-trd  32-64-128-256-512  Module_3          8000
# 15     model_0_8-30-8-adlt-trd  32-64-128-256-512  Module_3          8000
# 16   model_0_8-100-30-adlt-trd  32-64-128-256-512  Module_3          8000
# 17     model_0_8-30-8-RMSp-trd  32-64-128-256-512  Module_3          8000
# 18   model_0_8-100-30-RMSp-trd  32-64-128-256-512  Module_3          8000
# 19   model_0_8-100-21-RMSp-trd  32-64-128-256-512  Module_3          8000
# 20   model_1_8-100-100-sgd-trd  model_0 + Dropout  Module_4          8000
# 21     model_1_8-30-32-sgd-trd  model_0 + Dropout  Module_4          8000
# 22     model_1_8-30-40-sgd-trd  model_0 + Dropout  Module_4          8000
# 23     model_1_8-30-9-adlt-trd  model_0 + Dropout  Module_4          8000
# 24   model_1_8-100-30-RMSp-trd  model_0 + Dropout  Module_4          8000
# 25   model_2_8-100-100-sgd-trd  model_0 + reg. L2  Module_5          8000
# 26     model_2_8-30-40-sgd-trd  model_0 + reg. L2  Module_5          8000
# 27     model_2_8-30-9-adlt-trd  model_0 + reg. L2  Module_5          8000
# 28    model_2_8-30-20-adlt-trd  model_0 + reg. L2  Module_5          8000
# 29   model_2_8-100-25-RMSp-trd  model_0 + reg. L2  Module_5          8000
# 30   model_3_8-100-100-sgd-trd  32+64+128+128+256  Module_6          8000
# 31  model_3_8-100-100-adlt-trd  32+64+128+128+256  Module_6          8000
# 32   model_3_8-100-20-adlt-trd  32+64+128+128+256  Module_6          8000
#
#     batch_size  epochs         optimizer    acc      remarks
# 1          100     150               sgd  0.924  100-overfit
# 2          100     150          adadelta  0.918   20-overfit
# 3          100     120           rmsprop  0.924   15-overfit
# 4          100     100  RMSprop(lr=1e-4)  0.932   20-overfit
# 5          100     100               sgd  0.904   no overfit
# 6           30     100               sgd  0.918   40-overfit
# 7           15      40               sgd  0.920   15-overfit
# 8           15      25  RMSprop(lr=1e-4)  0.882    6-overfit
# 9           15      15           rmsprop  0.926    4-overfit
# 10         100     150               sgd  0.522   80-overfit
# 11         100     100               sgd  0.934          ok.
# 12          30     100               sgd  0.522   30-overfit
# 13          30      32               sgd  0.918           ok
# 14          30      30          adadelta  0.940    7-overfit
# 15          30       8          adadelta  0.938           ok
# 16         100      30          adadelta  0.928   13-overfit
# 17          30       8  RMSprop(lr=1e-4)  0.856       not ok
# 18         100      30  RMSprop(lr=1e-4)  0.940   20-overfit
# 19         100      21  RMSprop(lr=1e-4)  0.890   17-overfit
# 20         100     100               sgd  0.930   80-overfit
# 21          30      32               sgd  0.934          ok.
# 22          30      40               sgd  0.922   30-overfit
# 23          30       9          adadelta  0.922    7-overfit
# 24         100      30  RMSprop(lr=1e-4)  0.942   20-overfit
# 25         100     100               sgd  0.900   80-overfit
# 26          30      40               sgd  0.904   30-overfit
# 27          30       9          adadelta  0.898           ok
# 28          30      20          adadelta  0.930   12-overfit
# 29         100      25  RMSprop(lr=1e-4)  0.872           ok
# 30         100     100               sgd  0.936           ok
# 31         100     100          adadelta  0.942   15-overfit
# 32         100      20          adadelta  0.946   12-overfit

# %% [markdown]
# ### 3.4 model_3 & optimizer RMSprop(lr=1e-4)

# %%
model = keras.models.load_model('./Models/model_3.h5') # not trained model!

epochs = 30
batch_size = 100
optimizer = optimizers.RMSprop(lr=1e-4)
optimizer_name = 'RMSprop(lr=1e-4)'
trd_model_name = 'model_3_8-100-30-RMSp-trd' # model after training, name without file extension !
notebook = 'Module_6'
model_descr = '32+64+128+128+256'
dataset_size = len(TRAIN_X)

# Training (function no. 23)

acc = my_functions.train_and_chart(batch_size, epochs, model, optimizer, 
                                   TRAIN_X, TRAIN_Y, VALID_X, VALID_Y, trd_model_name)
del(model)
# Out:
# Train on 8000 samples, validate on 500 samples
# Epoch 1/30
# 8000/8000 [==============================] - 8s 938us/step - loss: 0.5886 - acc: 0.7007 - val_loss: 0.4483 - val_acc: 0.8340
# Epoch 2/30
# 8000/8000 [==============================] - 7s 851us/step - loss: 0.4955 - acc: 0.7666 - val_loss: 0.3647 - val_acc: 0.8300
# Epoch 3/30
# 8000/8000 [==============================] - 7s 851us/step - loss: 0.4464 - acc: 0.7999 - val_loss: 0.5042 - val_acc: 0.7760
# Epoch 4/30
# 8000/8000 [==============================] - 7s 848us/step - loss: 0.4038 - acc: 0.8244 - val_loss: 0.2990 - val_acc: 0.8680
# Epoch 5/30
# 8000/8000 [==============================] - 7s 846us/step - loss: 0.3808 - acc: 0.8354 - val_loss: 0.2518 - val_acc: 0.8920
# Epoch 6/30
# 8000/8000 [==============================] - 7s 849us/step - loss: 0.3556 - acc: 0.8469 - val_loss: 0.2759 - val_acc: 0.8840
# Epoch 7/30
# 8000/8000 [==============================] - 7s 849us/step - loss: 0.3471 - acc: 0.8509 - val_loss: 0.2575 - val_acc: 0.8900
# Epoch 8/30
# 8000/8000 [==============================] - 7s 854us/step - loss: 0.3300 - acc: 0.8581 - val_loss: 0.2378 - val_acc: 0.9020
# Epoch 9/30
# 8000/8000 [==============================] - 7s 853us/step - loss: 0.3192 - acc: 0.8659 - val_loss: 0.2108 - val_acc: 0.9160
# Epoch 10/30
# 8000/8000 [==============================] - 7s 854us/step - loss: 0.3117 - acc: 0.8705 - val_loss: 0.2089 - val_acc: 0.9160
# Epoch 11/30
# 8000/8000 [==============================] - 7s 852us/step - loss: 0.2903 - acc: 0.8819 - val_loss: 0.2318 - val_acc: 0.9000
# Epoch 12/30
# 8000/8000 [==============================] - 7s 850us/step - loss: 0.2882 - acc: 0.8873 - val_loss: 0.2040 - val_acc: 0.9160
# Epoch 13/30
# 8000/8000 [==============================] - 7s 854us/step - loss: 0.2756 - acc: 0.8857 - val_loss: 0.2022 - val_acc: 0.9140
# Epoch 14/30
# 8000/8000 [==============================] - 7s 855us/step - loss: 0.2702 - acc: 0.8905 - val_loss: 0.2012 - val_acc: 0.9140
# Epoch 15/30
# 8000/8000 [==============================] - 7s 853us/step - loss: 0.2545 - acc: 0.8966 - val_loss: 0.1863 - val_acc: 0.9280
# Epoch 16/30
# 8000/8000 [==============================] - 7s 853us/step - loss: 0.2521 - acc: 0.9010 - val_loss: 0.1890 - val_acc: 0.9280
# Epoch 17/30
# 8000/8000 [==============================] - 7s 852us/step - loss: 0.2394 - acc: 0.9062 - val_loss: 0.1891 - val_acc: 0.9240
# Epoch 18/30
# 8000/8000 [==============================] - 7s 854us/step - loss: 0.2399 - acc: 0.9026 - val_loss: 0.2355 - val_acc: 0.9020
# Epoch 19/30
# 8000/8000 [==============================] - 7s 855us/step - loss: 0.2236 - acc: 0.9105 - val_loss: 0.2141 - val_acc: 0.9060
# Epoch 20/30
# 8000/8000 [==============================] - 7s 851us/step - loss: 0.2199 - acc: 0.9129 - val_loss: 0.2389 - val_acc: 0.9160
# Epoch 21/30
# 8000/8000 [==============================] - 7s 850us/step - loss: 0.2096 - acc: 0.9160 - val_loss: 0.1754 - val_acc: 0.9340
# Epoch 22/30
# 8000/8000 [==============================] - 7s 850us/step - loss: 0.2027 - acc: 0.9191 - val_loss: 0.3249 - val_acc: 0.8760
# Epoch 23/30
# 8000/8000 [==============================] - 7s 849us/step - loss: 0.1960 - acc: 0.9216 - val_loss: 0.1934 - val_acc: 0.9260
# Epoch 24/30
# 8000/8000 [==============================] - 7s 853us/step - loss: 0.1906 - acc: 0.9226 - val_loss: 0.1775 - val_acc: 0.9320
# Epoch 25/30
# 8000/8000 [==============================] - 7s 851us/step - loss: 0.1834 - acc: 0.9275 - val_loss: 0.1771 - val_acc: 0.9280
# Epoch 26/30
# 8000/8000 [==============================] - 7s 846us/step - loss: 0.1794 - acc: 0.9275 - val_loss: 0.1974 - val_acc: 0.9240
# Epoch 27/30
# 8000/8000 [==============================] - 7s 861us/step - loss: 0.1704 - acc: 0.9344 - val_loss: 0.1698 - val_acc: 0.9380
# Epoch 28/30
# 8000/8000 [==============================] - 7s 851us/step - loss: 0.1667 - acc: 0.9341 - val_loss: 0.2024 - val_acc: 0.9180
# Epoch 29/30
# 8000/8000 [==============================] - 7s 851us/step - loss: 0.1553 - acc: 0.9415 - val_loss: 0.1803 - val_acc: 0.9360
# Epoch 30/30
# 8000/8000 [==============================] - 7s 853us/step - loss: 0.1498 - acc: 0.9389 - val_loss: 0.1787 - val_acc: 0.9320
# 500/500 [==============================] - 0s 487us/step
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# Validation accuracy 0.9319999814033508
#
# Execution time:   0:03:27.302575

# %%
remark = 'ok'

# Results saving (function no. 6)

my_functions.results_update(trd_model_name, model_descr, notebook, dataset_size, 
                            batch_size, epochs, optimizer_name, acc, remark)

# Results overview (function no. 8)

summary = pd.DataFrame(my_functions.results_preview()) 
summary.index = summary.index + 1
summary
# Out:
#                     model_name  model_description  notebook  dataset_size  \
# 1    model_0_0-100-150-sgd-trd  32-64-128-256-512  Module_1          1600
# 2   model_0_0-100-150-adlt-trd  32-64-128-256-512  Module_1          1600
# 3   model_0_0-100-120-rmsp-trd  32-64-128-256-512  Module_1          1600
# 4   model_0_0-100-100-RMSp-trd  32-64-128-256-512  Module_1          1600
# 5    model_0_0-100-100-sgd-trd  32-64-128-256-512  Module_1          1600
# 6     model_0_0-30-100-sgd-trd  32-64-128-256-512  Module_1          1600
# 7      model_0_0-15-40-sgd-trd  32-64-128-256-512  Module_1          1600
# 8     model_0_0-15-25-RMSp-trd  32-64-128-256-512  Module_1          1600
# 9     model_0_0-15-15-rmsp-trd  32-64-128-256-512  Module_1          1600
# 10   model_0_8-100-150-sgd-trd  32-64-128-256-512  Module_3          8000
# 11   model_0_8-100-100-sgd-trd  32-64-128-256-512  Module_3          8000
# 12    model_0_8-30-100-sgd-trd  32-64-128-256-512  Module_3          8000
# 13     model_0_8-30-32-sgd-trd  32-64-128-256-512  Module_3          8000
# 14    model_0_8-30-30-adlt-trd  32-64-128-256-512  Module_3          8000
# 15     model_0_8-30-8-adlt-trd  32-64-128-256-512  Module_3          8000
# 16   model_0_8-100-30-adlt-trd  32-64-128-256-512  Module_3          8000
# 17     model_0_8-30-8-RMSp-trd  32-64-128-256-512  Module_3          8000
# 18   model_0_8-100-30-RMSp-trd  32-64-128-256-512  Module_3          8000
# 19   model_0_8-100-21-RMSp-trd  32-64-128-256-512  Module_3          8000
# 20   model_1_8-100-100-sgd-trd  model_0 + Dropout  Module_4          8000
# 21     model_1_8-30-32-sgd-trd  model_0 + Dropout  Module_4          8000
# 22     model_1_8-30-40-sgd-trd  model_0 + Dropout  Module_4          8000
# 23     model_1_8-30-9-adlt-trd  model_0 + Dropout  Module_4          8000
# 24   model_1_8-100-30-RMSp-trd  model_0 + Dropout  Module_4          8000
# 25   model_2_8-100-100-sgd-trd  model_0 + reg. L2  Module_5          8000
# 26     model_2_8-30-40-sgd-trd  model_0 + reg. L2  Module_5          8000
# 27     model_2_8-30-9-adlt-trd  model_0 + reg. L2  Module_5          8000
# 28    model_2_8-30-20-adlt-trd  model_0 + reg. L2  Module_5          8000
# 29   model_2_8-100-25-RMSp-trd  model_0 + reg. L2  Module_5          8000
# 30   model_3_8-100-100-sgd-trd  32+64+128+128+256  Module_6          8000
# 31  model_3_8-100-100-adlt-trd  32+64+128+128+256  Module_6          8000
# 32   model_3_8-100-20-adlt-trd  32+64+128+128+256  Module_6          8000
# 33   model_3_8-100-30-RMSp-trd  32+64+128+128+256  Module_6          8000
#
#     batch_size  epochs         optimizer    acc      remarks
# 1          100     150               sgd  0.924  100-overfit
# 2          100     150          adadelta  0.918   20-overfit
# 3          100     120           rmsprop  0.924   15-overfit
# 4          100     100  RMSprop(lr=1e-4)  0.932   20-overfit
# 5          100     100               sgd  0.904   no overfit
# 6           30     100               sgd  0.918   40-overfit
# 7           15      40               sgd  0.920   15-overfit
# 8           15      25  RMSprop(lr=1e-4)  0.882    6-overfit
# 9           15      15           rmsprop  0.926    4-overfit
# 10         100     150               sgd  0.522   80-overfit
# 11         100     100               sgd  0.934          ok.
# 12          30     100               sgd  0.522   30-overfit
# 13          30      32               sgd  0.918           ok
# 14          30      30          adadelta  0.940    7-overfit
# 15          30       8          adadelta  0.938           ok
# 16         100      30          adadelta  0.928   13-overfit
# 17          30       8  RMSprop(lr=1e-4)  0.856       not ok
# 18         100      30  RMSprop(lr=1e-4)  0.940   20-overfit
# 19         100      21  RMSprop(lr=1e-4)  0.890   17-overfit
# 20         100     100               sgd  0.930   80-overfit
# 21          30      32               sgd  0.934          ok.
# 22          30      40               sgd  0.922   30-overfit
# 23          30       9          adadelta  0.922    7-overfit
# 24         100      30  RMSprop(lr=1e-4)  0.942   20-overfit
# 25         100     100               sgd  0.900   80-overfit
# 26          30      40               sgd  0.904   30-overfit
# 27          30       9          adadelta  0.898           ok
# 28          30      20          adadelta  0.930   12-overfit
# 29         100      25  RMSprop(lr=1e-4)  0.872           ok
# 30         100     100               sgd  0.936           ok
# 31         100     100          adadelta  0.942   15-overfit
# 32         100      20          adadelta  0.946   12-overfit
# 33         100      30  RMSprop(lr=1e-4)  0.932           ok
