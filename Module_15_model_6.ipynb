# %% [markdown]
# # model_6 - configuration & training - reduced own model
# - one GPU training

# %%
# Choosing of single GPU - has to be done before tensorflow import:
# All the notebooks used earlier with that option have to be closed or to have to have restarted the kernel
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="2"        # Will use only single GPU device

# %%
import numpy as np
import pandas as pd
import my_functions
import keras
from keras import layers
from keras import models
from keras import Model
from keras import optimizers
from keras import regularizers
import warnings
import tensorflow as tf
warnings.filterwarnings('ignore')
tf.logging.set_verbosity(tf.logging.ERROR)
# Out:
# Using TensorFlow backend.
# /home/artur/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/artur/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/artur/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/artur/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/artur/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/artur/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ## 1. New model configuration

# %% [markdown]
# ### 1.1 New convolutional base
# - Available models:

# %%
# %%bash
# ls ./Models
# Out:
# classifier_0.h5
# classifier_1.h5
# classifier_2.h5
# classifier_3.h5
# classifier_4.h5
# conv_base_0.h5
# conv_base_1.h5
# conv_base_2.h5
# conv_base_3.h5
# model_0_0-100-100-RMSp-trd.h5
# model_0_0-100-100-sgd-trd.h5
# model_0_0-100-120-rmsp-trd.h5
# model_0_0-100-150-adlt-trd.h5
# model_0_0-100-150-sgd-trd.h5
# model_0_0-15-15-rmsp-trd.h5
# model_0_0-15-25-RMSp-trd.h5
# model_0_0-15-40-sgd-trd.h5
# model_0_0-30-100-sgd-trd.h5
# model_0_8-100-100-sgd-trd.h5
# model_0_8-100-150-sgd-trd.h5
# model_0_8-100-21-RMSp-trd.h5
# model_0_8-100-30-adlt-trd.h5
# model_0_8-100-30-RMSp-trd.h5
# model_0_8-30-100-sgd-trd.h5
# model_0_8-30-30-adlt-trd.h5
# model_0_8-30-32-sgd-trd.h5
# model_0_8-30-8-adlt-trd.h5
# model_0_8-30-8-RMSp-trd.h5
# model_0.h5
# model_1_8-100-100-sgd-trd.h5
# model_1_8-100-30-RMSp-trd.h5
# model_1_8-30-32-sgd-trd.h5
# model_1_8-30-40-sgd-trd.h5
# model_1_8-30-9-adlt-trd.h5
# model_1.h5
# model_2_8-100-100-sgd-trd.h5
# model_2_8-100-25-RMSp-trd.h5
# model_2_8-30-20-adlt-trd.h5
# model_2_8-30-40-sgd-trd.h5
# model_2_8-30-9-adlt-trd.h5
# model_2.h5
# model_3_8-100-100-adlt-trd.h5
# model_3_8-100-100-sgd-trd.h5
# model_3_8-100-20-adlt-trd.h5
# model_3_8-100-30-RMSp-trd.h5
# model_3.h5
# model_4_8-100-100-sgd-trd.h5
# model_4_8-100-20-adlt-trd.h5
# model_4_8-100-30-RMSp-trd.h5
# model_4_8-100-40-RMSp-trd.h5
# model_4.h5
# model_5_8-100-25-RMSp-trd.h5
# model_5_8-100-50-sgd-trd.h5
# model_5_8-100-70-sgd-trd.h5

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(96, 96, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.name = 'conv_base_4'
model.summary()
model.save('./Models/conv_base_4.h5')
# Out:
# Model: "conv_base_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 32)        896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# =================================================================
# Total params: 240,832
# Trainable params: 240,832
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 1.2 Classifier modification

# %%
classifier_5 = models.Sequential()
classifier_5.add(layers.Dense(512, activation='relu', input_dim=4*4*128))
classifier_5.add(layers.Dense(2, activation='sigmoid'))
classifier_5.name = 'classifier_5'
classifier_5.summary()
classifier_5.save('./Models/classifier_5.h5')
# Out:
# Model: "classifier_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 1,050,114
# Trainable params: 1,050,114
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 1.3 model_6 aggregation

# %%
conv_base_4 = keras.models.load_model('./Models/conv_base_4.h5')
classifier_5 = keras.models.load_model('./Models/classifier_5.h5')

model_6 = models.Sequential()
model_6.add(model)
model_6.add(layers.Flatten())
model_6.add(classifier_5)
model_6.name = 'model_6'
model_6.summary()
model_6.save('./Models/model_6.h5') # not trained
# Out:
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_base_4 (Sequential)     (None, 4, 4, 128)         240832
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# classifier_5 (Sequential)    (None, 2)                 1050114
# =================================================================
# Total params: 1,290,946
# Trainable params: 1,290,946
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 2. Data loading and transformation
# - Available data:

# %%
# %%bash
# ls ./Used_data
# Out:
# TEST_IMAGES.npy
# TEST_LABELS.npy
# TRAIN_IMAGES.npy
# TRAIN_LABELS.npy
# TRAIN_X_EXTD.npy
# TRAIN_Y_EXTD.npy
# VALID_IMAGES.npy
# VALID_LABELS.npy

# %%
# Loads and transforms 'Used data' to CNN training

train_x_name = 'TRAIN_X_EXTD.npy'
train_y_name = 'TRAIN_Y_EXTD.npy'

TRAIN_X, VALID_X, TEST_X, TRAIN_Y, VALID_Y, TEST_Y = my_functions.data_conversion(train_x_name, train_y_name)
# Out:
# LOADED DATA (before conversion):
#   set name              shape  dtype       data sight
# 0  TRAIN_X  (8000, 96, 96, 3)  uint8     [87, 73, 37]
# 1  TRAIN_Y            (8000,)  uint8                2
# 2  VALID_X   (500, 96, 96, 3)  uint8  [204, 205, 210]
# 3  VALID_Y             (500,)  uint8                1
# 4   TEST_X   (500, 96, 96, 3)  uint8  [132, 167, 203]
# 5   TEST_Y             (500,)  uint8                1
#
# DATA FOR TRAINING (after conversion):
#   set name              shape    dtype                            data sight
# 0  TRAIN_X  (8000, 96, 96, 3)  float32  [0.34117648, 0.28627452, 0.14509805]
# 1  TRAIN_Y          (8000, 2)  float32                            [0.0, 1.0]
# 2  VALID_X   (500, 96, 96, 3)  float32           [0.8, 0.8039216, 0.8235294]
# 3  VALID_Y           (500, 2)  float32                            [1.0, 0.0]
# 4   TEST_X   (500, 96, 96, 3)  float32     [0.5176471, 0.654902, 0.79607844]
# 5   TEST_Y           (500, 2)  float32                            [1.0, 0.0]

# %% [markdown]
# ## 3. Model training
#
# For the training the models without 'trd' have to be choosen,
# models with 'trd' are trained already
#
# - Available models to choice:

# %%
# %%bash
# ls ./Models
# Out:
# classifier_0.h5
# classifier_1.h5
# classifier_2.h5
# classifier_3.h5
# classifier_4.h5
# classifier_5.h5
# conv_base_0.h5
# conv_base_1.h5
# conv_base_2.h5
# conv_base_3.h5
# conv_base_4.h5
# model_0_0-100-100-RMSp-trd.h5
# model_0_0-100-100-sgd-trd.h5
# model_0_0-100-120-rmsp-trd.h5
# model_0_0-100-150-adlt-trd.h5
# model_0_0-100-150-sgd-trd.h5
# model_0_0-15-15-rmsp-trd.h5
# model_0_0-15-25-RMSp-trd.h5
# model_0_0-15-40-sgd-trd.h5
# model_0_0-30-100-sgd-trd.h5
# model_0_8-100-100-sgd-trd.h5
# model_0_8-100-150-sgd-trd.h5
# model_0_8-100-21-RMSp-trd.h5
# model_0_8-100-30-adlt-trd.h5
# model_0_8-100-30-RMSp-trd.h5
# model_0_8-30-100-sgd-trd.h5
# model_0_8-30-30-adlt-trd.h5
# model_0_8-30-32-sgd-trd.h5
# model_0_8-30-8-adlt-trd.h5
# model_0_8-30-8-RMSp-trd.h5
# model_0.h5
# model_1_8-100-100-sgd-trd.h5
# model_1_8-100-30-RMSp-trd.h5
# model_1_8-30-32-sgd-trd.h5
# model_1_8-30-40-sgd-trd.h5
# model_1_8-30-9-adlt-trd.h5
# model_1.h5
# model_2_8-100-100-sgd-trd.h5
# model_2_8-100-25-RMSp-trd.h5
# model_2_8-30-20-adlt-trd.h5
# model_2_8-30-40-sgd-trd.h5
# model_2_8-30-9-adlt-trd.h5
# model_2.h5
# model_3_8-100-100-adlt-trd.h5
# model_3_8-100-100-sgd-trd.h5
# model_3_8-100-20-adlt-trd.h5
# model_3_8-100-30-RMSp-trd.h5
# model_3.h5
# model_4_8-100-100-sgd-trd.h5
# model_4_8-100-20-adlt-trd.h5
# model_4_8-100-30-RMSp-trd.h5
# model_4_8-100-40-RMSp-trd.h5
# model_4.h5
# model_5_8-100-25-RMSp-trd.h5
# model_5_8-100-50-sgd-trd.h5
# model_5_8-100-70-sgd-trd.h5
# model_6.h5

# %% [markdown]
# #### Existing results overview:

# %%
# Results overview (function no. 8)

summary = pd.DataFrame(my_functions.results_preview()) 
summary.index = summary.index + 1
summary
# Out:
#                     model_name     model_description   notebook  dataset_size  \
# 1    model_0_0-100-150-sgd-trd     32-64-128-256-512   Module_1          1600
# 2   model_0_0-100-150-adlt-trd     32-64-128-256-512   Module_1          1600
# 3   model_0_0-100-120-rmsp-trd     32-64-128-256-512   Module_1          1600
# 4   model_0_0-100-100-RMSp-trd     32-64-128-256-512   Module_1          1600
# 5    model_0_0-100-100-sgd-trd     32-64-128-256-512   Module_1          1600
# 6     model_0_0-30-100-sgd-trd     32-64-128-256-512   Module_1          1600
# 7      model_0_0-15-40-sgd-trd     32-64-128-256-512   Module_1          1600
# 8     model_0_0-15-25-RMSp-trd     32-64-128-256-512   Module_1          1600
# 9     model_0_0-15-15-rmsp-trd     32-64-128-256-512   Module_1          1600
# 10   model_0_8-100-150-sgd-trd     32-64-128-256-512   Module_3          8000
# 11   model_0_8-100-100-sgd-trd     32-64-128-256-512   Module_3          8000
# 12    model_0_8-30-100-sgd-trd     32-64-128-256-512   Module_3          8000
# 13     model_0_8-30-32-sgd-trd     32-64-128-256-512   Module_3          8000
# 14    model_0_8-30-30-adlt-trd     32-64-128-256-512   Module_3          8000
# 15     model_0_8-30-8-adlt-trd     32-64-128-256-512   Module_3          8000
# 16   model_0_8-100-30-adlt-trd     32-64-128-256-512   Module_3          8000
# 17     model_0_8-30-8-RMSp-trd     32-64-128-256-512   Module_3          8000
# 18   model_0_8-100-30-RMSp-trd     32-64-128-256-512   Module_3          8000
# 19   model_0_8-100-21-RMSp-trd     32-64-128-256-512   Module_3          8000
# 20   model_1_8-100-100-sgd-trd     model_0 + Dropout   Module_4          8000
# 21     model_1_8-30-32-sgd-trd     model_0 + Dropout   Module_4          8000
# 22     model_1_8-30-40-sgd-trd     model_0 + Dropout   Module_4          8000
# 23     model_1_8-30-9-adlt-trd     model_0 + Dropout   Module_4          8000
# 24   model_1_8-100-30-RMSp-trd     model_0 + Dropout   Module_4          8000
# 25   model_2_8-100-100-sgd-trd     model_0 + reg. L2   Module_5          8000
# 26     model_2_8-30-40-sgd-trd     model_0 + reg. L2   Module_5          8000
# 27     model_2_8-30-9-adlt-trd     model_0 + reg. L2   Module_5          8000
# 28    model_2_8-30-20-adlt-trd     model_0 + reg. L2   Module_5          8000
# 29   model_2_8-100-25-RMSp-trd     model_0 + reg. L2   Module_5          8000
# 30   model_3_8-100-100-sgd-trd     32+64+128+128+256   Module_6          8000
# 31  model_3_8-100-100-adlt-trd     32+64+128+128+256   Module_6          8000
# 32   model_3_8-100-20-adlt-trd     32+64+128+128+256   Module_6          8000
# 33   model_3_8-100-30-RMSp-trd     32+64+128+128+256   Module_6          8000
# 34   model_4_8-100-100-sgd-trd     32+64+128+128+128   Module_7          8000
# 35   model_4_8-100-20-adlt-trd     32+64+128+128+128   Module_7          8000
# 36   model_4_8-100-30-RMSp-trd     32+64+128+128+128   Module_7          8000
# 37   model_4_8-100-40-RMSp-trd     32+64+128+128+128   Module_7          8000
# 38    model_5_8-100-50-sgd-trd  vgg16 conv base None  Module_12          8000
# 39    model_5_8-100-70-sgd-trd  vgg16 conv base None  Module_13          8000
# 40   model_5_8-100-25-RMSp-trd  vgg16 conv base None  Module_14          8000
#
#     batch_size  epochs         optimizer    acc      remarks
# 1          100     150               sgd  0.924  100-overfit
# 2          100     150          adadelta  0.918   20-overfit
# 3          100     120           rmsprop  0.924   15-overfit
# 4          100     100  RMSprop(lr=1e-4)  0.932   20-overfit
# 5          100     100               sgd  0.904   no overfit
# 6           30     100               sgd  0.918   40-overfit
# 7           15      40               sgd  0.920   15-overfit
# 8           15      25  RMSprop(lr=1e-4)  0.882    6-overfit
# 9           15      15           rmsprop  0.926    4-overfit
# 10         100     150               sgd  0.522   80-overfit
# 11         100     100               sgd  0.934          ok.
# 12          30     100               sgd  0.522   30-overfit
# 13          30      32               sgd  0.918           ok
# 14          30      30          adadelta  0.940    7-overfit
# 15          30       8          adadelta  0.938           ok
# 16         100      30          adadelta  0.928   13-overfit
# 17          30       8  RMSprop(lr=1e-4)  0.856       not ok
# 18         100      30  RMSprop(lr=1e-4)  0.940   20-overfit
# 19         100      21  RMSprop(lr=1e-4)  0.890   17-overfit
# 20         100     100               sgd  0.930   80-overfit
# 21          30      32               sgd  0.934          ok.
# 22          30      40               sgd  0.922   30-overfit
# 23          30       9          adadelta  0.922    7-overfit
# 24         100      30  RMSprop(lr=1e-4)  0.942   20-overfit
# 25         100     100               sgd  0.900   80-overfit
# 26          30      40               sgd  0.904   30-overfit
# 27          30       9          adadelta  0.898           ok
# 28          30      20          adadelta  0.930   12-overfit
# 29         100      25  RMSprop(lr=1e-4)  0.872           ok
# 30         100     100               sgd  0.936           ok
# 31         100     100          adadelta  0.942   15-overfit
# 32         100      20          adadelta  0.946   12-overfit
# 33         100      30  RMSprop(lr=1e-4)  0.932           ok
# 34         100     100               sgd  0.924           ok
# 35         100      20          adadelta  0.926   13-overfit
# 36         100      30  RMSprop(lr=1e-4)  0.946           ok
# 37         100      40  RMSprop(lr=1e-4)  0.946           ok
# 38         100      50               sgd  0.904       val>tr
# 39         100      70               sgd  0.922     underfit
# 40         100      25  RMSprop(lr=1e-4)  0.910   10-overfit

# %% [markdown]
# ### 3.1 model_6 & optimizer sgd:

# %%
model = keras.models.load_model('./Models/model_6.h5') # not trained model!

epochs = 50
batch_size = 100
optimizer = 'sgd'
optimizer_name = optimizer
trd_model_name = 'model_6_8-100-50-sgd-trd' # model after training, name without file extension !
notebook = 'Module_15'
model_descr = '32+64+128+128'
dataset_size = len(TRAIN_X)

# Training (function no. 23)

acc = my_functions.train_and_chart(batch_size, epochs, model, optimizer, 
                                   TRAIN_X, TRAIN_Y, VALID_X, VALID_Y, trd_model_name)
del(model)
# Out:
# Train on 8000 samples, validate on 500 samples
# Epoch 1/50
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.6885 - acc: 0.5024 - val_loss: 0.6811 - val_acc: 0.5920
# Epoch 2/50
# 8000/8000 [==============================] - 6s 801us/step - loss: 0.6787 - acc: 0.6177 - val_loss: 0.6650 - val_acc: 0.6760
# Epoch 3/50
# 8000/8000 [==============================] - 6s 804us/step - loss: 0.6597 - acc: 0.6860 - val_loss: 0.6329 - val_acc: 0.7840
# Epoch 4/50
# 8000/8000 [==============================] - 6s 798us/step - loss: 0.6148 - acc: 0.7184 - val_loss: 0.5467 - val_acc: 0.7800
# Epoch 5/50
# 8000/8000 [==============================] - 6s 804us/step - loss: 0.5686 - acc: 0.7139 - val_loss: 0.5132 - val_acc: 0.7660
# Epoch 6/50
# 8000/8000 [==============================] - 6s 795us/step - loss: 0.5511 - acc: 0.7280 - val_loss: 0.5037 - val_acc: 0.7460
# Epoch 7/50
# 8000/8000 [==============================] - 6s 799us/step - loss: 0.5332 - acc: 0.7420 - val_loss: 0.4612 - val_acc: 0.7900
# Epoch 8/50
# 8000/8000 [==============================] - 6s 805us/step - loss: 0.5285 - acc: 0.7486 - val_loss: 0.4326 - val_acc: 0.8360
# Epoch 9/50
# 8000/8000 [==============================] - 6s 804us/step - loss: 0.5162 - acc: 0.7582 - val_loss: 0.4216 - val_acc: 0.8460
# Epoch 10/50
# 8000/8000 [==============================] - 6s 794us/step - loss: 0.5008 - acc: 0.7673 - val_loss: 0.4098 - val_acc: 0.8200
# Epoch 11/50
# 8000/8000 [==============================] - 6s 801us/step - loss: 0.4941 - acc: 0.7675 - val_loss: 0.4355 - val_acc: 0.7960
# Epoch 12/50
# 8000/8000 [==============================] - 6s 781us/step - loss: 0.4736 - acc: 0.7832 - val_loss: 0.3611 - val_acc: 0.8660
# Epoch 13/50
# 8000/8000 [==============================] - 6s 801us/step - loss: 0.4549 - acc: 0.7943 - val_loss: 0.3618 - val_acc: 0.8420
# 8000/8000 [==============================] - 6s 794us/step - loss: 0.3087 - acc: 0.8711 - val_loss: 0.2134 - val_acc: 0.9180
# Epoch 37/50
# 8000/8000 [==============================] - 6s 797us/step - loss: 0.3047 - acc: 0.8748 - val_loss: 0.2126 - val_acc: 0.9140
# Epoch 38/50
# 8000/8000 [==============================] - 6s 777us/step - loss: 0.3074 - acc: 0.8750 - val_loss: 0.2151 - val_acc: 0.9180
# Epoch 39/50
# 8000/8000 [==============================] - 6s 799us/step - loss: 0.2969 - acc: 0.8789 - val_loss: 0.2115 - val_acc: 0.9200
# Epoch 40/50
# 8000/8000 [==============================] - 6s 783us/step - loss: 0.2924 - acc: 0.8790 - val_loss: 0.2065 - val_acc: 0.9260
# Epoch 41/50
# 8000/8000 [==============================] - 6s 797us/step - loss: 0.2977 - acc: 0.8789 - val_loss: 0.2342 - val_acc: 0.9140
# Epoch 42/50
# 8000/8000 [==============================] - 6s 787us/step - loss: 0.2988 - acc: 0.8754 - val_loss: 0.2455 - val_acc: 0.9000
# Epoch 43/50
# 8000/8000 [==============================] - 6s 798us/step - loss: 0.2891 - acc: 0.8820 - val_loss: 0.2276 - val_acc: 0.9140
# Epoch 44/50
# 8000/8000 [==============================] - 6s 778us/step - loss: 0.2858 - acc: 0.8819 - val_loss: 0.2065 - val_acc: 0.9240
# Epoch 45/50
# 8000/8000 [==============================] - 6s 797us/step - loss: 0.2895 - acc: 0.8800 - val_loss: 0.3958 - val_acc: 0.8200
# Epoch 46/50
# 8000/8000 [==============================] - 6s 789us/step - loss: 0.2763 - acc: 0.8861 - val_loss: 0.2022 - val_acc: 0.9280
# Epoch 47/50
# 8000/8000 [==============================] - 6s 790us/step - loss: 0.2758 - acc: 0.8884 - val_loss: 0.2018 - val_acc: 0.9280
# Epoch 48/50
# 8000/8000 [==============================] - 6s 784us/step - loss: 0.2731 - acc: 0.8892 - val_loss: 0.2376 - val_acc: 0.9100
# Epoch 49/50
# 8000/8000 [==============================] - 6s 792us/step - loss: 0.2714 - acc: 0.8898 - val_loss: 0.1969 - val_acc: 0.9280
# Epoch 50/50
# 8000/8000 [==============================] - 6s 789us/step - loss: 0.2679 - acc: 0.8906 - val_loss: 0.2154 - val_acc: 0.9140
# 500/500 [==============================] - 0s 656us/step
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# Validation accuracy 0.9139999747276306
#
# Execution time:   0:05:21.207002

# %%
remark = 'val>>tr'

# Results saving (function no. 6)

my_functions.results_update(trd_model_name, model_descr, notebook, dataset_size, 
                            batch_size, epochs, optimizer_name, acc, remark)

# Results overview (function no. 8)

summary = pd.DataFrame(my_functions.results_preview()) 
summary.index = summary.index + 1
summary
# Out:
#                     model_name     model_description   notebook  dataset_size  \
# 1    model_0_0-100-150-sgd-trd     32-64-128-256-512   Module_1          1600
# 2   model_0_0-100-150-adlt-trd     32-64-128-256-512   Module_1          1600
# 3   model_0_0-100-120-rmsp-trd     32-64-128-256-512   Module_1          1600
# 4   model_0_0-100-100-RMSp-trd     32-64-128-256-512   Module_1          1600
# 5    model_0_0-100-100-sgd-trd     32-64-128-256-512   Module_1          1600
# 6     model_0_0-30-100-sgd-trd     32-64-128-256-512   Module_1          1600
# 7      model_0_0-15-40-sgd-trd     32-64-128-256-512   Module_1          1600
# 8     model_0_0-15-25-RMSp-trd     32-64-128-256-512   Module_1          1600
# 9     model_0_0-15-15-rmsp-trd     32-64-128-256-512   Module_1          1600
# 10   model_0_8-100-150-sgd-trd     32-64-128-256-512   Module_3          8000
# 11   model_0_8-100-100-sgd-trd     32-64-128-256-512   Module_3          8000
# 12    model_0_8-30-100-sgd-trd     32-64-128-256-512   Module_3          8000
# 13     model_0_8-30-32-sgd-trd     32-64-128-256-512   Module_3          8000
# 14    model_0_8-30-30-adlt-trd     32-64-128-256-512   Module_3          8000
# 15     model_0_8-30-8-adlt-trd     32-64-128-256-512   Module_3          8000
# 16   model_0_8-100-30-adlt-trd     32-64-128-256-512   Module_3          8000
# 17     model_0_8-30-8-RMSp-trd     32-64-128-256-512   Module_3          8000
# 18   model_0_8-100-30-RMSp-trd     32-64-128-256-512   Module_3          8000
# 19   model_0_8-100-21-RMSp-trd     32-64-128-256-512   Module_3          8000
# 20   model_1_8-100-100-sgd-trd     model_0 + Dropout   Module_4          8000
# 21     model_1_8-30-32-sgd-trd     model_0 + Dropout   Module_4          8000
# 22     model_1_8-30-40-sgd-trd     model_0 + Dropout   Module_4          8000
# 23     model_1_8-30-9-adlt-trd     model_0 + Dropout   Module_4          8000
# 24   model_1_8-100-30-RMSp-trd     model_0 + Dropout   Module_4          8000
# 25   model_2_8-100-100-sgd-trd     model_0 + reg. L2   Module_5          8000
# 26     model_2_8-30-40-sgd-trd     model_0 + reg. L2   Module_5          8000
# 27     model_2_8-30-9-adlt-trd     model_0 + reg. L2   Module_5          8000
# 28    model_2_8-30-20-adlt-trd     model_0 + reg. L2   Module_5          8000
# 29   model_2_8-100-25-RMSp-trd     model_0 + reg. L2   Module_5          8000
# 30   model_3_8-100-100-sgd-trd     32+64+128+128+256   Module_6          8000
# 31  model_3_8-100-100-adlt-trd     32+64+128+128+256   Module_6          8000
# 32   model_3_8-100-20-adlt-trd     32+64+128+128+256   Module_6          8000
# 33   model_3_8-100-30-RMSp-trd     32+64+128+128+256   Module_6          8000
# 34   model_4_8-100-100-sgd-trd     32+64+128+128+128   Module_7          8000
# 35   model_4_8-100-20-adlt-trd     32+64+128+128+128   Module_7          8000
# 36   model_4_8-100-30-RMSp-trd     32+64+128+128+128   Module_7          8000
# 37   model_4_8-100-40-RMSp-trd     32+64+128+128+128   Module_7          8000
# 38    model_5_8-100-50-sgd-trd  vgg16 conv base None  Module_12          8000
# 39    model_5_8-100-70-sgd-trd  vgg16 conv base None  Module_13          8000
# 40   model_5_8-100-25-RMSp-trd  vgg16 conv base None  Module_14          8000
# 41    model_6_8-100-50-sgd-trd         32+64+128+128  Module_15          8000
#
#     batch_size  epochs         optimizer    acc      remarks
# 1          100     150               sgd  0.924  100-overfit
# 2          100     150          adadelta  0.918   20-overfit
# 3          100     120           rmsprop  0.924   15-overfit
# 4          100     100  RMSprop(lr=1e-4)  0.932   20-overfit
# 5          100     100               sgd  0.904   no overfit
# 6           30     100               sgd  0.918   40-overfit
# 7           15      40               sgd  0.920   15-overfit
# 8           15      25  RMSprop(lr=1e-4)  0.882    6-overfit
# 9           15      15           rmsprop  0.926    4-overfit
# 10         100     150               sgd  0.522   80-overfit
# 11         100     100               sgd  0.934          ok.
# 12          30     100               sgd  0.522   30-overfit
# 13          30      32               sgd  0.918           ok
# 14          30      30          adadelta  0.940    7-overfit
# 15          30       8          adadelta  0.938           ok
# 16         100      30          adadelta  0.928   13-overfit
# 17          30       8  RMSprop(lr=1e-4)  0.856       not ok
# 18         100      30  RMSprop(lr=1e-4)  0.940   20-overfit
# 19         100      21  RMSprop(lr=1e-4)  0.890   17-overfit
# 20         100     100               sgd  0.930   80-overfit
# 21          30      32               sgd  0.934          ok.
# 22          30      40               sgd  0.922   30-overfit
# 23          30       9          adadelta  0.922    7-overfit
# 24         100      30  RMSprop(lr=1e-4)  0.942   20-overfit
# 25         100     100               sgd  0.900   80-overfit
# 26          30      40               sgd  0.904   30-overfit
# 27          30       9          adadelta  0.898           ok
# 28          30      20          adadelta  0.930   12-overfit
# 29         100      25  RMSprop(lr=1e-4)  0.872           ok
# 30         100     100               sgd  0.936           ok
# 31         100     100          adadelta  0.942   15-overfit
# 32         100      20          adadelta  0.946   12-overfit
# 33         100      30  RMSprop(lr=1e-4)  0.932           ok
# 34         100     100               sgd  0.924           ok
# 35         100      20          adadelta  0.926   13-overfit
# 36         100      30  RMSprop(lr=1e-4)  0.946           ok
# 37         100      40  RMSprop(lr=1e-4)  0.946           ok
# 38         100      50               sgd  0.904       val>tr
# 39         100      70               sgd  0.922     underfit
# 40         100      25  RMSprop(lr=1e-4)  0.910   10-overfit
# 41         100      50               sgd  0.914      val>>tr

# %% [markdown]
# ### 3.2 model_6 & optimizer sgd:

# %%
model = keras.models.load_model('./Models/model_6.h5') # not trained model!

epochs = 100
batch_size = 100
optimizer = 'sgd'
optimizer_name = optimizer
trd_model_name = 'model_6_8-100-100-sgd-trd' # model after training, name without file extension !
notebook = 'Module_15'
model_descr = '32+64+128+128'
dataset_size = len(TRAIN_X)

# Training (function no. 23)

acc = my_functions.train_and_chart(batch_size, epochs, model, optimizer, 
                                   TRAIN_X, TRAIN_Y, VALID_X, VALID_Y, trd_model_name)
del(model)
# Out:
# Train on 8000 samples, validate on 500 samples
# Epoch 1/100
# 8000/8000 [==============================] - 7s 862us/step - loss: 0.6886 - acc: 0.5069 - val_loss: 0.6801 - val_acc: 0.5360
# Epoch 2/100
# 8000/8000 [==============================] - 6s 806us/step - loss: 0.6787 - acc: 0.6020 - val_loss: 0.6646 - val_acc: 0.6580
# Epoch 3/100
# 8000/8000 [==============================] - 6s 800us/step - loss: 0.6600 - acc: 0.6844 - val_loss: 0.6309 - val_acc: 0.7640
# 8000/8000 [==============================] - 6s 795us/step - loss: 0.1341 - acc: 0.9548 - val_loss: 0.2295 - val_acc: 0.9260
# Epoch 97/100
# 8000/8000 [==============================] - 6s 794us/step - loss: 0.1187 - acc: 0.9566 - val_loss: 0.2026 - val_acc: 0.9320
# Epoch 98/100
# 8000/8000 [==============================] - 6s 800us/step - loss: 0.0845 - acc: 0.9722 - val_loss: 0.2187 - val_acc: 0.9300
# Epoch 99/100
# 8000/8000 [==============================] - 6s 795us/step - loss: 0.0927 - acc: 0.9671 - val_loss: 0.2192 - val_acc: 0.9320
# Epoch 100/100
# 8000/8000 [==============================] - 6s 793us/step - loss: 0.0646 - acc: 0.9796 - val_loss: 0.2244 - val_acc: 0.9320
# 500/500 [==============================] - 0s 472us/step
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# Validation accuracy 0.9319999814033508
#
# Execution time:   0:10:38.828780

# %%
remark = '80-overfit'

# Results saving (function no. 6)

my_functions.results_update(trd_model_name, model_descr, notebook, dataset_size, 
                            batch_size, epochs, optimizer_name, acc, remark)

# Results overview (function no. 8)

summary = pd.DataFrame(my_functions.results_preview()) 
summary.index = summary.index + 1
summary
# Out:
#                     model_name     model_description   notebook  dataset_size  \
# 1    model_0_0-100-150-sgd-trd     32-64-128-256-512   Module_1          1600
# 2   model_0_0-100-150-adlt-trd     32-64-128-256-512   Module_1          1600
# 3   model_0_0-100-120-rmsp-trd     32-64-128-256-512   Module_1          1600
# 4   model_0_0-100-100-RMSp-trd     32-64-128-256-512   Module_1          1600
# 5    model_0_0-100-100-sgd-trd     32-64-128-256-512   Module_1          1600
# 6     model_0_0-30-100-sgd-trd     32-64-128-256-512   Module_1          1600
# 7      model_0_0-15-40-sgd-trd     32-64-128-256-512   Module_1          1600
# 8     model_0_0-15-25-RMSp-trd     32-64-128-256-512   Module_1          1600
# 9     model_0_0-15-15-rmsp-trd     32-64-128-256-512   Module_1          1600
# 10   model_0_8-100-150-sgd-trd     32-64-128-256-512   Module_3          8000
# 11   model_0_8-100-100-sgd-trd     32-64-128-256-512   Module_3          8000
# 12    model_0_8-30-100-sgd-trd     32-64-128-256-512   Module_3          8000
# 13     model_0_8-30-32-sgd-trd     32-64-128-256-512   Module_3          8000
# 14    model_0_8-30-30-adlt-trd     32-64-128-256-512   Module_3          8000
# 15     model_0_8-30-8-adlt-trd     32-64-128-256-512   Module_3          8000
# 16   model_0_8-100-30-adlt-trd     32-64-128-256-512   Module_3          8000
# 17     model_0_8-30-8-RMSp-trd     32-64-128-256-512   Module_3          8000
# 18   model_0_8-100-30-RMSp-trd     32-64-128-256-512   Module_3          8000
# 19   model_0_8-100-21-RMSp-trd     32-64-128-256-512   Module_3          8000
# 20   model_1_8-100-100-sgd-trd     model_0 + Dropout   Module_4          8000
# 21     model_1_8-30-32-sgd-trd     model_0 + Dropout   Module_4          8000
# 22     model_1_8-30-40-sgd-trd     model_0 + Dropout   Module_4          8000
# 23     model_1_8-30-9-adlt-trd     model_0 + Dropout   Module_4          8000
# 24   model_1_8-100-30-RMSp-trd     model_0 + Dropout   Module_4          8000
# 25   model_2_8-100-100-sgd-trd     model_0 + reg. L2   Module_5          8000
# 26     model_2_8-30-40-sgd-trd     model_0 + reg. L2   Module_5          8000
# 27     model_2_8-30-9-adlt-trd     model_0 + reg. L2   Module_5          8000
# 28    model_2_8-30-20-adlt-trd     model_0 + reg. L2   Module_5          8000
# 29   model_2_8-100-25-RMSp-trd     model_0 + reg. L2   Module_5          8000
# 30   model_3_8-100-100-sgd-trd     32+64+128+128+256   Module_6          8000
# 31  model_3_8-100-100-adlt-trd     32+64+128+128+256   Module_6          8000
# 32   model_3_8-100-20-adlt-trd     32+64+128+128+256   Module_6          8000
# 33   model_3_8-100-30-RMSp-trd     32+64+128+128+256   Module_6          8000
# 34   model_4_8-100-100-sgd-trd     32+64+128+128+128   Module_7          8000
# 35   model_4_8-100-20-adlt-trd     32+64+128+128+128   Module_7          8000
# 36   model_4_8-100-30-RMSp-trd     32+64+128+128+128   Module_7          8000
# 37   model_4_8-100-40-RMSp-trd     32+64+128+128+128   Module_7          8000
# 38    model_5_8-100-50-sgd-trd  vgg16 conv base None  Module_12          8000
# 39    model_5_8-100-70-sgd-trd  vgg16 conv base None  Module_13          8000
# 40   model_5_8-100-25-RMSp-trd  vgg16 conv base None  Module_14          8000
# 41    model_6_8-100-50-sgd-trd         32+64+128+128  Module_15          8000
# 42   model_6_8-100-100-sgd-trd         32+64+128+128  Module_15          8000
#
#     batch_size  epochs         optimizer    acc      remarks
# 1          100     150               sgd  0.924  100-overfit
# 2          100     150          adadelta  0.918   20-overfit
# 3          100     120           rmsprop  0.924   15-overfit
# 4          100     100  RMSprop(lr=1e-4)  0.932   20-overfit
# 5          100     100               sgd  0.904   no overfit
# 6           30     100               sgd  0.918   40-overfit
# 7           15      40               sgd  0.920   15-overfit
# 8           15      25  RMSprop(lr=1e-4)  0.882    6-overfit
# 9           15      15           rmsprop  0.926    4-overfit
# 10         100     150               sgd  0.522   80-overfit
# 11         100     100               sgd  0.934          ok.
# 12          30     100               sgd  0.522   30-overfit
# 13          30      32               sgd  0.918           ok
# 14          30      30          adadelta  0.940    7-overfit
# 15          30       8          adadelta  0.938           ok
# 16         100      30          adadelta  0.928   13-overfit
# 17          30       8  RMSprop(lr=1e-4)  0.856       not ok
# 18         100      30  RMSprop(lr=1e-4)  0.940   20-overfit
# 19         100      21  RMSprop(lr=1e-4)  0.890   17-overfit
# 20         100     100               sgd  0.930   80-overfit
# 21          30      32               sgd  0.934          ok.
# 22          30      40               sgd  0.922   30-overfit
# 23          30       9          adadelta  0.922    7-overfit
# 24         100      30  RMSprop(lr=1e-4)  0.942   20-overfit
# 25         100     100               sgd  0.900   80-overfit
# 26          30      40               sgd  0.904   30-overfit
# 27          30       9          adadelta  0.898           ok
# 28          30      20          adadelta  0.930   12-overfit
# 29         100      25  RMSprop(lr=1e-4)  0.872           ok
# 30         100     100               sgd  0.936           ok
# 31         100     100          adadelta  0.942   15-overfit
# 32         100      20          adadelta  0.946   12-overfit
# 33         100      30  RMSprop(lr=1e-4)  0.932           ok
# 34         100     100               sgd  0.924           ok
# 35         100      20          adadelta  0.926   13-overfit
# 36         100      30  RMSprop(lr=1e-4)  0.946           ok
# 37         100      40  RMSprop(lr=1e-4)  0.946           ok
# 38         100      50               sgd  0.904       val>tr
# 39         100      70               sgd  0.922     underfit
# 40         100      25  RMSprop(lr=1e-4)  0.910   10-overfit
# 41         100      50               sgd  0.914      val>>tr
# 42         100     100               sgd  0.932   80-overfit

# %% [markdown]
# ### 3.3 model_6 & optimizer adadelta:

# %%
model = keras.models.load_model('./Models/model_6.h5') # not trained model!

epochs = 40
batch_size = 100
optimizer = 'adadelta'
optimizer_name = optimizer
trd_model_name = 'model_6_8-100-40-adlt-trd' # model after training, name without file extension !
notebook = 'Module_15'
model_descr = '32+64+128+128'
dataset_size = len(TRAIN_X)

# Training (function no. 23)

acc = my_functions.train_and_chart(batch_size, epochs, model, optimizer, 
                                   TRAIN_X, TRAIN_Y, VALID_X, VALID_Y, trd_model_name)
del(model)
# Out:
# Train on 8000 samples, validate on 500 samples
# Epoch 1/40
# 8000/8000 [==============================] - 8s 966us/step - loss: 0.6487 - acc: 0.6349 - val_loss: 0.5284 - val_acc: 0.7700
# Epoch 2/40
# 8000/8000 [==============================] - 7s 848us/step - loss: 0.5342 - acc: 0.7454 - val_loss: 0.5043 - val_acc: 0.7660
# Epoch 3/40
# 8000/8000 [==============================] - 7s 844us/step - loss: 0.4299 - acc: 0.8174 - val_loss: 0.5396 - val_acc: 0.7640
# Epoch 4/40
# 8000/8000 [==============================] - 7s 847us/step - loss: 0.3599 - acc: 0.8535 - val_loss: 0.2316 - val_acc: 0.9040
# Epoch 5/40
# 8000/8000 [==============================] - 7s 847us/step - loss: 0.3343 - acc: 0.8568 - val_loss: 0.1875 - val_acc: 0.9160
# Epoch 6/40
# 8000/8000 [==============================] - 7s 842us/step - loss: 0.3076 - acc: 0.8685 - val_loss: 0.2319 - val_acc: 0.9020
# Epoch 7/40
# 8000/8000 [==============================] - 7s 841us/step - loss: 0.2796 - acc: 0.8780 - val_loss: 0.2190 - val_acc: 0.9240
# Epoch 8/40
# 8000/8000 [==============================] - 7s 847us/step - loss: 0.2640 - acc: 0.8917 - val_loss: 0.1950 - val_acc: 0.9260
# Epoch 9/40
# 8000/8000 [==============================] - 7s 849us/step - loss: 0.2366 - acc: 0.9021 - val_loss: 0.1865 - val_acc: 0.9360
# Epoch 10/40
# 8000/8000 [==============================] - 7s 850us/step - loss: 0.2229 - acc: 0.9091 - val_loss: 0.2145 - val_acc: 0.9080
# Epoch 11/40
# 8000/8000 [==============================] - 7s 846us/step - loss: 0.2018 - acc: 0.9139 - val_loss: 0.1838 - val_acc: 0.9300
# Epoch 12/40
# 8000/8000 [==============================] - 7s 855us/step - loss: 0.1903 - acc: 0.9214 - val_loss: 0.1959 - val_acc: 0.9240
# Epoch 13/40
# 8000/8000 [==============================] - 7s 850us/step - loss: 0.1668 - acc: 0.9321 - val_loss: 0.2143 - val_acc: 0.9320
# Epoch 14/40
# 8000/8000 [==============================] - 7s 852us/step - loss: 0.1440 - acc: 0.9419 - val_loss: 0.2677 - val_acc: 0.8860
# Epoch 35/40
# 8000/8000 [==============================] - 7s 855us/step - loss: 7.6911e-04 - acc: 1.0000 - val_loss: 0.4511 - val_acc: 0.9420
# Epoch 36/40
# 8000/8000 [==============================] - 7s 868us/step - loss: 3.0580e-04 - acc: 1.0000 - val_loss: 0.4681 - val_acc: 0.9500
# Epoch 37/40
# 8000/8000 [==============================] - 7s 863us/step - loss: 8.3071e-05 - acc: 1.0000 - val_loss: 0.4743 - val_acc: 0.9520
# Epoch 38/40
# 8000/8000 [==============================] - 7s 847us/step - loss: 0.0790 - acc: 0.9850 - val_loss: 0.3706 - val_acc: 0.9440
# Epoch 39/40
# 8000/8000 [==============================] - 7s 846us/step - loss: 0.0016 - acc: 0.9999 - val_loss: 0.4067 - val_acc: 0.9420
# Epoch 40/40
# 8000/8000 [==============================] - 7s 852us/step - loss: 3.0528e-04 - acc: 1.0000 - val_loss: 0.4424 - val_acc: 0.9520
# 500/500 [==============================] - 0s 479us/step
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# Validation accuracy 0.9520000219345093
#
# Execution time:   0:04:36.154472

# %%
remark = '15-overfit'

# Results saving (function no. 6)

my_functions.results_update(trd_model_name, model_descr, notebook, dataset_size, 
                            batch_size, epochs, optimizer_name, acc, remark)

# Results overview (function no. 8)

summary = pd.DataFrame(my_functions.results_preview()) 
summary.index = summary.index + 1
summary
# Out:
#                     model_name     model_description   notebook  dataset_size  \
# 1    model_0_0-100-150-sgd-trd     32-64-128-256-512   Module_1          1600
# 2   model_0_0-100-150-adlt-trd     32-64-128-256-512   Module_1          1600
# 3   model_0_0-100-120-rmsp-trd     32-64-128-256-512   Module_1          1600
# 4   model_0_0-100-100-RMSp-trd     32-64-128-256-512   Module_1          1600
# 5    model_0_0-100-100-sgd-trd     32-64-128-256-512   Module_1          1600
# 6     model_0_0-30-100-sgd-trd     32-64-128-256-512   Module_1          1600
# 7      model_0_0-15-40-sgd-trd     32-64-128-256-512   Module_1          1600
# 8     model_0_0-15-25-RMSp-trd     32-64-128-256-512   Module_1          1600
# 9     model_0_0-15-15-rmsp-trd     32-64-128-256-512   Module_1          1600
# 10   model_0_8-100-150-sgd-trd     32-64-128-256-512   Module_3          8000
# 11   model_0_8-100-100-sgd-trd     32-64-128-256-512   Module_3          8000
# 12    model_0_8-30-100-sgd-trd     32-64-128-256-512   Module_3          8000
# 13     model_0_8-30-32-sgd-trd     32-64-128-256-512   Module_3          8000
# 14    model_0_8-30-30-adlt-trd     32-64-128-256-512   Module_3          8000
# 15     model_0_8-30-8-adlt-trd     32-64-128-256-512   Module_3          8000
# 16   model_0_8-100-30-adlt-trd     32-64-128-256-512   Module_3          8000
# 17     model_0_8-30-8-RMSp-trd     32-64-128-256-512   Module_3          8000
# 18   model_0_8-100-30-RMSp-trd     32-64-128-256-512   Module_3          8000
# 19   model_0_8-100-21-RMSp-trd     32-64-128-256-512   Module_3          8000
# 20   model_1_8-100-100-sgd-trd     model_0 + Dropout   Module_4          8000
# 21     model_1_8-30-32-sgd-trd     model_0 + Dropout   Module_4          8000
# 22     model_1_8-30-40-sgd-trd     model_0 + Dropout   Module_4          8000
# 23     model_1_8-30-9-adlt-trd     model_0 + Dropout   Module_4          8000
# 24   model_1_8-100-30-RMSp-trd     model_0 + Dropout   Module_4          8000
# 25   model_2_8-100-100-sgd-trd     model_0 + reg. L2   Module_5          8000
# 26     model_2_8-30-40-sgd-trd     model_0 + reg. L2   Module_5          8000
# 27     model_2_8-30-9-adlt-trd     model_0 + reg. L2   Module_5          8000
# 28    model_2_8-30-20-adlt-trd     model_0 + reg. L2   Module_5          8000
# 29   model_2_8-100-25-RMSp-trd     model_0 + reg. L2   Module_5          8000
# 30   model_3_8-100-100-sgd-trd     32+64+128+128+256   Module_6          8000
# 31  model_3_8-100-100-adlt-trd     32+64+128+128+256   Module_6          8000
# 32   model_3_8-100-20-adlt-trd     32+64+128+128+256   Module_6          8000
# 33   model_3_8-100-30-RMSp-trd     32+64+128+128+256   Module_6          8000
# 34   model_4_8-100-100-sgd-trd     32+64+128+128+128   Module_7          8000
# 35   model_4_8-100-20-adlt-trd     32+64+128+128+128   Module_7          8000
# 36   model_4_8-100-30-RMSp-trd     32+64+128+128+128   Module_7          8000
# 37   model_4_8-100-40-RMSp-trd     32+64+128+128+128   Module_7          8000
# 38    model_5_8-100-50-sgd-trd  vgg16 conv base None  Module_12          8000
# 39    model_5_8-100-70-sgd-trd  vgg16 conv base None  Module_13          8000
# 40   model_5_8-100-25-RMSp-trd  vgg16 conv base None  Module_14          8000
# 41    model_6_8-100-50-sgd-trd         32+64+128+128  Module_15          8000
# 42   model_6_8-100-100-sgd-trd         32+64+128+128  Module_15          8000
# 43   model_6_8-100-40-adlt-trd         32+64+128+128  Module_15          8000
#
#     batch_size  epochs         optimizer    acc      remarks
# 1          100     150               sgd  0.924  100-overfit
# 2          100     150          adadelta  0.918   20-overfit
# 3          100     120           rmsprop  0.924   15-overfit
# 4          100     100  RMSprop(lr=1e-4)  0.932   20-overfit
# 5          100     100               sgd  0.904   no overfit
# 6           30     100               sgd  0.918   40-overfit
# 7           15      40               sgd  0.920   15-overfit
# 8           15      25  RMSprop(lr=1e-4)  0.882    6-overfit
# 9           15      15           rmsprop  0.926    4-overfit
# 10         100     150               sgd  0.522   80-overfit
# 11         100     100               sgd  0.934          ok.
# 12          30     100               sgd  0.522   30-overfit
# 13          30      32               sgd  0.918           ok
# 14          30      30          adadelta  0.940    7-overfit
# 15          30       8          adadelta  0.938           ok
# 16         100      30          adadelta  0.928   13-overfit
# 17          30       8  RMSprop(lr=1e-4)  0.856       not ok
# 18         100      30  RMSprop(lr=1e-4)  0.940   20-overfit
# 19         100      21  RMSprop(lr=1e-4)  0.890   17-overfit
# 20         100     100               sgd  0.930   80-overfit
# 21          30      32               sgd  0.934          ok.
# 22          30      40               sgd  0.922   30-overfit
# 23          30       9          adadelta  0.922    7-overfit
# 24         100      30  RMSprop(lr=1e-4)  0.942   20-overfit
# 25         100     100               sgd  0.900   80-overfit
# 26          30      40               sgd  0.904   30-overfit
# 27          30       9          adadelta  0.898           ok
# 28          30      20          adadelta  0.930   12-overfit
# 29         100      25  RMSprop(lr=1e-4)  0.872           ok
# 30         100     100               sgd  0.936           ok
# 31         100     100          adadelta  0.942   15-overfit
# 32         100      20          adadelta  0.946   12-overfit
# 33         100      30  RMSprop(lr=1e-4)  0.932           ok
# 34         100     100               sgd  0.924           ok
# 35         100      20          adadelta  0.926   13-overfit
# 36         100      30  RMSprop(lr=1e-4)  0.946           ok
# 37         100      40  RMSprop(lr=1e-4)  0.946           ok
# 38         100      50               sgd  0.904       val>tr
# 39         100      70               sgd  0.922     underfit
# 40         100      25  RMSprop(lr=1e-4)  0.910   10-overfit
# 41         100      50               sgd  0.914      val>>tr
# 42         100     100               sgd  0.932   80-overfit
# 43         100      40          adadelta  0.952   15-overfit

# %% [markdown]
# ### 3.4 model_6 & optimizer adadelta:

# %%
model = keras.models.load_model('./Models/model_6.h5') # not trained model!

epochs = 17
batch_size = 100
optimizer = 'adadelta'
optimizer_name = optimizer
trd_model_name = 'model_6_8-100-17-adlt-trd' # model after training, name without file extension !
notebook = 'Module_15'
model_descr = '32+64+128+128'
dataset_size = len(TRAIN_X)

# Training (function no. 23)

acc = my_functions.train_and_chart(batch_size, epochs, model, optimizer, 
                                   TRAIN_X, TRAIN_Y, VALID_X, VALID_Y, trd_model_name)
del(model)
# Out:
# Train on 8000 samples, validate on 500 samples
# Epoch 1/17
# 8000/8000 [==============================] - 8s 944us/step - loss: 0.6613 - acc: 0.6350 - val_loss: 0.6412 - val_acc: 0.6480
# Epoch 2/17
# 8000/8000 [==============================] - 7s 841us/step - loss: 0.5411 - acc: 0.7409 - val_loss: 0.4646 - val_acc: 0.7760
# Epoch 3/17
# 8000/8000 [==============================] - 7s 835us/step - loss: 0.4389 - acc: 0.8051 - val_loss: 0.3309 - val_acc: 0.9020
# Epoch 4/17
# 8000/8000 [==============================] - 7s 835us/step - loss: 0.3672 - acc: 0.8469 - val_loss: 0.2332 - val_acc: 0.9000
# Epoch 5/17
# 8000/8000 [==============================] - 7s 849us/step - loss: 0.3259 - acc: 0.8634 - val_loss: 0.2287 - val_acc: 0.9100
# Epoch 6/17
# 8000/8000 [==============================] - 7s 853us/step - loss: 0.3016 - acc: 0.8706 - val_loss: 0.2235 - val_acc: 0.8960
# Epoch 7/17
# 8000/8000 [==============================] - 7s 839us/step - loss: 0.2849 - acc: 0.8788 - val_loss: 0.2001 - val_acc: 0.9240
# Epoch 8/17
# 8000/8000 [==============================] - 7s 834us/step - loss: 0.2582 - acc: 0.8920 - val_loss: 0.1858 - val_acc: 0.9300
# Epoch 9/17
# 8000/8000 [==============================] - 7s 840us/step - loss: 0.2398 - acc: 0.8980 - val_loss: 0.2011 - val_acc: 0.9260
# Epoch 10/17
# 8000/8000 [==============================] - 7s 841us/step - loss: 0.2209 - acc: 0.9091 - val_loss: 0.2048 - val_acc: 0.9200
# Epoch 11/17
# 8000/8000 [==============================] - 7s 834us/step - loss: 0.2088 - acc: 0.9171 - val_loss: 0.1848 - val_acc: 0.9280
# Epoch 12/17
# 8000/8000 [==============================] - 7s 847us/step - loss: 0.1854 - acc: 0.9226 - val_loss: 0.1911 - val_acc: 0.9320
# Epoch 13/17
# 8000/8000 [==============================] - 7s 836us/step - loss: 0.1684 - acc: 0.9304 - val_loss: 0.1858 - val_acc: 0.9260
# Epoch 14/17
# 8000/8000 [==============================] - 7s 843us/step - loss: 0.1550 - acc: 0.9376 - val_loss: 0.1956 - val_acc: 0.9340
# Epoch 15/17
# 8000/8000 [==============================] - 7s 839us/step - loss: 0.1326 - acc: 0.9457 - val_loss: 0.1754 - val_acc: 0.9380
# Epoch 16/17
# 8000/8000 [==============================] - 7s 837us/step - loss: 0.1223 - acc: 0.9494 - val_loss: 0.2441 - val_acc: 0.9160
# Epoch 17/17
# 8000/8000 [==============================] - 7s 842us/step - loss: 0.1052 - acc: 0.9589 - val_loss: 0.2432 - val_acc: 0.9340
# 500/500 [==============================] - 0s 490us/step
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# Validation accuracy 0.9340000152587891
#
# Execution time:   0:01:57.485494

# %%
remark = 'ok'

# Results saving (function no. 6)

my_functions.results_update(trd_model_name, model_descr, notebook, dataset_size, 
                            batch_size, epochs, optimizer_name, acc, remark)

# Results overview (function no. 8)

summary = pd.DataFrame(my_functions.results_preview()) 
summary.index = summary.index + 1
summary
# Out:
#                     model_name     model_description   notebook  dataset_size  \
# 1    model_0_0-100-150-sgd-trd     32-64-128-256-512   Module_1          1600
# 2   model_0_0-100-150-adlt-trd     32-64-128-256-512   Module_1          1600
# 3   model_0_0-100-120-rmsp-trd     32-64-128-256-512   Module_1          1600
# 4   model_0_0-100-100-RMSp-trd     32-64-128-256-512   Module_1          1600
# 5    model_0_0-100-100-sgd-trd     32-64-128-256-512   Module_1          1600
# 6     model_0_0-30-100-sgd-trd     32-64-128-256-512   Module_1          1600
# 7      model_0_0-15-40-sgd-trd     32-64-128-256-512   Module_1          1600
# 8     model_0_0-15-25-RMSp-trd     32-64-128-256-512   Module_1          1600
# 9     model_0_0-15-15-rmsp-trd     32-64-128-256-512   Module_1          1600
# 10   model_0_8-100-150-sgd-trd     32-64-128-256-512   Module_3          8000
# 11   model_0_8-100-100-sgd-trd     32-64-128-256-512   Module_3          8000
# 12    model_0_8-30-100-sgd-trd     32-64-128-256-512   Module_3          8000
# 13     model_0_8-30-32-sgd-trd     32-64-128-256-512   Module_3          8000
# 14    model_0_8-30-30-adlt-trd     32-64-128-256-512   Module_3          8000
# 15     model_0_8-30-8-adlt-trd     32-64-128-256-512   Module_3          8000
# 16   model_0_8-100-30-adlt-trd     32-64-128-256-512   Module_3          8000
# 17     model_0_8-30-8-RMSp-trd     32-64-128-256-512   Module_3          8000
# 18   model_0_8-100-30-RMSp-trd     32-64-128-256-512   Module_3          8000
# 19   model_0_8-100-21-RMSp-trd     32-64-128-256-512   Module_3          8000
# 20   model_1_8-100-100-sgd-trd     model_0 + Dropout   Module_4          8000
# 21     model_1_8-30-32-sgd-trd     model_0 + Dropout   Module_4          8000
# 22     model_1_8-30-40-sgd-trd     model_0 + Dropout   Module_4          8000
# 23     model_1_8-30-9-adlt-trd     model_0 + Dropout   Module_4          8000
# 24   model_1_8-100-30-RMSp-trd     model_0 + Dropout   Module_4          8000
# 25   model_2_8-100-100-sgd-trd     model_0 + reg. L2   Module_5          8000
# 26     model_2_8-30-40-sgd-trd     model_0 + reg. L2   Module_5          8000
# 27     model_2_8-30-9-adlt-trd     model_0 + reg. L2   Module_5          8000
# 28    model_2_8-30-20-adlt-trd     model_0 + reg. L2   Module_5          8000
# 29   model_2_8-100-25-RMSp-trd     model_0 + reg. L2   Module_5          8000
# 30   model_3_8-100-100-sgd-trd     32+64+128+128+256   Module_6          8000
# 31  model_3_8-100-100-adlt-trd     32+64+128+128+256   Module_6          8000
# 32   model_3_8-100-20-adlt-trd     32+64+128+128+256   Module_6          8000
# 33   model_3_8-100-30-RMSp-trd     32+64+128+128+256   Module_6          8000
# 34   model_4_8-100-100-sgd-trd     32+64+128+128+128   Module_7          8000
# 35   model_4_8-100-20-adlt-trd     32+64+128+128+128   Module_7          8000
# 36   model_4_8-100-30-RMSp-trd     32+64+128+128+128   Module_7          8000
# 37   model_4_8-100-40-RMSp-trd     32+64+128+128+128   Module_7          8000
# 38    model_5_8-100-50-sgd-trd  vgg16 conv base None  Module_12          8000
# 39    model_5_8-100-70-sgd-trd  vgg16 conv base None  Module_13          8000
# 40   model_5_8-100-25-RMSp-trd  vgg16 conv base None  Module_14          8000
# 41    model_6_8-100-50-sgd-trd         32+64+128+128  Module_15          8000
# 42   model_6_8-100-100-sgd-trd         32+64+128+128  Module_15          8000
# 43   model_6_8-100-40-adlt-trd         32+64+128+128  Module_15          8000
# 44   model_6_8-100-17-adlt-trd         32+64+128+128  Module_15          8000
#
#     batch_size  epochs         optimizer    acc      remarks
# 1          100     150               sgd  0.924  100-overfit
# 2          100     150          adadelta  0.918   20-overfit
# 3          100     120           rmsprop  0.924   15-overfit
# 4          100     100  RMSprop(lr=1e-4)  0.932   20-overfit
# 5          100     100               sgd  0.904   no overfit
# 6           30     100               sgd  0.918   40-overfit
# 7           15      40               sgd  0.920   15-overfit
# 8           15      25  RMSprop(lr=1e-4)  0.882    6-overfit
# 9           15      15           rmsprop  0.926    4-overfit
# 10         100     150               sgd  0.522   80-overfit
# 11         100     100               sgd  0.934          ok.
# 12          30     100               sgd  0.522   30-overfit
# 13          30      32               sgd  0.918           ok
# 14          30      30          adadelta  0.940    7-overfit
# 15          30       8          adadelta  0.938           ok
# 16         100      30          adadelta  0.928   13-overfit
# 17          30       8  RMSprop(lr=1e-4)  0.856       not ok
# 18         100      30  RMSprop(lr=1e-4)  0.940   20-overfit
# 19         100      21  RMSprop(lr=1e-4)  0.890   17-overfit
# 20         100     100               sgd  0.930   80-overfit
# 21          30      32               sgd  0.934          ok.
# 22          30      40               sgd  0.922   30-overfit
# 23          30       9          adadelta  0.922    7-overfit
# 24         100      30  RMSprop(lr=1e-4)  0.942   20-overfit
# 25         100     100               sgd  0.900   80-overfit
# 26          30      40               sgd  0.904   30-overfit
# 27          30       9          adadelta  0.898           ok
# 28          30      20          adadelta  0.930   12-overfit
# 29         100      25  RMSprop(lr=1e-4)  0.872           ok
# 30         100     100               sgd  0.936           ok
# 31         100     100          adadelta  0.942   15-overfit
# 32         100      20          adadelta  0.946   12-overfit
# 33         100      30  RMSprop(lr=1e-4)  0.932           ok
# 34         100     100               sgd  0.924           ok
# 35         100      20          adadelta  0.926   13-overfit
# 36         100      30  RMSprop(lr=1e-4)  0.946           ok
# 37         100      40  RMSprop(lr=1e-4)  0.946           ok
# 38         100      50               sgd  0.904       val>tr
# 39         100      70               sgd  0.922     underfit
# 40         100      25  RMSprop(lr=1e-4)  0.910   10-overfit
# 41         100      50               sgd  0.914      val>>tr
# 42         100     100               sgd  0.932   80-overfit
# 43         100      40          adadelta  0.952   15-overfit
# 44         100      17          adadelta  0.934           ok

# %% [markdown]
# ### 3.5 model_6 & optimizer RMSprop(lr=1e-4)

# %%
model = keras.models.load_model('./Models/model_6.h5') # not trained model!

epochs = 25
batch_size = 100
optimizer = optimizers.RMSprop(lr=1e-4)
optimizer_name = 'RMSprop(lr=1e-4)'
trd_model_name = 'model_6_8-100-25-RMSp-trd' # model after training, name without file extension !
notebook = 'Module_15'
model_descr = '32+64+128+128'
dataset_size = len(TRAIN_X)

# Training (function no. 23)

acc = my_functions.train_and_chart(batch_size, epochs, model, optimizer, 
                                   TRAIN_X, TRAIN_Y, VALID_X, VALID_Y, trd_model_name)
del(model)
# Out:
# Train on 8000 samples, validate on 500 samples
# Epoch 1/25
# 8000/8000 [==============================] - 7s 912us/step - loss: 0.5743 - acc: 0.7050 - val_loss: 0.4065 - val_acc: 0.8380
# Epoch 2/25
# 8000/8000 [==============================] - 7s 819us/step - loss: 0.4704 - acc: 0.7811 - val_loss: 0.3039 - val_acc: 0.8840
# Epoch 3/25
# 8000/8000 [==============================] - 7s 831us/step - loss: 0.4269 - acc: 0.8067 - val_loss: 0.2756 - val_acc: 0.8700
# Epoch 4/25
# 8000/8000 [==============================] - 7s 832us/step - loss: 0.3995 - acc: 0.8245 - val_loss: 0.2996 - val_acc: 0.8760
# Epoch 5/25
# 8000/8000 [==============================] - 7s 828us/step - loss: 0.3680 - acc: 0.8430 - val_loss: 0.2358 - val_acc: 0.9020
# Epoch 6/25
# 8000/8000 [==============================] - 7s 822us/step - loss: 0.3556 - acc: 0.8431 - val_loss: 0.2723 - val_acc: 0.8840
# Epoch 7/25
# 8000/8000 [==============================] - 7s 822us/step - loss: 0.3379 - acc: 0.8590 - val_loss: 0.2802 - val_acc: 0.8840
# Epoch 8/25
# 8000/8000 [==============================] - 7s 814us/step - loss: 0.3294 - acc: 0.8611 - val_loss: 0.2660 - val_acc: 0.8860
# Epoch 9/25
# 8000/8000 [==============================] - 7s 840us/step - loss: 0.3087 - acc: 0.8692 - val_loss: 0.2049 - val_acc: 0.9140
# Epoch 10/25
# 8000/8000 [==============================] - 7s 829us/step - loss: 0.2968 - acc: 0.8802 - val_loss: 0.2001 - val_acc: 0.9120
# Epoch 11/25
# 8000/8000 [==============================] - 7s 817us/step - loss: 0.2885 - acc: 0.8838 - val_loss: 0.1938 - val_acc: 0.9260
# Epoch 12/25
# 8000/8000 [==============================] - 7s 819us/step - loss: 0.2741 - acc: 0.8850 - val_loss: 0.2073 - val_acc: 0.9220
# Epoch 13/25
# 8000/8000 [==============================] - 7s 829us/step - loss: 0.2610 - acc: 0.8941 - val_loss: 0.3220 - val_acc: 0.8580
# Epoch 14/25
# 8000/8000 [==============================] - 7s 825us/step - loss: 0.2513 - acc: 0.8997 - val_loss: 0.2014 - val_acc: 0.9140
# Epoch 15/25
# 8000/8000 [==============================] - 7s 817us/step - loss: 0.2456 - acc: 0.9038 - val_loss: 0.2029 - val_acc: 0.9260
# Epoch 16/25
# 8000/8000 [==============================] - 7s 814us/step - loss: 0.2345 - acc: 0.9028 - val_loss: 0.2222 - val_acc: 0.9120
# Epoch 17/25
# 8000/8000 [==============================] - 7s 819us/step - loss: 0.2246 - acc: 0.9074 - val_loss: 0.1772 - val_acc: 0.9340
# Epoch 18/25
# 8000/8000 [==============================] - 7s 822us/step - loss: 0.2192 - acc: 0.9115 - val_loss: 0.1759 - val_acc: 0.9280
# Epoch 19/25
# 8000/8000 [==============================] - 7s 818us/step - loss: 0.2077 - acc: 0.9168 - val_loss: 0.1996 - val_acc: 0.9200
# Epoch 20/25
# 8000/8000 [==============================] - 6s 812us/step - loss: 0.2006 - acc: 0.9218 - val_loss: 0.1677 - val_acc: 0.9300
# Epoch 21/25
# 8000/8000 [==============================] - 6s 811us/step - loss: 0.1942 - acc: 0.9275 - val_loss: 0.1569 - val_acc: 0.9480
# Epoch 22/25
# 8000/8000 [==============================] - 7s 816us/step - loss: 0.1798 - acc: 0.9301 - val_loss: 0.1574 - val_acc: 0.9480
# Epoch 23/25
# 8000/8000 [==============================] - 7s 826us/step - loss: 0.1770 - acc: 0.9324 - val_loss: 0.1561 - val_acc: 0.9460
# Epoch 24/25
# 8000/8000 [==============================] - 7s 823us/step - loss: 0.1685 - acc: 0.9342 - val_loss: 0.1530 - val_acc: 0.9480
# Epoch 25/25
# 8000/8000 [==============================] - 7s 817us/step - loss: 0.1627 - acc: 0.9384 - val_loss: 0.2073 - val_acc: 0.9000
# 500/500 [==============================] - 0s 473us/step
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# Validation accuracy 0.8999999761581421
#
# Execution time:   0:02:47.000400

# %%
remark = 'ok'

# Results saving (function no. 6)

my_functions.results_update(trd_model_name, model_descr, notebook, dataset_size, 
                            batch_size, epochs, optimizer_name, acc, remark)

# Results overview (function no. 8)

summary = pd.DataFrame(my_functions.results_preview()) 
summary.index = summary.index + 1
summary
# Out:
#                     model_name     model_description   notebook  dataset_size  \
# 1    model_0_0-100-150-sgd-trd     32-64-128-256-512   Module_1          1600
# 2   model_0_0-100-150-adlt-trd     32-64-128-256-512   Module_1          1600
# 3   model_0_0-100-120-rmsp-trd     32-64-128-256-512   Module_1          1600
# 4   model_0_0-100-100-RMSp-trd     32-64-128-256-512   Module_1          1600
# 5    model_0_0-100-100-sgd-trd     32-64-128-256-512   Module_1          1600
# 6     model_0_0-30-100-sgd-trd     32-64-128-256-512   Module_1          1600
# 7      model_0_0-15-40-sgd-trd     32-64-128-256-512   Module_1          1600
# 8     model_0_0-15-25-RMSp-trd     32-64-128-256-512   Module_1          1600
# 9     model_0_0-15-15-rmsp-trd     32-64-128-256-512   Module_1          1600
# 10   model_0_8-100-150-sgd-trd     32-64-128-256-512   Module_3          8000
# 11   model_0_8-100-100-sgd-trd     32-64-128-256-512   Module_3          8000
# 12    model_0_8-30-100-sgd-trd     32-64-128-256-512   Module_3          8000
# 13     model_0_8-30-32-sgd-trd     32-64-128-256-512   Module_3          8000
# 14    model_0_8-30-30-adlt-trd     32-64-128-256-512   Module_3          8000
# 15     model_0_8-30-8-adlt-trd     32-64-128-256-512   Module_3          8000
# 16   model_0_8-100-30-adlt-trd     32-64-128-256-512   Module_3          8000
# 17     model_0_8-30-8-RMSp-trd     32-64-128-256-512   Module_3          8000
# 18   model_0_8-100-30-RMSp-trd     32-64-128-256-512   Module_3          8000
# 19   model_0_8-100-21-RMSp-trd     32-64-128-256-512   Module_3          8000
# 20   model_1_8-100-100-sgd-trd     model_0 + Dropout   Module_4          8000
# 21     model_1_8-30-32-sgd-trd     model_0 + Dropout   Module_4          8000
# 22     model_1_8-30-40-sgd-trd     model_0 + Dropout   Module_4          8000
# 23     model_1_8-30-9-adlt-trd     model_0 + Dropout   Module_4          8000
# 24   model_1_8-100-30-RMSp-trd     model_0 + Dropout   Module_4          8000
# 25   model_2_8-100-100-sgd-trd     model_0 + reg. L2   Module_5          8000
# 26     model_2_8-30-40-sgd-trd     model_0 + reg. L2   Module_5          8000
# 27     model_2_8-30-9-adlt-trd     model_0 + reg. L2   Module_5          8000
# 28    model_2_8-30-20-adlt-trd     model_0 + reg. L2   Module_5          8000
# 29   model_2_8-100-25-RMSp-trd     model_0 + reg. L2   Module_5          8000
# 30   model_3_8-100-100-sgd-trd     32+64+128+128+256   Module_6          8000
# 31  model_3_8-100-100-adlt-trd     32+64+128+128+256   Module_6          8000
# 32   model_3_8-100-20-adlt-trd     32+64+128+128+256   Module_6          8000
# 33   model_3_8-100-30-RMSp-trd     32+64+128+128+256   Module_6          8000
# 34   model_4_8-100-100-sgd-trd     32+64+128+128+128   Module_7          8000
# 35   model_4_8-100-20-adlt-trd     32+64+128+128+128   Module_7          8000
# 36   model_4_8-100-30-RMSp-trd     32+64+128+128+128   Module_7          8000
# 37   model_4_8-100-40-RMSp-trd     32+64+128+128+128   Module_7          8000
# 38    model_5_8-100-50-sgd-trd  vgg16 conv base None  Module_12          8000
# 39    model_5_8-100-70-sgd-trd  vgg16 conv base None  Module_13          8000
# 40   model_5_8-100-25-RMSp-trd  vgg16 conv base None  Module_14          8000
# 41    model_6_8-100-50-sgd-trd         32+64+128+128  Module_15          8000
# 42   model_6_8-100-100-sgd-trd         32+64+128+128  Module_15          8000
# 43   model_6_8-100-40-adlt-trd         32+64+128+128  Module_15          8000
# 44   model_6_8-100-17-adlt-trd         32+64+128+128  Module_15          8000
# 45   model_6_8-100-25-RMSp-trd         32+64+128+128  Module_15          8000
#
#     batch_size  epochs         optimizer    acc      remarks
# 1          100     150               sgd  0.924  100-overfit
# 2          100     150          adadelta  0.918   20-overfit
# 3          100     120           rmsprop  0.924   15-overfit
# 4          100     100  RMSprop(lr=1e-4)  0.932   20-overfit
# 5          100     100               sgd  0.904   no overfit
# 6           30     100               sgd  0.918   40-overfit
# 7           15      40               sgd  0.920   15-overfit
# 8           15      25  RMSprop(lr=1e-4)  0.882    6-overfit
# 9           15      15           rmsprop  0.926    4-overfit
# 10         100     150               sgd  0.522   80-overfit
# 11         100     100               sgd  0.934          ok.
# 12          30     100               sgd  0.522   30-overfit
# 13          30      32               sgd  0.918           ok
# 14          30      30          adadelta  0.940    7-overfit
# 15          30       8          adadelta  0.938           ok
# 16         100      30          adadelta  0.928   13-overfit
# 17          30       8  RMSprop(lr=1e-4)  0.856       not ok
# 18         100      30  RMSprop(lr=1e-4)  0.940   20-overfit
# 19         100      21  RMSprop(lr=1e-4)  0.890   17-overfit
# 20         100     100               sgd  0.930   80-overfit
# 21          30      32               sgd  0.934          ok.
# 22          30      40               sgd  0.922   30-overfit
# 23          30       9          adadelta  0.922    7-overfit
# 24         100      30  RMSprop(lr=1e-4)  0.942   20-overfit
# 25         100     100               sgd  0.900   80-overfit
# 26          30      40               sgd  0.904   30-overfit
# 27          30       9          adadelta  0.898           ok
# 28          30      20          adadelta  0.930   12-overfit
# 29         100      25  RMSprop(lr=1e-4)  0.872           ok
# 30         100     100               sgd  0.936           ok
# 31         100     100          adadelta  0.942   15-overfit
# 32         100      20          adadelta  0.946   12-overfit
# 33         100      30  RMSprop(lr=1e-4)  0.932           ok
# 34         100     100               sgd  0.924           ok
# 35         100      20          adadelta  0.926   13-overfit
# 36         100      30  RMSprop(lr=1e-4)  0.946           ok
# 37         100      40  RMSprop(lr=1e-4)  0.946           ok
# 38         100      50               sgd  0.904       val>tr
# 39         100      70               sgd  0.922     underfit
# 40         100      25  RMSprop(lr=1e-4)  0.910   10-overfit
# 41         100      50               sgd  0.914      val>>tr
# 42         100     100               sgd  0.932   80-overfit
# 43         100      40          adadelta  0.952   15-overfit
# 44         100      17          adadelta  0.934           ok
# 45         100      25  RMSprop(lr=1e-4)  0.900           ok

# %% [markdown]
# ### 3.6 model_6 & optimizer RMSprop(lr=1e-4)

# %%
model = keras.models.load_model('./Models/model_6.h5') # not trained model!

epochs = 30
batch_size = 100
optimizer = optimizers.RMSprop(lr=1e-4)
optimizer_name = 'RMSprop(lr=1e-4)'
trd_model_name = 'model_6_8-100-30-RMSp-trd' # model after training, name without file extension !
notebook = 'Module_15'
model_descr = '32+64+128+128'
dataset_size = len(TRAIN_X)

# Training (function no. 23)

acc = my_functions.train_and_chart(batch_size, epochs, model, optimizer, 
                                   TRAIN_X, TRAIN_Y, VALID_X, VALID_Y, trd_model_name)
del(model)
# Out:
# Train on 8000 samples, validate on 500 samples
# Epoch 1/30
# 8000/8000 [==============================] - 7s 910us/step - loss: 0.5663 - acc: 0.7170 - val_loss: 0.4020 - val_acc: 0.8560
# Epoch 2/30
# 8000/8000 [==============================] - 7s 821us/step - loss: 0.4740 - acc: 0.7800 - val_loss: 0.3050 - val_acc: 0.8680
# Epoch 3/30
# 8000/8000 [==============================] - 7s 823us/step - loss: 0.4220 - acc: 0.8052 - val_loss: 0.2951 - val_acc: 0.8860
# Epoch 4/30
# 8000/8000 [==============================] - 7s 821us/step - loss: 0.3989 - acc: 0.8210 - val_loss: 0.2553 - val_acc: 0.8860
# Epoch 5/30
# 8000/8000 [==============================] - 7s 818us/step - loss: 0.3775 - acc: 0.8330 - val_loss: 0.2902 - val_acc: 0.8780
# Epoch 6/30
# 8000/8000 [==============================] - 7s 826us/step - loss: 0.3462 - acc: 0.8529 - val_loss: 0.2411 - val_acc: 0.8900
# Epoch 7/30
# 8000/8000 [==============================] - 7s 819us/step - loss: 0
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# Validation accuracy 0.9520000219345093
#
# Execution time:   0:03:20.113518

# %%
remark = 'ok'

# Results saving (function no. 6)

my_functions.results_update(trd_model_name, model_descr, notebook, dataset_size, 
                            batch_size, epochs, optimizer_name, acc, remark)

# Results overview (function no. 8)

summary = pd.DataFrame(my_functions.results_preview()) 
summary.index = summary.index + 1
summary
# Out:
#                     model_name     model_description   notebook  dataset_size  \
# 1    model_0_0-100-150-sgd-trd     32-64-128-256-512   Module_1          1600
# 2   model_0_0-100-150-adlt-trd     32-64-128-256-512   Module_1          1600
# 3   model_0_0-100-120-rmsp-trd     32-64-128-256-512   Module_1          1600
# 4   model_0_0-100-100-RMSp-trd     32-64-128-256-512   Module_1          1600
# 5    model_0_0-100-100-sgd-trd     32-64-128-256-512   Module_1          1600
# 6     model_0_0-30-100-sgd-trd     32-64-128-256-512   Module_1          1600
# 7      model_0_0-15-40-sgd-trd     32-64-128-256-512   Module_1          1600
# 8     model_0_0-15-25-RMSp-trd     32-64-128-256-512   Module_1          1600
# 9     model_0_0-15-15-rmsp-trd     32-64-128-256-512   Module_1          1600
# 10   model_0_8-100-150-sgd-trd     32-64-128-256-512   Module_3          8000
# 11   model_0_8-100-100-sgd-trd     32-64-128-256-512   Module_3          8000
# 12    model_0_8-30-100-sgd-trd     32-64-128-256-512   Module_3          8000
# 13     model_0_8-30-32-sgd-trd     32-64-128-256-512   Module_3          8000
# 14    model_0_8-30-30-adlt-trd     32-64-128-256-512   Module_3          8000
# 15     model_0_8-30-8-adlt-trd     32-64-128-256-512   Module_3          8000
# 16   model_0_8-100-30-adlt-trd     32-64-128-256-512   Module_3          8000
# 17     model_0_8-30-8-RMSp-trd     32-64-128-256-512   Module_3          8000
# 18   model_0_8-100-30-RMSp-trd     32-64-128-256-512   Module_3          8000
# 19   model_0_8-100-21-RMSp-trd     32-64-128-256-512   Module_3          8000
# 20   model_1_8-100-100-sgd-trd     model_0 + Dropout   Module_4          8000
# 21     model_1_8-30-32-sgd-trd     model_0 + Dropout   Module_4          8000
# 22     model_1_8-30-40-sgd-trd     model_0 + Dropout   Module_4          8000
# 23     model_1_8-30-9-adlt-trd     model_0 + Dropout   Module_4          8000
# 24   model_1_8-100-30-RMSp-trd     model_0 + Dropout   Module_4          8000
# 25   model_2_8-100-100-sgd-trd     model_0 + reg. L2   Module_5          8000
# 26     model_2_8-30-40-sgd-trd     model_0 + reg. L2   Module_5          8000
# 27     model_2_8-30-9-adlt-trd     model_0 + reg. L2   Module_5          8000
# 28    model_2_8-30-20-adlt-trd     model_0 + reg. L2   Module_5          8000
# 29   model_2_8-100-25-RMSp-trd     model_0 + reg. L2   Module_5          8000
# 30   model_3_8-100-100-sgd-trd     32+64+128+128+256   Module_6          8000
# 31  model_3_8-100-100-adlt-trd     32+64+128+128+256   Module_6          8000
# 32   model_3_8-100-20-adlt-trd     32+64+128+128+256   Module_6          8000
# 33   model_3_8-100-30-RMSp-trd     32+64+128+128+256   Module_6          8000
# 34   model_4_8-100-100-sgd-trd     32+64+128+128+128   Module_7          8000
# 35   model_4_8-100-20-adlt-trd     32+64+128+128+128   Module_7          8000
# 36   model_4_8-100-30-RMSp-trd     32+64+128+128+128   Module_7          8000
# 37   model_4_8-100-40-RMSp-trd     32+64+128+128+128   Module_7          8000
# 38    model_5_8-100-50-sgd-trd  vgg16 conv base None  Module_12          8000
# 39    model_5_8-100-70-sgd-trd  vgg16 conv base None  Module_13          8000
# 40   model_5_8-100-25-RMSp-trd  vgg16 conv base None  Module_14          8000
# 41    model_6_8-100-50-sgd-trd         32+64+128+128  Module_15          8000
# 42   model_6_8-100-100-sgd-trd         32+64+128+128  Module_15          8000
# 43   model_6_8-100-40-adlt-trd         32+64+128+128  Module_15          8000
# 44   model_6_8-100-17-adlt-trd         32+64+128+128  Module_15          8000
# 45   model_6_8-100-25-RMSp-trd         32+64+128+128  Module_15          8000
# 46   model_6_8-100-30-RMSp-trd         32+64+128+128  Module_15          8000
#
#     batch_size  epochs         optimizer    acc      remarks
# 1          100     150               sgd  0.924  100-overfit
# 2          100     150          adadelta  0.918   20-overfit
# 3          100     120           rmsprop  0.924   15-overfit
# 4          100     100  RMSprop(lr=1e-4)  0.932   20-overfit
# 5          100     100               sgd  0.904   no overfit
# 6           30     100               sgd  0.918   40-overfit
# 7           15      40               sgd  0.920   15-overfit
# 8           15      25  RMSprop(lr=1e-4)  0.882    6-overfit
# 9           15      15           rmsprop  0.926    4-overfit
# 10         100     150               sgd  0.522   80-overfit
# 11         100     100               sgd  0.934          ok.
# 12          30     100               sgd  0.522   30-overfit
# 13          30      32               sgd  0.918           ok
# 14          30      30          adadelta  0.940    7-overfit
# 15          30       8          adadelta  0.938           ok
# 16         100      30          adadelta  0.928   13-overfit
# 17          30       8  RMSprop(lr=1e-4)  0.856       not ok
# 18         100      30  RMSprop(lr=1e-4)  0.940   20-overfit
# 19         100      21  RMSprop(lr=1e-4)  0.890   17-overfit
# 20         100     100               sgd  0.930   80-overfit
# 21          30      32               sgd  0.934          ok.
# 22          30      40               sgd  0.922   30-overfit
# 23          30       9          adadelta  0.922    7-overfit
# 24         100      30  RMSprop(lr=1e-4)  0.942   20-overfit
# 25         100     100               sgd  0.900   80-overfit
# 26          30      40               sgd  0.904   30-overfit
# 27          30       9          adadelta  0.898           ok
# 28          30      20          adadelta  0.930   12-overfit
# 29         100      25  RMSprop(lr=1e-4)  0.872           ok
# 30         100     100               sgd  0.936           ok
# 31         100     100          adadelta  0.942   15-overfit
# 32         100      20          adadelta  0.946   12-overfit
# 33         100      30  RMSprop(lr=1e-4)  0.932           ok
# 34         100     100               sgd  0.924           ok
# 35         100      20          adadelta  0.926   13-overfit
# 36         100      30  RMSprop(lr=1e-4)  0.946           ok
# 37         100      40  RMSprop(lr=1e-4)  0.946           ok
# 38         100      50               sgd  0.904       val>tr
# 39         100      70               sgd  0.922     underfit
# 40         100      25  RMSprop(lr=1e-4)  0.910   10-overfit
# 41         100      50               sgd  0.914      val>>tr
# 42         100     100               sgd  0.932   80-overfit
# 43         100      40          adadelta  0.952   15-overfit
# 44         100      17          adadelta  0.934           ok
# 45         100      25  RMSprop(lr=1e-4)  0.900           ok
# 46         100      30  RMSprop(lr=1e-4)  0.952           ok
