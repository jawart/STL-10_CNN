# %% [markdown]
# # model_4 - configuration & training

# %%
# Choosing of single GPU - has to be done before tensorflow import:
# All the notebooks used earlier with that option have to be closed or to have to have restarted the kernel
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="2"        # Will use only single GPU device

# %%
import numpy as np
import pandas as pd
import my_functions
import keras
from keras import layers
from keras import models
from keras import Model
from keras import optimizers
from keras import regularizers
import warnings
import tensorflow as tf
warnings.filterwarnings('ignore')
tf.logging.set_verbosity(tf.logging.ERROR)
# Out:
# Using TensorFlow backend.
# /home/artur/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/artur/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/artur/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/artur/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/artur/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/artur/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ## 1. New model configuration

# %% [markdown]
# ### 1.1 New convolutional base
# - Available models:

# %%
# %%bash
# ls ./Models
# Out:
# classifier_0.h5
# classifier_1.h5
# classifier_2.h5
# conv_base_0.h5
# conv_base_1.h5
# conv_base_2.h5
# model_0_0-100-100-RMSp-trd.h5
# model_0_0-100-100-sgd-trd.h5
# model_0_0-100-120-rmsp-trd.h5
# model_0_0-100-150-adlt-trd.h5
# model_0_0-100-150-sgd-trd.h5
# model_0_0-15-15-rmsp-trd.h5
# model_0_0-15-25-RMSp-trd.h5
# model_0_0-15-40-sgd-trd.h5
# model_0_0-30-100-sgd-trd.h5
# model_0_8-100-100-sgd-trd.h5
# model_0_8-100-150-sgd-trd.h5
# model_0_8-100-21-RMSp-trd.h5
# model_0_8-100-30-adlt-trd.h5
# model_0_8-100-30-RMSp-trd.h5
# model_0_8-30-100-sgd-trd.h5
# model_0_8-30-30-adlt-trd.h5
# model_0_8-30-32-sgd-trd.h5
# model_0_8-30-8-adlt-trd.h5
# model_0_8-30-8-RMSp-trd.h5
# model_0.h5
# model_1_8-100-100-sgd-trd.h5
# model_1_8-100-30-RMSp-trd.h5
# model_1_8-30-32-sgd-trd.h5
# model_1_8-30-40-sgd-trd.h5
# model_1_8-30-9-adlt-trd.h5
# model_1.h5
# model_2_8-100-100-sgd-trd.h5
# model_2_8-100-25-RMSp-trd.h5
# model_2_8-30-20-adlt-trd.h5
# model_2_8-30-40-sgd-trd.h5
# model_2_8-30-9-adlt-trd.h5
# model_2.h5
# model_3_8-100-100-adlt-trd.h5
# model_3_8-100-100-sgd-trd.h5
# model_3_8-100-20-adlt-trd.h5
# model_3_8-100-30-RMSp-trd.h5
# model_3.h5

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(96, 96, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.name = 'conv_base_3'
model.summary()
model.save('./Models/conv_base_3.h5')
# Out:
# Model: "conv_base_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 32)        896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 2, 2, 128)         147584
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 1, 1, 128)         0
# =================================================================
# Total params: 388,416
# Trainable params: 388,416
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 1.2 Classifier modification

# %%
classifier_3 = models.Sequential()
classifier_3.add(layers.Dense(512, activation='relu', input_dim=1*1*128))
classifier_3.add(layers.Dense(2, activation='sigmoid'))
classifier_3.name = 'classifier_3'
classifier_3.summary()
classifier_3.save('./Models/classifier_3.h5')
# Out:
# Model: "classifier_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               66048
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 67,074
# Trainable params: 67,074
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 1.3 model_4 aggregation

# %%
conv_base_3 = keras.models.load_model('./Models/conv_base_3.h5')
classifier_3 = keras.models.load_model('./Models/classifier_3.h5')

model_4 = models.Sequential()
model_4.add(conv_base_3)
model_4.add(layers.Flatten())
model_4.add(classifier_3)
model_4.name = 'model_4'
model_4.summary()
model_4.save('./Models/model_4.h5') # not trained
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_base_3 (Sequential)     (None, 1, 1, 128)         388416
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# classifier_3 (Sequential)    (None, 2)                 67074
# =================================================================
# Total params: 455,490
# Trainable params: 455,490
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 2. Data loading and transformation
# - Available data:

# %%
# %%bash
# ls ./Used_data
# Out:
# TEST_IMAGES.npy
# TEST_LABELS.npy
# TRAIN_IMAGES.npy
# TRAIN_LABELS.npy
# TRAIN_X_EXTD.npy
# TRAIN_Y_EXTD.npy
# VALID_IMAGES.npy
# VALID_LABELS.npy

# %%
# Loads and transforms 'Used data' to CNN training

train_x_name = 'TRAIN_X_EXTD.npy'
train_y_name = 'TRAIN_Y_EXTD.npy'

TRAIN_X, VALID_X, TEST_X, TRAIN_Y, VALID_Y, TEST_Y = my_functions.data_conversion(train_x_name, train_y_name)
# Out:
# LOADED DATA (before conversion):
#   set name              shape  dtype       data sight
# 0  TRAIN_X  (8000, 96, 96, 3)  uint8     [87, 73, 37]
# 1  TRAIN_Y            (8000,)  uint8                2
# 2  VALID_X   (500, 96, 96, 3)  uint8  [204, 205, 210]
# 3  VALID_Y             (500,)  uint8                1
# 4   TEST_X   (500, 96, 96, 3)  uint8  [132, 167, 203]
# 5   TEST_Y             (500,)  uint8                1
#
# DATA FOR TRAINING (after conversion):
#   set name              shape    dtype                            data sight
# 0  TRAIN_X  (8000, 96, 96, 3)  float32  [0.34117648, 0.28627452, 0.14509805]
# 1  TRAIN_Y          (8000, 2)  float32                            [0.0, 1.0]
# 2  VALID_X   (500, 96, 96, 3)  float32           [0.8, 0.8039216, 0.8235294]
# 3  VALID_Y           (500, 2)  float32                            [1.0, 0.0]
# 4   TEST_X   (500, 96, 96, 3)  float32     [0.5176471, 0.654902, 0.79607844]
# 5   TEST_Y           (500, 2)  float32                            [1.0, 0.0]

# %% [markdown]
# ## 3. Model training
#
# For the training the models without 'trd' have to be choosen,
# models with 'trd' are trained already
#
# - Available models to choice:

# %%
# %%bash
# ls ./Models
# Out:
# classifier_0.h5
# classifier_1.h5
# classifier_2.h5
# classifier_3.h5
# conv_base_0.h5
# conv_base_1.h5
# conv_base_2.h5
# conv_base_3.h5
# model_0_0-100-100-RMSp-trd.h5
# model_0_0-100-100-sgd-trd.h5
# model_0_0-100-120-rmsp-trd.h5
# model_0_0-100-150-adlt-trd.h5
# model_0_0-100-150-sgd-trd.h5
# model_0_0-15-15-rmsp-trd.h5
# model_0_0-15-25-RMSp-trd.h5
# model_0_0-15-40-sgd-trd.h5
# model_0_0-30-100-sgd-trd.h5
# model_0_8-100-100-sgd-trd.h5
# model_0_8-100-150-sgd-trd.h5
# model_0_8-100-21-RMSp-trd.h5
# model_0_8-100-30-adlt-trd.h5
# model_0_8-100-30-RMSp-trd.h5
# model_0_8-30-100-sgd-trd.h5
# model_0_8-30-30-adlt-trd.h5
# model_0_8-30-32-sgd-trd.h5
# model_0_8-30-8-adlt-trd.h5
# model_0_8-30-8-RMSp-trd.h5
# model_0.h5
# model_1_8-100-100-sgd-trd.h5
# model_1_8-100-30-RMSp-trd.h5
# model_1_8-30-32-sgd-trd.h5
# model_1_8-30-40-sgd-trd.h5
# model_1_8-30-9-adlt-trd.h5
# model_1.h5
# model_2_8-100-100-sgd-trd.h5
# model_2_8-100-25-RMSp-trd.h5
# model_2_8-30-20-adlt-trd.h5
# model_2_8-30-40-sgd-trd.h5
# model_2_8-30-9-adlt-trd.h5
# model_2.h5
# model_3_8-100-100-adlt-trd.h5
# model_3_8-100-100-sgd-trd.h5
# model_3_8-100-20-adlt-trd.h5
# model_3_8-100-30-RMSp-trd.h5
# model_3.h5
# model_4.h5

# %% [markdown]
# #### Existing results overview:

# %%
# Results overview (function no. 8)

summary = pd.DataFrame(my_functions.results_preview()) 
summary.index = summary.index + 1
summary
# Out:
#                     model_name  model_description  notebook  dataset_size  \
# 1    model_0_0-100-150-sgd-trd  32-64-128-256-512  Module_1          1600
# 2   model_0_0-100-150-adlt-trd  32-64-128-256-512  Module_1          1600
# 3   model_0_0-100-120-rmsp-trd  32-64-128-256-512  Module_1          1600
# 4   model_0_0-100-100-RMSp-trd  32-64-128-256-512  Module_1          1600
# 5    model_0_0-100-100-sgd-trd  32-64-128-256-512  Module_1          1600
# 6     model_0_0-30-100-sgd-trd  32-64-128-256-512  Module_1          1600
# 7      model_0_0-15-40-sgd-trd  32-64-128-256-512  Module_1          1600
# 8     model_0_0-15-25-RMSp-trd  32-64-128-256-512  Module_1          1600
# 9     model_0_0-15-15-rmsp-trd  32-64-128-256-512  Module_1          1600
# 10   model_0_8-100-150-sgd-trd  32-64-128-256-512  Module_3          8000
# 11   model_0_8-100-100-sgd-trd  32-64-128-256-512  Module_3          8000
# 12    model_0_8-30-100-sgd-trd  32-64-128-256-512  Module_3          8000
# 13     model_0_8-30-32-sgd-trd  32-64-128-256-512  Module_3          8000
# 14    model_0_8-30-30-adlt-trd  32-64-128-256-512  Module_3          8000
# 15     model_0_8-30-8-adlt-trd  32-64-128-256-512  Module_3          8000
# 16   model_0_8-100-30-adlt-trd  32-64-128-256-512  Module_3          8000
# 17     model_0_8-30-8-RMSp-trd  32-64-128-256-512  Module_3          8000
# 18   model_0_8-100-30-RMSp-trd  32-64-128-256-512  Module_3          8000
# 19   model_0_8-100-21-RMSp-trd  32-64-128-256-512  Module_3          8000
# 20   model_1_8-100-100-sgd-trd  model_0 + Dropout  Module_4          8000
# 21     model_1_8-30-32-sgd-trd  model_0 + Dropout  Module_4          8000
# 22     model_1_8-30-40-sgd-trd  model_0 + Dropout  Module_4          8000
# 23     model_1_8-30-9-adlt-trd  model_0 + Dropout  Module_4          8000
# 24   model_1_8-100-30-RMSp-trd  model_0 + Dropout  Module_4          8000
# 25   model_2_8-100-100-sgd-trd  model_0 + reg. L2  Module_5          8000
# 26     model_2_8-30-40-sgd-trd  model_0 + reg. L2  Module_5          8000
# 27     model_2_8-30-9-adlt-trd  model_0 + reg. L2  Module_5          8000
# 28    model_2_8-30-20-adlt-trd  model_0 + reg. L2  Module_5          8000
# 29   model_2_8-100-25-RMSp-trd  model_0 + reg. L2  Module_5          8000
# 30   model_3_8-100-100-sgd-trd  32+64+128+128+256  Module_6          8000
# 31  model_3_8-100-100-adlt-trd  32+64+128+128+256  Module_6          8000
# 32   model_3_8-100-20-adlt-trd  32+64+128+128+256  Module_6          8000
# 33   model_3_8-100-30-RMSp-trd  32+64+128+128+256  Module_6          8000
#
#     batch_size  epochs         optimizer    acc      remarks
# 1          100     150               sgd  0.924  100-overfit
# 2          100     150          adadelta  0.918   20-overfit
# 3          100     120           rmsprop  0.924   15-overfit
# 4          100     100  RMSprop(lr=1e-4)  0.932   20-overfit
# 5          100     100               sgd  0.904   no overfit
# 6           30     100               sgd  0.918   40-overfit
# 7           15      40               sgd  0.920   15-overfit
# 8           15      25  RMSprop(lr=1e-4)  0.882    6-overfit
# 9           15      15           rmsprop  0.926    4-overfit
# 10         100     150               sgd  0.522   80-overfit
# 11         100     100               sgd  0.934          ok.
# 12          30     100               sgd  0.522   30-overfit
# 13          30      32               sgd  0.918           ok
# 14          30      30          adadelta  0.940    7-overfit
# 15          30       8          adadelta  0.938           ok
# 16         100      30          adadelta  0.928   13-overfit
# 17          30       8  RMSprop(lr=1e-4)  0.856       not ok
# 18         100      30  RMSprop(lr=1e-4)  0.940   20-overfit
# 19         100      21  RMSprop(lr=1e-4)  0.890   17-overfit
# 20         100     100               sgd  0.930   80-overfit
# 21          30      32               sgd  0.934          ok.
# 22          30      40               sgd  0.922   30-overfit
# 23          30       9          adadelta  0.922    7-overfit
# 24         100      30  RMSprop(lr=1e-4)  0.942   20-overfit
# 25         100     100               sgd  0.900   80-overfit
# 26          30      40               sgd  0.904   30-overfit
# 27          30       9          adadelta  0.898           ok
# 28          30      20          adadelta  0.930   12-overfit
# 29         100      25  RMSprop(lr=1e-4)  0.872           ok
# 30         100     100               sgd  0.936           ok
# 31         100     100          adadelta  0.942   15-overfit
# 32         100      20          adadelta  0.946   12-overfit
# 33         100      30  RMSprop(lr=1e-4)  0.932           ok

# %% [markdown]
# ### 3.1 model_4 & optimizer sgd:

# %%
model = keras.models.load_model('./Models/model_4.h5') # not trained model!

epochs = 100
batch_size = 100
optimizer = 'sgd'
optimizer_name = optimizer
trd_model_name = 'model_4_8-100-100-sgd-trd' # model after training, name without file extension !
notebook = 'Module_7'
model_descr = '32+64+128+128+128'
dataset_size = len(TRAIN_X)

# Training (function no. 23)

acc = my_functions.train_and_chart(batch_size, epochs, model, optimizer, 
                                   TRAIN_X, TRAIN_Y, VALID_X, VALID_Y, trd_model_name)
del(model)
# Out:
# Train on 8000 samples, validate on 500 samples
# Epoch 1/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.6924 - acc: 0.5394 - val_loss: 0.6918 - val_acc: 0.6360
# Epoch 2/100
# 8000/8000 [==============================] - 7s 825us/step - loss: 0.6911 - acc: 0.6860 - val_loss: 0.6901 - val_acc: 0.7540
# Epoch 3/100
# 8000/8000 [==============================] - 7s 816us/step - loss: 0.6894 - acc: 0.6971 - val_loss: 0.6880 - val_acc: 0.7440
# Epoch 4/100
# 8000/8000 [==============================] - 7s 815us/step - loss: 0.6873 - acc: 0.7232 - val_loss: 0.6850 - val_acc: 0.7640
# Epoch 5/100
# 8000/8000 [==============================] - 7s 816us/step - loss: 0.6841 - acc: 0.7234 - val_loss: 0.6802 - val_acc: 0.7600
# Epoch 6/100
# 8000/8000 [==============================] - 7s 816us/step - loss: 0.6791 - acc: 0.7266 - val_loss: 0.6729 - val_acc: 0.7560
# Epoch 7/100
# 8000/8000 [==============================] - 7s 817us/step - loss: 0
# 8000/8000 [==============================] - 7s 822us/step - loss: 0.2194 - acc: 0.9141 - val_loss: 0.2187 - val_acc: 0.9220
# Epoch 81/100
# 8000/8000 [==============================] - 7s 820us/step - loss: 0.2114 - acc: 0.9160 - val_loss: 0.2034 - val_acc: 0.9300
# Epoch 82/100
# 8000/8000 [==============================] - 7s 823us/step - loss: 0.2263 - acc: 0.9103 - val_loss: 0.2470 - val_acc: 0.8800
# Epoch 83/100
# 8000/8000 [==============================] - 7s 818us/step - loss: 0.2184 - acc: 0.9120 - val_loss: 0.1957 - val_acc: 0.9260
# Epoch 84/100
# 8000/8000 [==============================] - 7s 817us/step - loss: 0.2108 - acc: 0.9149 - val_loss: 0.1906 - val_acc: 0.9240
# Epoch 85/100
# 8000/8000 [==============================] - 7s 819us/step - loss: 0.2016 - acc: 0.9220 - val_loss: 0.3140 - val_acc: 0.8920
# Epoch 86/100
# 8000/8000 [==============================] - 7s 817us/step - loss: 0.2119 - acc: 0.9193 - val_loss: 0.1932 - val_acc: 0.9300
# Epoch 87/100
# 8000/8000 [==============================] - 7s 818us/step - loss: 0.1875 - acc: 0.9284 - val_loss: 0.1928 - val_acc: 0.9340
# Epoch 88/100
# 8000/8000 [==============================] - 7s 821us/step - loss: 0.1956 - acc: 0.9247 - val_loss: 0.1911 - val_acc: 0.9360
# Epoch 89/100
# 8000/8000 [==============================] - 7s 813us/step - loss: 0.2029 - acc: 0.9219 - val_loss: 0.2231 - val_acc: 0.9180
# Epoch 90/100
# 8000/8000 [==============================] - 7s 814us/step - loss: 0.1946 - acc: 0.9234 - val_loss: 0.1933 - val_acc: 0.9240
# Epoch 91/100
# 8000/8000 [==============================] - 7s 824us/step - loss: 0.1953 - acc: 0.9224 - val_loss: 0.2370 - val_acc: 0.9000
# Epoch 92/100
# 8000/8000 [==============================] - 7s 820us/step - loss: 0.1771 - acc: 0.9310 - val_loss: 0.2007 - val_acc: 0.9380
# Epoch 93/100
# 8000/8000 [==============================] - 7s 817us/step - loss: 0.1971 - acc: 0.9224 - val_loss: 0.2257 - val_acc: 0.9200
# Epoch 94/100
# 8000/8000 [==============================] - 7s 818us/step - loss: 0.1979 - acc: 0.9230 - val_loss: 0.3409 - val_acc: 0.8500
# Epoch 95/100
# 8000/8000 [==============================] - 7s 820us/step - loss: 0.1810 - acc: 0.9283 - val_loss: 0.1927 - val_acc: 0.9280
# Epoch 96/100
# 8000/8000 [==============================] - 7s 814us/step - loss: 0.1751 - acc: 0.9346 - val_loss: 0.1925 - val_acc: 0.9300
# Epoch 97/100
# 8000/8000 [==============================] - 6s 812us/step - loss: 0.1686 - acc: 0.9369 - val_loss: 0.4577 - val_acc: 0.8620
# Epoch 98/100
# 8000/8000 [==============================] - 7s 814us/step - loss: 0.1648 - acc: 0.9373 - val_loss: 0.1901 - val_acc: 0.9340
# Epoch 99/100
# 8000/8000 [==============================] - 7s 814us/step - loss: 0.1720 - acc: 0.9336 - val_loss: 0.1900 - val_acc: 0.9360
# Epoch 100/100
# 8000/8000 [==============================] - 7s 813us/step - loss: 0.1639 - acc: 0.9360 - val_loss: 0.2014 - val_acc: 0.9240
# 500/500 [==============================] - 0s 696us/step
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# Validation accuracy 0.9240000247955322
#
# Execution time:   0:11:00.335021

# %%
remark = 'ok'

# Results saving (function no. 6)

my_functions.results_update(trd_model_name, model_descr, notebook, dataset_size, 
                            batch_size, epochs, optimizer_name, acc, remark)

# Results overview (function no. 8)

summary = pd.DataFrame(my_functions.results_preview()) 
summary.index = summary.index + 1
summary
# Out:
#                     model_name  model_description  notebook  dataset_size  \
# 1    model_0_0-100-150-sgd-trd  32-64-128-256-512  Module_1          1600
# 2   model_0_0-100-150-adlt-trd  32-64-128-256-512  Module_1          1600
# 3   model_0_0-100-120-rmsp-trd  32-64-128-256-512  Module_1          1600
# 4   model_0_0-100-100-RMSp-trd  32-64-128-256-512  Module_1          1600
# 5    model_0_0-100-100-sgd-trd  32-64-128-256-512  Module_1          1600
# 6     model_0_0-30-100-sgd-trd  32-64-128-256-512  Module_1          1600
# 7      model_0_0-15-40-sgd-trd  32-64-128-256-512  Module_1          1600
# 8     model_0_0-15-25-RMSp-trd  32-64-128-256-512  Module_1          1600
# 9     model_0_0-15-15-rmsp-trd  32-64-128-256-512  Module_1          1600
# 10   model_0_8-100-150-sgd-trd  32-64-128-256-512  Module_3          8000
# 11   model_0_8-100-100-sgd-trd  32-64-128-256-512  Module_3          8000
# 12    model_0_8-30-100-sgd-trd  32-64-128-256-512  Module_3          8000
# 13     model_0_8-30-32-sgd-trd  32-64-128-256-512  Module_3          8000
# 14    model_0_8-30-30-adlt-trd  32-64-128-256-512  Module_3          8000
# 15     model_0_8-30-8-adlt-trd  32-64-128-256-512  Module_3          8000
# 16   model_0_8-100-30-adlt-trd  32-64-128-256-512  Module_3          8000
# 17     model_0_8-30-8-RMSp-trd  32-64-128-256-512  Module_3          8000
# 18   model_0_8-100-30-RMSp-trd  32-64-128-256-512  Module_3          8000
# 19   model_0_8-100-21-RMSp-trd  32-64-128-256-512  Module_3          8000
# 20   model_1_8-100-100-sgd-trd  model_0 + Dropout  Module_4          8000
# 21     model_1_8-30-32-sgd-trd  model_0 + Dropout  Module_4          8000
# 22     model_1_8-30-40-sgd-trd  model_0 + Dropout  Module_4          8000
# 23     model_1_8-30-9-adlt-trd  model_0 + Dropout  Module_4          8000
# 24   model_1_8-100-30-RMSp-trd  model_0 + Dropout  Module_4          8000
# 25   model_2_8-100-100-sgd-trd  model_0 + reg. L2  Module_5          8000
# 26     model_2_8-30-40-sgd-trd  model_0 + reg. L2  Module_5          8000
# 27     model_2_8-30-9-adlt-trd  model_0 + reg. L2  Module_5          8000
# 28    model_2_8-30-20-adlt-trd  model_0 + reg. L2  Module_5          8000
# 29   model_2_8-100-25-RMSp-trd  model_0 + reg. L2  Module_5          8000
# 30   model_3_8-100-100-sgd-trd  32+64+128+128+256  Module_6          8000
# 31  model_3_8-100-100-adlt-trd  32+64+128+128+256  Module_6          8000
# 32   model_3_8-100-20-adlt-trd  32+64+128+128+256  Module_6          8000
# 33   model_3_8-100-30-RMSp-trd  32+64+128+128+256  Module_6          8000
# 34   model_4_8-100-100-sgd-trd  32+64+128+128+128  Module_6          8000
#
#     batch_size  epochs         optimizer    acc      remarks
# 1          100     150               sgd  0.924  100-overfit
# 2          100     150          adadelta  0.918   20-overfit
# 3          100     120           rmsprop  0.924   15-overfit
# 4          100     100  RMSprop(lr=1e-4)  0.932   20-overfit
# 5          100     100               sgd  0.904   no overfit
# 6           30     100               sgd  0.918   40-overfit
# 7           15      40               sgd  0.920   15-overfit
# 8           15      25  RMSprop(lr=1e-4)  0.882    6-overfit
# 9           15      15           rmsprop  0.926    4-overfit
# 10         100     150               sgd  0.522   80-overfit
# 11         100     100               sgd  0.934          ok.
# 12          30     100               sgd  0.522   30-overfit
# 13          30      32               sgd  0.918           ok
# 14          30      30          adadelta  0.940    7-overfit
# 15          30       8          adadelta  0.938           ok
# 16         100      30          adadelta  0.928   13-overfit
# 17          30       8  RMSprop(lr=1e-4)  0.856       not ok
# 18         100      30  RMSprop(lr=1e-4)  0.940   20-overfit
# 19         100      21  RMSprop(lr=1e-4)  0.890   17-overfit
# 20         100     100               sgd  0.930   80-overfit
# 21          30      32               sgd  0.934          ok.
# 22          30      40               sgd  0.922   30-overfit
# 23          30       9          adadelta  0.922    7-overfit
# 24         100      30  RMSprop(lr=1e-4)  0.942   20-overfit
# 25         100     100               sgd  0.900   80-overfit
# 26          30      40               sgd  0.904   30-overfit
# 27          30       9          adadelta  0.898           ok
# 28          30      20          adadelta  0.930   12-overfit
# 29         100      25  RMSprop(lr=1e-4)  0.872           ok
# 30         100     100               sgd  0.936           ok
# 31         100     100          adadelta  0.942   15-overfit
# 32         100      20          adadelta  0.946   12-overfit
# 33         100      30  RMSprop(lr=1e-4)  0.932           ok
# 34         100     100               sgd  0.924           ok

# %% [markdown]
# ### 3.2 model_4 & optimizer adadelta:

# %%
model = keras.models.load_model('./Models/model_4.h5') # not trained model!

epochs = 20
batch_size = 100
optimizer = 'adadelta'
optimizer_name = optimizer
trd_model_name = 'model_4_8-100-20-adlt-trd' # model after training, name without file extension !
notebook = 'Module_7'
model_descr = '32+64+128+128+128'
dataset_size = len(TRAIN_X)

# Training (function no. 23)

acc = my_functions.train_and_chart(batch_size, epochs, model, optimizer, 
                                   TRAIN_X, TRAIN_Y, VALID_X, VALID_Y, trd_model_name)
del(model)
# Out:
# Train on 8000 samples, validate on 500 samples
# Epoch 1/20
# 8000/8000 [==============================] - 8s 953us/step - loss: 0.6627 - acc: 0.6336 - val_loss: 0.5692 - val_acc: 0.7560
# Epoch 2/20
# 8000/8000 [==============================] - 7s 857us/step - loss: 0.5611 - acc: 0.7351 - val_loss: 0.3983 - val_acc: 0.8560
# Epoch 3/20
# 8000/8000 [==============================] - 7s 862us/step - loss: 0.4614 - acc: 0.8031 - val_loss: 0.3110 - val_acc: 0.8700
# Epoch 4/20
# 8000/8000 [==============================] - 7s 861us/step - loss: 0.3839 - acc: 0.8385 - val_loss: 0.4526 - val_acc: 0.8060
# Epoch 5/20
# 8000/8000 [==============================] - 7s 861us/step - loss: 0.3616 - acc: 0.8474 - val_loss: 0.3095 - val_acc: 0.9000
# Epoch 6/20
# 8000/8000 [==============================] - 7s 864us/step - loss: 0.3183 - acc: 0.8681 - val_loss: 0.3056 - val_acc: 0.8600
# Epoch 7/20
# 8000/8000 [==============================] - 7s 865us/step - loss: 0.3115 - acc: 0.8681 - val_loss: 0.2236 - val_acc: 0.9040
# Epoch 8/20
# 8000/8000 [==============================] - 7s 843us/step - loss: 0.2773 - acc: 0.8864 - val_loss: 0.2738 - val_acc: 0.8740
# Epoch 9/20
# 8000/8000 [==============================] - 7s 854us/step - loss: 0.2683 - acc: 0.8896 - val_loss: 0.2123 - val_acc: 0.9180
# Epoch 10/20
# 8000/8000 [==============================] - 7s 857us/step - loss: 0.2509 - acc: 0.8971 - val_loss: 0.2852 - val_acc: 0.8820
# Epoch 11/20
# 8000/8000 [==============================] - 7s 851us/step - loss: 0.2311 - acc: 0.9074 - val_loss: 0.2038 - val_acc: 0.9320
# Epoch 12/20
# 8000/8000 [==============================] - 7s 858us/step - loss: 0.2141 - acc: 0.9122 - val_loss: 0.2307 - val_acc: 0.9000
# Epoch 13/20
# 8000/8000 [==============================] - 7s 860us/step - loss: 0.1996 - acc: 0.9205 - val_loss: 0.1966 - val_acc: 0.9240
# Epoch 14/20
# 8000/8000 [==============================] - 7s 858us/step - loss: 0.1805 - acc: 0.9293 - val_loss: 0.1997 - val_acc: 0.9260
# Epoch 15/20
# 8000/8000 [==============================] - 7s 852us/step - loss: 0.1457 - acc: 0.9398 - val_loss: 0.2165 - val_acc: 0.9300
# Epoch 16/20
# 8000/8000 [==============================] - 7s 853us/step - loss: 0.1297 - acc: 0.9503 - val_loss: 0.2582 - val_acc: 0.9280
# Epoch 17/20
# 8000/8000 [==============================] - 7s 854us/step - loss: 0.1118 - acc: 0.9535 - val_loss: 0.2451 - val_acc: 0.9220
# Epoch 18/20
# 8000/8000 [==============================] - 7s 853us/step - loss: 0.1047 - acc: 0.9606 - val_loss: 0.2976 - val_acc: 0.9200
# Epoch 19/20
# 8000/8000 [==============================] - 7s 860us/step - loss: 0.0608 - acc: 0.9761 - val_loss: 0.2975 - val_acc: 0.9300
# Epoch 20/20
# 8000/8000 [==============================] - 7s 860us/step - loss: 0.0534 - acc: 0.9809 - val_loss: 0.2981 - val_acc: 0.9260
# 500/500 [==============================] - 0s 476us/step
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# Validation accuracy 0.9259999990463257
#
# Execution time:   0:02:20.090741

# %%
remark = '13-overfit'

# Results saving (function no. 6)

my_functions.results_update(trd_model_name, model_descr, notebook, dataset_size, 
                            batch_size, epochs, optimizer_name, acc, remark)

# Results overview (function no. 8)

summary = pd.DataFrame(my_functions.results_preview()) 
summary.index = summary.index + 1
summary
# Out:
#                     model_name  model_description  notebook  dataset_size  \
# 1    model_0_0-100-150-sgd-trd  32-64-128-256-512  Module_1          1600
# 2   model_0_0-100-150-adlt-trd  32-64-128-256-512  Module_1          1600
# 3   model_0_0-100-120-rmsp-trd  32-64-128-256-512  Module_1          1600
# 4   model_0_0-100-100-RMSp-trd  32-64-128-256-512  Module_1          1600
# 5    model_0_0-100-100-sgd-trd  32-64-128-256-512  Module_1          1600
# 6     model_0_0-30-100-sgd-trd  32-64-128-256-512  Module_1          1600
# 7      model_0_0-15-40-sgd-trd  32-64-128-256-512  Module_1          1600
# 8     model_0_0-15-25-RMSp-trd  32-64-128-256-512  Module_1          1600
# 9     model_0_0-15-15-rmsp-trd  32-64-128-256-512  Module_1          1600
# 10   model_0_8-100-150-sgd-trd  32-64-128-256-512  Module_3          8000
# 11   model_0_8-100-100-sgd-trd  32-64-128-256-512  Module_3          8000
# 12    model_0_8-30-100-sgd-trd  32-64-128-256-512  Module_3          8000
# 13     model_0_8-30-32-sgd-trd  32-64-128-256-512  Module_3          8000
# 14    model_0_8-30-30-adlt-trd  32-64-128-256-512  Module_3          8000
# 15     model_0_8-30-8-adlt-trd  32-64-128-256-512  Module_3          8000
# 16   model_0_8-100-30-adlt-trd  32-64-128-256-512  Module_3          8000
# 17     model_0_8-30-8-RMSp-trd  32-64-128-256-512  Module_3          8000
# 18   model_0_8-100-30-RMSp-trd  32-64-128-256-512  Module_3          8000
# 19   model_0_8-100-21-RMSp-trd  32-64-128-256-512  Module_3          8000
# 20   model_1_8-100-100-sgd-trd  model_0 + Dropout  Module_4          8000
# 21     model_1_8-30-32-sgd-trd  model_0 + Dropout  Module_4          8000
# 22     model_1_8-30-40-sgd-trd  model_0 + Dropout  Module_4          8000
# 23     model_1_8-30-9-adlt-trd  model_0 + Dropout  Module_4          8000
# 24   model_1_8-100-30-RMSp-trd  model_0 + Dropout  Module_4          8000
# 25   model_2_8-100-100-sgd-trd  model_0 + reg. L2  Module_5          8000
# 26     model_2_8-30-40-sgd-trd  model_0 + reg. L2  Module_5          8000
# 27     model_2_8-30-9-adlt-trd  model_0 + reg. L2  Module_5          8000
# 28    model_2_8-30-20-adlt-trd  model_0 + reg. L2  Module_5          8000
# 29   model_2_8-100-25-RMSp-trd  model_0 + reg. L2  Module_5          8000
# 30   model_3_8-100-100-sgd-trd  32+64+128+128+256  Module_6          8000
# 31  model_3_8-100-100-adlt-trd  32+64+128+128+256  Module_6          8000
# 32   model_3_8-100-20-adlt-trd  32+64+128+128+256  Module_6          8000
# 33   model_3_8-100-30-RMSp-trd  32+64+128+128+256  Module_6          8000
# 34   model_4_8-100-100-sgd-trd  32+64+128+128+128  Module_6          8000
# 35   model_4_8-100-20-adlt-trd  32+64+128+128+128  Module_7          8000
#
#     batch_size  epochs         optimizer    acc      remarks
# 1          100     150               sgd  0.924  100-overfit
# 2          100     150          adadelta  0.918   20-overfit
# 3          100     120           rmsprop  0.924   15-overfit
# 4          100     100  RMSprop(lr=1e-4)  0.932   20-overfit
# 5          100     100               sgd  0.904   no overfit
# 6           30     100               sgd  0.918   40-overfit
# 7           15      40               sgd  0.920   15-overfit
# 8           15      25  RMSprop(lr=1e-4)  0.882    6-overfit
# 9           15      15           rmsprop  0.926    4-overfit
# 10         100     150               sgd  0.522   80-overfit
# 11         100     100               sgd  0.934          ok.
# 12          30     100               sgd  0.522   30-overfit
# 13          30      32               sgd  0.918           ok
# 14          30      30          adadelta  0.940    7-overfit
# 15          30       8          adadelta  0.938           ok
# 16         100      30          adadelta  0.928   13-overfit
# 17          30       8  RMSprop(lr=1e-4)  0.856       not ok
# 18         100      30  RMSprop(lr=1e-4)  0.940   20-overfit
# 19         100      21  RMSprop(lr=1e-4)  0.890   17-overfit
# 20         100     100               sgd  0.930   80-overfit
# 21          30      32               sgd  0.934          ok.
# 22          30      40               sgd  0.922   30-overfit
# 23          30       9          adadelta  0.922    7-overfit
# 24         100      30  RMSprop(lr=1e-4)  0.942   20-overfit
# 25         100     100               sgd  0.900   80-overfit
# 26          30      40               sgd  0.904   30-overfit
# 27          30       9          adadelta  0.898           ok
# 28          30      20          adadelta  0.930   12-overfit
# 29         100      25  RMSprop(lr=1e-4)  0.872           ok
# 30         100     100               sgd  0.936           ok
# 31         100     100          adadelta  0.942   15-overfit
# 32         100      20          adadelta  0.946   12-overfit
# 33         100      30  RMSprop(lr=1e-4)  0.932           ok
# 34         100     100               sgd  0.924           ok
# 35         100      20          adadelta  0.926   13-overfit

# %% [markdown]
# ### 3.3 model_4 & optimizer RMSprop(lr=1e-4)

# %%
model = keras.models.load_model('./Models/model_4.h5') # not trained model!

epochs = 30
batch_size = 100
optimizer = optimizers.RMSprop(lr=1e-4)
optimizer_name = 'RMSprop(lr=1e-4)'
trd_model_name = 'model_4_8-100-30-RMSp-trd' # model after training, name without file extension !
notebook = 'Module_7'
model_descr = '32+64+128+128+128'
dataset_size = len(TRAIN_X)

# Training (function no. 23)

acc = my_functions.train_and_chart(batch_size, epochs, model, optimizer, 
                                   TRAIN_X, TRAIN_Y, VALID_X, VALID_Y, trd_model_name)
del(model)
# Out:
# Train on 8000 samples, validate on 500 samples
# Epoch 1/30
# 8000/8000 [==============================] - 7s 931us/step - loss: 0.5957 - acc: 0.6913 - val_loss: 0.4686 - val_acc: 0.8300
# Epoch 2/30
# 8000/8000 [==============================] - 7s 841us/step - loss: 0.4994 - acc: 0.7676 - val_loss: 0.3955 - val_acc: 0.8420
# Epoch 3/30
# 8000/8000 [==============================] - 7s 841us/step - loss: 0.4605 - acc: 0.7949 - val_loss: 0.3196 - val_acc: 0.8620
# Epoch 4/30
# 8000/8000 [==============================] - 7s 846us/step - loss: 0.4183 - acc: 0.8183 - val_loss: 0.3365 - val_acc: 0.8660
# Epoch 5/30
# 8000/8000 [==============================] - 7s 842us/step - loss: 0.4013 - acc: 0.8265 - val_loss: 0.2742 - val_acc: 0.8840
# Epoch 6/30
# 8000/8000 [==============================] - 7s 857us/step - loss: 0.3755 - acc: 0.8380 - val_loss: 0.2541 - val_acc: 0.8860
# Epoch 7/30
# 8000/8000 [==============================] - 7s 849us/step - loss: 0.3593 - acc: 0.8457 - val_loss: 0.2443 - val_acc: 0.9020
# Epoch 8/30
# 8000/8000 [==============================] - 7s 840us/step - loss: 0.3483 - acc: 0.8521 - val_loss: 0.2585 - val_acc: 0.8940
# Epoch 9/30
# 8000/8000 [==============================] - 7s 849us/step - loss: 0.3327 - acc: 0.8606 - val_loss: 0.2477 - val_acc: 0.8920
# Epoch 10/30
# 8000/8000 [==============================] - 7s 848us/step - loss: 0.3270 - acc: 0.8637 - val_loss: 0.2470 - val_acc: 0.8880
# Epoch 11/30
# 8000/8000 [==============================] - 7s 850us/step - loss: 0.3196 - acc: 0.8643 - val_loss: 0.2552 - val_acc: 0.8900
# Epoch 12/30
# 8000/8000 [==============================] - 7s 839us/step - loss: 0.3046 - acc: 0.8756 - val_loss: 0.2991 - val_acc: 0.8640
# Epoch 13/30
# 8000/8000 [==============================] - 7s 837us/step - loss: 0.3042 - acc: 0.8725 - val_loss: 0.2962 - val_acc: 0.8640
# Epoch 14/30
# 8000/8000 [==============================] - 7s 850us/step - loss: 0.2900 - acc: 0.8791 - val_loss: 0.2180 - val_acc: 0.9080
# Epoch 15/30
# 8000/8000 [==============================] - 7s 852us/step - loss: 0.2796 - acc: 0.8850 - val_loss: 0.2768 - val_acc: 0.8740
# Epoch 16/30
# 8000/8000 [==============================] - 7s 850us/step - loss: 0.2763 - acc: 0.8878 - val_loss: 0.2038 - val_acc: 0.9160
# Epoch 17/30
# 8000/8000 [==============================] - 7s 848us/step - loss: 0.2698 - acc: 0.8881 - val_loss: 0.2231 - val_acc: 0.9200
# Epoch 18/30
# 8000/8000 [==============================] - 7s 850us/step - loss: 0.2612 - acc: 0.8959 - val_loss: 0.1942 - val_acc: 0.9220
# Epoch 19/30
# 8000/8000 [==============================] - 7s 858us/step - loss: 0.2499 - acc: 0.8970 - val_loss: 0.2170 - val_acc: 0.9180
# Epoch 20/30
# 8000/8000 [==============================] - 7s 862us/step - loss: 0.2465 - acc: 0.9040 - val_loss: 0.1978 - val_acc: 0.9180
# Epoch 21/30
# 8000/8000 [==============================] - 7s 847us/step - loss: 0.2323 - acc: 0.9107 - val_loss: 0.1969 - val_acc: 0.9280
# Epoch 22/30
# 8000/8000 [==============================] - 7s 852us/step - loss: 0.2294 - acc: 0.9085 - val_loss: 0.3254 - val_acc: 0.8480
# Epoch 23/30
# 8000/8000 [==============================] - 7s 854us/step - loss: 0.2269 - acc: 0.9104 - val_loss: 0.2025 - val_acc: 0.9320
# Epoch 24/30
# 8000/8000 [==============================] - 7s 859us/step - loss: 0.2213 - acc: 0.9139 - val_loss: 0.1863 - val_acc: 0.9260
# Epoch 25/30
# 8000/8000 [==============================] - 7s 856us/step - loss: 0.2117 - acc: 0.9176 - val_loss: 0.2952 - val_acc: 0.9000
# Epoch 26/30
# 8000/8000 [==============================] - 7s 857us/step - loss: 0.2060 - acc: 0.9168 - val_loss: 0.3307 - val_acc: 0.8480
# Epoch 27/30
# 8000/8000 [==============================] - 7s 848us/step - loss: 0.1990 - acc: 0.9205 - val_loss: 0.2483 - val_acc: 0.8940
# Epoch 28/30
# 8000/8000 [==============================] - 7s 846us/step - loss: 0.1986 - acc: 0.9224 - val_loss: 0.2312 - val_acc: 0.9020
# Epoch 29/30
# 8000/8000 [==============================] - 7s 860us/step - loss: 0.1859 - acc: 0.9274 - val_loss: 0.1888 - val_acc: 0.9260
# Epoch 30/30
# 8000/8000 [==============================] - 7s 845us/step - loss: 0.1821 - acc: 0.9294 - val_loss: 0.1923 - val_acc: 0.9460
# 500/500 [==============================] - 0s 517us/step
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# Validation accuracy 0.9459999799728394
#
# Execution time:   0:03:26.440078

# %%
remark = 'ok'

# Results saving (function no. 6)

my_functions.results_update(trd_model_name, model_descr, notebook, dataset_size, 
                            batch_size, epochs, optimizer_name, acc, remark)

# Results overview (function no. 8)

summary = pd.DataFrame(my_functions.results_preview()) 
summary.index = summary.index + 1
summary
# Out:
#                     model_name  model_description  notebook  dataset_size  \
# 1    model_0_0-100-150-sgd-trd  32-64-128-256-512  Module_1          1600
# 2   model_0_0-100-150-adlt-trd  32-64-128-256-512  Module_1          1600
# 3   model_0_0-100-120-rmsp-trd  32-64-128-256-512  Module_1          1600
# 4   model_0_0-100-100-RMSp-trd  32-64-128-256-512  Module_1          1600
# 5    model_0_0-100-100-sgd-trd  32-64-128-256-512  Module_1          1600
# 6     model_0_0-30-100-sgd-trd  32-64-128-256-512  Module_1          1600
# 7      model_0_0-15-40-sgd-trd  32-64-128-256-512  Module_1          1600
# 8     model_0_0-15-25-RMSp-trd  32-64-128-256-512  Module_1          1600
# 9     model_0_0-15-15-rmsp-trd  32-64-128-256-512  Module_1          1600
# 10   model_0_8-100-150-sgd-trd  32-64-128-256-512  Module_3          8000
# 11   model_0_8-100-100-sgd-trd  32-64-128-256-512  Module_3          8000
# 12    model_0_8-30-100-sgd-trd  32-64-128-256-512  Module_3          8000
# 13     model_0_8-30-32-sgd-trd  32-64-128-256-512  Module_3          8000
# 14    model_0_8-30-30-adlt-trd  32-64-128-256-512  Module_3          8000
# 15     model_0_8-30-8-adlt-trd  32-64-128-256-512  Module_3          8000
# 16   model_0_8-100-30-adlt-trd  32-64-128-256-512  Module_3          8000
# 17     model_0_8-30-8-RMSp-trd  32-64-128-256-512  Module_3          8000
# 18   model_0_8-100-30-RMSp-trd  32-64-128-256-512  Module_3          8000
# 19   model_0_8-100-21-RMSp-trd  32-64-128-256-512  Module_3          8000
# 20   model_1_8-100-100-sgd-trd  model_0 + Dropout  Module_4          8000
# 21     model_1_8-30-32-sgd-trd  model_0 + Dropout  Module_4          8000
# 22     model_1_8-30-40-sgd-trd  model_0 + Dropout  Module_4          8000
# 23     model_1_8-30-9-adlt-trd  model_0 + Dropout  Module_4          8000
# 24   model_1_8-100-30-RMSp-trd  model_0 + Dropout  Module_4          8000
# 25   model_2_8-100-100-sgd-trd  model_0 + reg. L2  Module_5          8000
# 26     model_2_8-30-40-sgd-trd  model_0 + reg. L2  Module_5          8000
# 27     model_2_8-30-9-adlt-trd  model_0 + reg. L2  Module_5          8000
# 28    model_2_8-30-20-adlt-trd  model_0 + reg. L2  Module_5          8000
# 29   model_2_8-100-25-RMSp-trd  model_0 + reg. L2  Module_5          8000
# 30   model_3_8-100-100-sgd-trd  32+64+128+128+256  Module_6          8000
# 31  model_3_8-100-100-adlt-trd  32+64+128+128+256  Module_6          8000
# 32   model_3_8-100-20-adlt-trd  32+64+128+128+256  Module_6          8000
# 33   model_3_8-100-30-RMSp-trd  32+64+128+128+256  Module_6          8000
# 34   model_4_8-100-100-sgd-trd  32+64+128+128+128  Module_6          8000
# 35   model_4_8-100-20-adlt-trd  32+64+128+128+128  Module_7          8000
# 36   model_4_8-100-30-RMSp-trd  32+64+128+128+128  Module_7          8000
#
#     batch_size  epochs         optimizer    acc      remarks
# 1          100     150               sgd  0.924  100-overfit
# 2          100     150          adadelta  0.918   20-overfit
# 3          100     120           rmsprop  0.924   15-overfit
# 4          100     100  RMSprop(lr=1e-4)  0.932   20-overfit
# 5          100     100               sgd  0.904   no overfit
# 6           30     100               sgd  0.918   40-overfit
# 7           15      40               sgd  0.920   15-overfit
# 8           15      25  RMSprop(lr=1e-4)  0.882    6-overfit
# 9           15      15           rmsprop  0.926    4-overfit
# 10         100     150               sgd  0.522   80-overfit
# 11         100     100               sgd  0.934          ok.
# 12          30     100               sgd  0.522   30-overfit
# 13          30      32               sgd  0.918           ok
# 14          30      30          adadelta  0.940    7-overfit
# 15          30       8          adadelta  0.938           ok
# 16         100      30          adadelta  0.928   13-overfit
# 17          30       8  RMSprop(lr=1e-4)  0.856       not ok
# 18         100      30  RMSprop(lr=1e-4)  0.940   20-overfit
# 19         100      21  RMSprop(lr=1e-4)  0.890   17-overfit
# 20         100     100               sgd  0.930   80-overfit
# 21          30      32               sgd  0.934          ok.
# 22          30      40               sgd  0.922   30-overfit
# 23          30       9          adadelta  0.922    7-overfit
# 24         100      30  RMSprop(lr=1e-4)  0.942   20-overfit
# 25         100     100               sgd  0.900   80-overfit
# 26          30      40               sgd  0.904   30-overfit
# 27          30       9          adadelta  0.898           ok
# 28          30      20          adadelta  0.930   12-overfit
# 29         100      25  RMSprop(lr=1e-4)  0.872           ok
# 30         100     100               sgd  0.936           ok
# 31         100     100          adadelta  0.942   15-overfit
# 32         100      20          adadelta  0.946   12-overfit
# 33         100      30  RMSprop(lr=1e-4)  0.932           ok
# 34         100     100               sgd  0.924           ok
# 35         100      20          adadelta  0.926   13-overfit
# 36         100      30  RMSprop(lr=1e-4)  0.946           ok

# %% [markdown]
# ### 3.4 model_4 & optimizer RMSprop(lr=1e-4)

# %%
model = keras.models.load_model('./Models/model_4.h5') # not trained model!

epochs = 40
batch_size = 100
optimizer = optimizers.RMSprop(lr=1e-4)
optimizer_name = 'RMSprop(lr=1e-4)'
trd_model_name = 'model_4_8-100-40-RMSp-trd' # model after training, name without file extension !
notebook = 'Module_7'
model_descr = '32+64+128+128+128'
dataset_size = len(TRAIN_X)

# Training (function no. 23)

acc = my_functions.train_and_chart(batch_size, epochs, model, optimizer, 
                                   TRAIN_X, TRAIN_Y, VALID_X, VALID_Y, trd_model_name)
del(model)
# Out:
# Train on 8000 samples, validate on 500 samples
# Epoch 1/40
# 8000/8000 [==============================] - 8s 947us/step - loss: 0.5970 - acc: 0.6948 - val_loss: 0.4744 - val_acc: 0.7940
# Epoch 2/40
# 8000/8000 [==============================] - 7s 835us/step - loss: 0.5020 - acc: 0.7648 - val_loss: 0.4170 - val_acc: 0.8280
# Epoch 3/40
# 8000/8000 [==============================] - 7s 835us/step - loss: 0.4487 - acc: 0.7965 - val_loss: 0.4252 - val_acc: 0.8100
# Epoch 4/40
# 8000/8000 [==============================] - 7s 829us/step - loss: 0.4193 - acc: 0.8135 - val_loss: 0.3443 - val_acc: 0.8500
# Epoch 5/40
# 8000/8000 [==============================] - 7s 832us/step - loss: 0.3950 - acc: 0.8269 - val_loss: 0.3560 - val_acc: 0.8440
# Epoch 6/40
# 8000/8000 [==============================] - 7s 834us/step - loss: 0.3718 - acc: 0.8395 - val_loss: 0.2470 - val_acc: 0.9020
# Epoch 7/40
# 8000/8000 [==============================] - 7s 834us/step - loss: 0.3570 - acc: 0.8470 - val_loss: 0.4394 - val_acc: 0.8180
# Epoch 8/40
# 8000/8000 [==============================] - 7s 828us/step - loss: 0.3398 - acc: 0.8537 - val_loss: 0.2403 - val_acc: 0.9060
# Epoch 9/40
# 8000/8000 [==============================] - 7s 834us/step - loss: 0.3311 - acc: 0.8576 - val_loss: 0.2418 - val_acc: 0.8860
# Epoch 10/40
# 8000/8000 [==============================] - 7s 833us/step - loss: 0.3147 - acc: 0.8700 - val_loss: 0.2745 - val_acc: 0.8780
# Epoch 11/40
# 8000/8000 [==============================] - 7s 833us/step - loss: 0.3125 - acc: 0.8706 - val_loss: 0.2728 - val_acc: 0.8940
# Epoch 12/40
# Epoch 33/40
# 8000/8000 [==============================] - 7s 832us/step - loss: 0.1611 - acc: 0.9371 - val_loss: 0.1790 - val_acc: 0.9320
# Epoch 34/40
# 8000/8000 [==============================] - 7s 837us/step - loss: 0.1505 - acc: 0.9413 - val_loss: 0.1823 - val_acc: 0.9260
# Epoch 35/40
# 8000/8000 [==============================] - 7s 832us/step - loss: 0.1474 - acc: 0.9409 - val_loss: 0.1810 - val_acc: 0.9420
# Epoch 36/40
# 8000/8000 [==============================] - 7s 832us/step - loss: 0.1406 - acc: 0.9455 - val_loss: 0.1863 - val_acc: 0.9440
# Epoch 37/40
# 8000/8000 [==============================] - 7s 832us/step - loss: 0.1307 - acc: 0.9494 - val_loss: 0.1827 - val_acc: 0.9400
# Epoch 38/40
# 8000/8000 [==============================] - 7s 837us/step - loss: 0.1342 - acc: 0.9499 - val_loss: 0.1797 - val_acc: 0.9480
# Epoch 39/40
# 8000/8000 [==============================] - 7s 834us/step - loss: 0.1220 - acc: 0.9551 - val_loss: 0.2531 - val_acc: 0.9360
# Epoch 40/40
# 8000/8000 [==============================] - 7s 832us/step - loss: 0.1168 - acc: 0.9580 - val_loss: 0.1735 - val_acc: 0.9460
# 500/500 [==============================] - 0s 495us/step
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# Validation accuracy 0.9459999799728394
#
# Execution time:   0:04:29.996131

# %%
remark = 'ok'

# Results saving (function no. 6)

my_functions.results_update(trd_model_name, model_descr, notebook, dataset_size, 
                            batch_size, epochs, optimizer_name, acc, remark)

# Results overview (function no. 8)

summary = pd.DataFrame(my_functions.results_preview()) 
summary.index = summary.index + 1
summary
# Out:
#                     model_name  model_description  notebook  dataset_size  \
# 1    model_0_0-100-150-sgd-trd  32-64-128-256-512  Module_1          1600
# 2   model_0_0-100-150-adlt-trd  32-64-128-256-512  Module_1          1600
# 3   model_0_0-100-120-rmsp-trd  32-64-128-256-512  Module_1          1600
# 4   model_0_0-100-100-RMSp-trd  32-64-128-256-512  Module_1          1600
# 5    model_0_0-100-100-sgd-trd  32-64-128-256-512  Module_1          1600
# 6     model_0_0-30-100-sgd-trd  32-64-128-256-512  Module_1          1600
# 7      model_0_0-15-40-sgd-trd  32-64-128-256-512  Module_1          1600
# 8     model_0_0-15-25-RMSp-trd  32-64-128-256-512  Module_1          1600
# 9     model_0_0-15-15-rmsp-trd  32-64-128-256-512  Module_1          1600
# 10   model_0_8-100-150-sgd-trd  32-64-128-256-512  Module_3          8000
# 11   model_0_8-100-100-sgd-trd  32-64-128-256-512  Module_3          8000
# 12    model_0_8-30-100-sgd-trd  32-64-128-256-512  Module_3          8000
# 13     model_0_8-30-32-sgd-trd  32-64-128-256-512  Module_3          8000
# 14    model_0_8-30-30-adlt-trd  32-64-128-256-512  Module_3          8000
# 15     model_0_8-30-8-adlt-trd  32-64-128-256-512  Module_3          8000
# 16   model_0_8-100-30-adlt-trd  32-64-128-256-512  Module_3          8000
# 17     model_0_8-30-8-RMSp-trd  32-64-128-256-512  Module_3          8000
# 18   model_0_8-100-30-RMSp-trd  32-64-128-256-512  Module_3          8000
# 19   model_0_8-100-21-RMSp-trd  32-64-128-256-512  Module_3          8000
# 20   model_1_8-100-100-sgd-trd  model_0 + Dropout  Module_4          8000
# 21     model_1_8-30-32-sgd-trd  model_0 + Dropout  Module_4          8000
# 22     model_1_8-30-40-sgd-trd  model_0 + Dropout  Module_4          8000
# 23     model_1_8-30-9-adlt-trd  model_0 + Dropout  Module_4          8000
# 24   model_1_8-100-30-RMSp-trd  model_0 + Dropout  Module_4          8000
# 25   model_2_8-100-100-sgd-trd  model_0 + reg. L2  Module_5          8000
# 26     model_2_8-30-40-sgd-trd  model_0 + reg. L2  Module_5          8000
# 27     model_2_8-30-9-adlt-trd  model_0 + reg. L2  Module_5          8000
# 28    model_2_8-30-20-adlt-trd  model_0 + reg. L2  Module_5          8000
# 29   model_2_8-100-25-RMSp-trd  model_0 + reg. L2  Module_5          8000
# 30   model_3_8-100-100-sgd-trd  32+64+128+128+256  Module_6          8000
# 31  model_3_8-100-100-adlt-trd  32+64+128+128+256  Module_6          8000
# 32   model_3_8-100-20-adlt-trd  32+64+128+128+256  Module_6          8000
# 33   model_3_8-100-30-RMSp-trd  32+64+128+128+256  Module_6          8000
# 34   model_4_8-100-100-sgd-trd  32+64+128+128+128  Module_6          8000
# 35   model_4_8-100-20-adlt-trd  32+64+128+128+128  Module_7          8000
# 36   model_4_8-100-30-RMSp-trd  32+64+128+128+128  Module_7          8000
# 37   model_4_8-100-40-RMSp-trd  32+64+128+128+128  Module_7          8000
#
#     batch_size  epochs         optimizer    acc      remarks
# 1          100     150               sgd  0.924  100-overfit
# 2          100     150          adadelta  0.918   20-overfit
# 3          100     120           rmsprop  0.924   15-overfit
# 4          100     100  RMSprop(lr=1e-4)  0.932   20-overfit
# 5          100     100               sgd  0.904   no overfit
# 6           30     100               sgd  0.918   40-overfit
# 7           15      40               sgd  0.920   15-overfit
# 8           15      25  RMSprop(lr=1e-4)  0.882    6-overfit
# 9           15      15           rmsprop  0.926    4-overfit
# 10         100     150               sgd  0.522   80-overfit
# 11         100     100               sgd  0.934          ok.
# 12          30     100               sgd  0.522   30-overfit
# 13          30      32               sgd  0.918           ok
# 14          30      30          adadelta  0.940    7-overfit
# 15          30       8          adadelta  0.938           ok
# 16         100      30          adadelta  0.928   13-overfit
# 17          30       8  RMSprop(lr=1e-4)  0.856       not ok
# 18         100      30  RMSprop(lr=1e-4)  0.940   20-overfit
# 19         100      21  RMSprop(lr=1e-4)  0.890   17-overfit
# 20         100     100               sgd  0.930   80-overfit
# 21          30      32               sgd  0.934          ok.
# 22          30      40               sgd  0.922   30-overfit
# 23          30       9          adadelta  0.922    7-overfit
# 24         100      30  RMSprop(lr=1e-4)  0.942   20-overfit
# 25         100     100               sgd  0.900   80-overfit
# 26          30      40               sgd  0.904   30-overfit
# 27          30       9          adadelta  0.898           ok
# 28          30      20          adadelta  0.930   12-overfit
# 29         100      25  RMSprop(lr=1e-4)  0.872           ok
# 30         100     100               sgd  0.936           ok
# 31         100     100          adadelta  0.942   15-overfit
# 32         100      20          adadelta  0.946   12-overfit
# 33         100      30  RMSprop(lr=1e-4)  0.932           ok
# 34         100     100               sgd  0.924           ok
# 35         100      20          adadelta  0.926   13-overfit
# 36         100      30  RMSprop(lr=1e-4)  0.946           ok
# 37         100      40  RMSprop(lr=1e-4)  0.946           ok
