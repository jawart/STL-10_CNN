# %% [markdown]
# # model_7
# # -  final tuning with one GPU processing

# %%
# Choosing of single GPU - has to be done before tensorflow import:
# All the notebooks used earlier with that option have to be closed or to have to have restarted the kernel
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="2"        # Will use only single GPU device

# %%
import numpy as np
import pandas as pd
import my_functions
import keras
from keras import layers
from keras import models
from keras import Model
from keras import optimizers
from keras.utils import multi_gpu_model
from keras.applications import VGG16
import warnings
import tensorflow as tf
warnings.filterwarnings('ignore')
tf.logging.set_verbosity(tf.logging.ERROR)
# Out:
# Using TensorFlow backend.
# /home/artur/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/artur/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/artur/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/artur/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/artur/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/artur/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ## 1. New model configuration
#
# #### - Not needed - already existing classifier + convolutional base from Keras

# %% [markdown]
# ## 2. Data loading and transformation
# - Available data:

# %%
# %%bash
# ls ./Used_data
# Out:
# TEST_IMAGES.npy
# TEST_LABELS.npy
# TRAIN_IMAGES.npy
# TRAIN_LABELS.npy
# TRAIN_X_EXTD.npy
# TRAIN_Y_EXTD.npy
# VALID_IMAGES.npy
# VALID_LABELS.npy

# %%
# Loads and transforms 'Used data' to CNN training

train_x_name = 'TRAIN_X_EXTD.npy'
train_y_name = 'TRAIN_Y_EXTD.npy'

TRAIN_X, VALID_X, TEST_X, TRAIN_Y, VALID_Y, TEST_Y = my_functions.data_conversion(train_x_name, train_y_name)
# Out:
# LOADED DATA (before conversion):
#   set name              shape  dtype       data sight
# 0  TRAIN_X  (8000, 96, 96, 3)  uint8     [87, 73, 37]
# 1  TRAIN_Y            (8000,)  uint8                2
# 2  VALID_X   (500, 96, 96, 3)  uint8  [204, 205, 210]
# 3  VALID_Y             (500,)  uint8                1
# 4   TEST_X   (500, 96, 96, 3)  uint8  [132, 167, 203]
# 5   TEST_Y             (500,)  uint8                1
#
# DATA FOR TRAINING (after conversion):
#   set name              shape    dtype                            data sight
# 0  TRAIN_X  (8000, 96, 96, 3)  float32  [0.34117648, 0.28627452, 0.14509805]
# 1  TRAIN_Y          (8000, 2)  float32                            [0.0, 1.0]
# 2  VALID_X   (500, 96, 96, 3)  float32           [0.8, 0.8039216, 0.8235294]
# 3  VALID_Y           (500, 2)  float32                            [1.0, 0.0]
# 4   TEST_X   (500, 96, 96, 3)  float32     [0.5176471, 0.654902, 0.79607844]
# 5   TEST_Y           (500, 2)  float32                            [1.0, 0.0]

# %% [markdown]
# ## 3. model_7 - configuration and training
# #### - Available layers overview:

# %%
conv_base = VGG16(weights='imagenet', include_top=False, input_shape=(96, 96, 3))
conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 96, 96, 3)         0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 96, 96, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 96, 96, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 48, 48, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 48, 48, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 48, 48, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 24, 24, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 24, 24, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 24, 24, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 24, 24, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 12, 12, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 12, 12, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 12, 12, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 3, 3, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 3.1 Parallel_model, 3 last vgg16 convolutional layers training

# %%
conv_base = VGG16(weights='imagenet', include_top=False, input_shape=(96, 96, 3))
conv_base.trainable = True    # lockup of the trained weights  !!!

set_trainable = False
for layer in conv_base.layers:
    if layer.name == 'block5_conv1':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
    
classifier_4 = keras.models.load_model('./Models/classifier_4.h5')  # not trained
  
# Model aggregation:
    
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(classifier_4)
model.name = 'model_7'
model.summary()

epochs = 5
batch_size = 100
optimizer = 'sgd'
optimizer_name = optimizer
trd_model_name = 'model_7_8-100-5-3vgg16s-trd_a' # model after training, name without file extension !
notebook = 'Module_19a'
model_descr = '3 last vgg16 layers tr.'
dataset_size = len(TRAIN_X)

# Training (function no. 23)

acc = my_functions.train_and_chart(batch_size, epochs, model, optimizer, 
                                   TRAIN_X, TRAIN_Y, VALID_X, VALID_Y, trd_model_name)
del(model)
# Out:
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 3, 3, 512)         14714688
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# classifier_4 (Sequential)    (None, 2)                 2360834
# =================================================================
# Total params: 17,075,522
# Trainable params: 9,440,258
# Non-trainable params: 7,635,264
# _________________________________________________________________
# Train on 8000 samples, validate on 500 samples
# Epoch 1/5
# 8000/8000 [==============================] - 26s 3ms/step - loss: 0.2422 - acc: 0.8934 - val_loss: 0.0711 - val_acc: 0.9760
# Epoch 2/5
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0683 - acc: 0.9753 - val_loss: 0.0563 - val_acc: 0.9800
# Epoch 3/5
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0429 - acc: 0.9837 - val_loss: 0.0519 - val_acc: 0.9800
# Epoch 4/5
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0279 - acc: 0.9911 - val_loss: 0.0564 - val_acc: 0.9840
# Epoch 5/5
# 8000/8000 [==============================] - 21s 3ms/step - loss: 0.0214 - acc: 0.9930 - val_loss: 0.0589 - val_acc: 0.9860
# 500/500 [==============================] - 2s 5ms/step
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# Validation accuracy 0.9860000014305115
#
# Execution time:   0:01:54.593858

# %%
remark = 'ok'

# Results saving (function no. 6)

my_functions.results_update(trd_model_name, model_descr, notebook, dataset_size, 
                            batch_size, epochs, optimizer_name, acc, remark)

# Results overview (function no. 8)

summary = pd.DataFrame(my_functions.results_preview()) 
summary.index = summary.index + 1
summary
# Out:
#                        model_name          model_description    notebook  \
# 1       model_0_0-100-150-sgd-trd          32-64-128-256-512    Module_1
# 2      model_0_0-100-150-adlt-trd          32-64-128-256-512    Module_1
# 3      model_0_0-100-120-rmsp-trd          32-64-128-256-512    Module_1
# 4      model_0_0-100-100-RMSp-trd          32-64-128-256-512    Module_1
# 5       model_0_0-100-100-sgd-trd          32-64-128-256-512    Module_1
# 6        model_0_0-30-100-sgd-trd          32-64-128-256-512    Module_1
# 7         model_0_0-15-40-sgd-trd          32-64-128-256-512    Module_1
# 8        model_0_0-15-25-RMSp-trd          32-64-128-256-512    Module_1
# 9        model_0_0-15-15-rmsp-trd          32-64-128-256-512    Module_1
# 10      model_0_8-100-150-sgd-trd          32-64-128-256-512    Module_3
# 11      model_0_8-100-100-sgd-trd          32-64-128-256-512    Module_3
# 12       model_0_8-30-100-sgd-trd          32-64-128-256-512    Module_3
# 13        model_0_8-30-32-sgd-trd          32-64-128-256-512    Module_3
# 14       model_0_8-30-30-adlt-trd          32-64-128-256-512    Module_3
# 15        model_0_8-30-8-adlt-trd          32-64-128-256-512    Module_3
# 16      model_0_8-100-30-adlt-trd          32-64-128-256-512    Module_3
# 17        model_0_8-30-8-RMSp-trd          32-64-128-256-512    Module_3
# 18      model_0_8-100-30-RMSp-trd          32-64-128-256-512    Module_3
# 19      model_0_8-100-21-RMSp-trd          32-64-128-256-512    Module_3
# 20      model_1_8-100-100-sgd-trd          model_0 + Dropout    Module_4
# 21        model_1_8-30-32-sgd-trd          model_0 + Dropout    Module_4
# 22        model_1_8-30-40-sgd-trd          model_0 + Dropout    Module_4
# 23        model_1_8-30-9-adlt-trd          model_0 + Dropout    Module_4
# 24      model_1_8-100-30-RMSp-trd          model_0 + Dropout    Module_4
# 25      model_2_8-100-100-sgd-trd          model_0 + reg. L2    Module_5
# 26        model_2_8-30-40-sgd-trd          model_0 + reg. L2    Module_5
# 27        model_2_8-30-9-adlt-trd          model_0 + reg. L2    Module_5
# 28       model_2_8-30-20-adlt-trd          model_0 + reg. L2    Module_5
# 29      model_2_8-100-25-RMSp-trd          model_0 + reg. L2    Module_5
# 30      model_3_8-100-100-sgd-trd          32+64+128+128+256    Module_6
# 31     model_3_8-100-100-adlt-trd          32+64+128+128+256    Module_6
# 32      model_3_8-100-20-adlt-trd          32+64+128+128+256    Module_6
# 33      model_3_8-100-30-RMSp-trd          32+64+128+128+256    Module_6
# 34      model_4_8-100-100-sgd-trd          32+64+128+128+128    Module_7
# 35      model_4_8-100-20-adlt-trd          32+64+128+128+128    Module_7
# 36      model_4_8-100-30-RMSp-trd          32+64+128+128+128    Module_7
# 37      model_4_8-100-40-RMSp-trd          32+64+128+128+128    Module_7
# 38       model_5_8-100-50-sgd-trd       vgg16 conv base None   Module_12
# 39       model_5_8-100-70-sgd-trd       vgg16 conv base None   Module_13
# 40      model_5_8-100-25-RMSp-trd       vgg16 conv base None   Module_14
# 41       model_6_8-100-50-sgd-trd              32+64+128+128   Module_15
# 42      model_6_8-100-100-sgd-trd              32+64+128+128   Module_15
# 43      model_6_8-100-40-adlt-trd              32+64+128+128   Module_15
# 44      model_6_8-100-17-adlt-trd              32+64+128+128   Module_15
# 45      model_6_8-100-25-RMSp-trd              32+64+128+128   Module_15
# 46      model_6_8-100-30-RMSp-trd              32+64+128+128   Module_15
# 47    model_7_8-100-30-0vgg16-trd     full vgg16 base frozen   Module_16
# 48    model_7_8-100-12-0vgg16-trd     full vgg16 base frozen   Module_16
# 49   model_7_8-100-20-1vgg16s-trd  last vgg16 layer training   Module_17
# 50   model_7_8-100-12-1vgg16R-trd  last vgg16 layer training   Module_17
# 51    model_7_8-100-5-1vgg16s-trd  last vgg16 layer training   Module_17
# 52   model_7_8-100-20-2vgg16s-trd    2 last vgg16 layers tr.   Module_18
# 53    model_7_8-100-5-2vgg16s-trd    2 last vgg16 layers tr.   Module_18
# 54   model_7_8-100-20-3vgg16s-trd    3 last vgg16 layers tr.   Module_19
# 55    model_7_8-100-5-3vgg16s-trd    3 last vgg16 layers tr.   Module_19
# 56  model_7_8-100-5-3vgg16s-trd_a    3 last vgg16 layers tr.  Module_19a
#
#     dataset_size  batch_size  epochs         optimizer    acc      remarks
# 1           1600         100     150               sgd  0.924  100-overfit
# 2           1600         100     150          adadelta  0.918   20-overfit
# 3           1600         100     120           rmsprop  0.924   15-overfit
# 4           1600         100     100  RMSprop(lr=1e-4)  0.932   20-overfit
# 5           1600         100     100               sgd  0.904   no overfit
# 6           1600          30     100               sgd  0.918   40-overfit
# 7           1600          15      40               sgd  0.920   15-overfit
# 8           1600          15      25  RMSprop(lr=1e-4)  0.882    6-overfit
# 9           1600          15      15           rmsprop  0.926    4-overfit
# 10          8000         100     150               sgd  0.522   80-overfit
# 11          8000         100     100               sgd  0.934          ok.
# 12          8000          30     100               sgd  0.522   30-overfit
# 13          8000          30      32               sgd  0.918           ok
# 14          8000          30      30          adadelta  0.940    7-overfit
# 15          8000          30       8          adadelta  0.938           ok
# 16          8000         100      30          adadelta  0.928   13-overfit
# 17          8000          30       8  RMSprop(lr=1e-4)  0.856       not ok
# 18          8000         100      30  RMSprop(lr=1e-4)  0.940   20-overfit
# 19          8000         100      21  RMSprop(lr=1e-4)  0.890   17-overfit
# 20          8000         100     100               sgd  0.930   80-overfit
# 21          8000          30      32               sgd  0.934          ok.
# 22          8000          30      40               sgd  0.922   30-overfit
# 23          8000          30       9          adadelta  0.922    7-overfit
# 24          8000         100      30  RMSprop(lr=1e-4)  0.942   20-overfit
# 25          8000         100     100               sgd  0.900   80-overfit
# 26          8000          30      40               sgd  0.904   30-overfit
# 27          8000          30       9          adadelta  0.898           ok
# 28          8000          30      20          adadelta  0.930   12-overfit
# 29          8000         100      25  RMSprop(lr=1e-4)  0.872           ok
# 30          8000         100     100               sgd  0.936           ok
# 31          8000         100     100          adadelta  0.942   15-overfit
# 32          8000         100      20          adadelta  0.946   12-overfit
# 33          8000         100      30  RMSprop(lr=1e-4)  0.932           ok
# 34          8000         100     100               sgd  0.924           ok
# 35          8000         100      20          adadelta  0.926   13-overfit
# 36          8000         100      30  RMSprop(lr=1e-4)  0.946           ok
# 37          8000         100      40  RMSprop(lr=1e-4)  0.946           ok
# 38          8000         100      50               sgd  0.904       val>tr
# 39          8000         100      70               sgd  0.922     underfit
# 40          8000         100      25  RMSprop(lr=1e-4)  0.910   10-overfit
# 41          8000         100      50               sgd  0.914      val>>tr
# 42          8000         100     100               sgd  0.932   80-overfit
# 43          8000         100      40          adadelta  0.952   15-overfit
# 44          8000         100      17          adadelta  0.934           ok
# 45          8000         100      25  RMSprop(lr=1e-4)  0.900           ok
# 46          8000         100      30  RMSprop(lr=1e-4)  0.952           ok
# 47          8000         100      30               sgd  0.978   10-overfit
# 48          8000         100      12               sgd  0.964           ok
# 49          8000         100      20               sgd  0.982    3-overfit
# 50          8000         100      12  RMSprop(lr=1e-4)  0.982       not ok
# 51          8000         100       5               sgd  0.978           ok
# 52          8000         100      20               sgd  0.984    3-overfit
# 53          8000         100       5               sgd  0.982           ok
# 54          8000         100      20               sgd  0.984    3-overfit
# 55          8000         100       5               sgd  0.988           ok
# 56          8000         100       5               sgd  0.986           ok
